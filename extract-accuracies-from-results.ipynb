# %%
## process files
import glob
import pprint as pp

use_Morfessor = False
if use_Morfessor:
    target_dir_root = "results-Morfessor"
    target_subdir = "ml2.5"
    target_dir_path = f"{target_dir_root}/{target_subdir}/1.2k"
else:
    target_dir_root = "results"
    target_subdir = "1.2k/mgv6-xsk"
    target_dir_path = f"{target_dir_root}/{target_subdir}"
files = glob.glob(f"{target_dir_path}/*")
#pprint.pprint(files)

## filter files
import re
filter_by_sample_n = False
lang_name = ""
if filter_by_sample_n:
    sample_n = 2000
    data_files = [ file for file in files if re.match(f".*result-{lang_name}.*{sample_n}.*.txt", file) ]
else:
    data_files = [ file for file in files if re.match(f".*result-{lang_name}.*.txt", file) ]
pp.pprint(data_files)
# Out:
# ['results/1.2k/mgv6-xsk/result-Czech2-sample1200-xsk-mgv6-2025-1-9-8-57.txt',
#  'results/1.2k/mgv6-xsk/result-Irish-sample1200-xsk-mgv6-2025-1-7-9-23.txt',
#  'results/1.2k/mgv6-xsk/result-French-sample1200-xsk-mgv6-2025-1-4-19-27.txt',
#  'results/1.2k/mgv6-xsk/result-German-sample1200-xsk-mgv6-2025-1-7-8-43.txt',
#  'results/1.2k/mgv6-xsk/result-Czech2-sample1200-xsk-mgv6-2025-1-10-8-31.txt',
#  'results/1.2k/mgv6-xsk/result-Czech-sample1200-xsk-mgv6-2025-1-4-17-4.txt']

# %%
## extract values
import io, re
import pprint as pp
method_names = [ 'DT', 'RF', 'NN', 'MM' ]
attr_names   = [ 'gender', 'plurality', 'case', 'case2' ]
trueness     = [ 'True]', 'False]' ]
lang_names   = [ 'Czech', 'French', 'German', 'Irish' ]
term_names   = [ f"{x}{y}gram{z}" for x in [ '', 'skippy', 'xskippy' ]
                                    for y in range(2,5)
                                    for z in ['-no-hash', '-hash-at-both'] ]
pp.pprint(f"term_names: {term_names}")

## define registered vals
registered_vals = method_names + lang_names + attr_names + trueness + term_names
pp.pprint(f"registered_vals: {registered_vals}")
# Out:
# ("term_names: ['2gram-no-hash', '2gram-hash-at-both', '3gram-no-hash', "
#  "'3gram-hash-at-both', '4gram-no-hash', '4gram-hash-at-both', "
#  "'skippy2gram-no-hash', 'skippy2gram-hash-at-both', 'skippy3gram-no-hash', "
#  "'skippy3gram-hash-at-both', 'skippy4gram-no-hash', "
#  "'skippy4gram-hash-at-both', 'xskippy2gram-no-hash', "
#  "'xskippy2gram-hash-at-both', 'xskippy3gram-no-hash', "
#  "'xskippy3gram-hash-at-both', 'xskippy4gram-no-hash', "
#  "'xskippy4gram-hash-at-both']")
# ("registered_vals: ['DT', 'RF', 'NN', 'MM', 'Czech', 'French', 'German', "
#  "'Irish', 'gender', 'plurality', 'case', 'case2', 'True]', 'False]', "
#  "'2gram-no-hash', '2gram-hash-at-both', '3gram-no-hash', "
#  "'3gram-hash-at-both', '4gram-no-hash', '4gram-hash-at-both', "
#  "'skippy2gram-no-hash', 'skippy2gram-hash-at-both', 'skippy3gram-no-hash', "
#  "'skippy3gram-hash-at-both', 'skippy4gram-no-hash', "
#  "'skippy4gram-hash-at-both', 'xskippy2gram-no-hash', "
#  "'xskippy2gram-hash-at-both', 'xskippy3gram-no-hash', "
#  "'xskippy3gram-hash-at-both', 'xskippy4gram-no-hash', "
#  "'xskippy4gram-hash-at-both']")

# %%
def select_lines (lines, check: bool = False):
    import re
    lines = [ line.strip() for line in lines if len(line.strip()) > 0 ]
    values  = [ ]
    for i, line in enumerate(lines):
        fields = re.split(r"\s\s*", line)
        if check:
            print(f"fields: {fields}")
        ## define value
        if fields[0] in method_names:
            method_line = fields
        elif fields[0] in [ 'accuracy' ]:
            accuracy_val = fields[-2]
            ##
            value = (method_line, accuracy_val)
            if check:
                print(f"value: {value}")
            values.append(value)
    ##
    if check:
        print(f"values: {values}")
    return values

# %%
def extract_values (records, registered: list, check: bool = False):
    import re
    extracted = [ ]
    for record in records:
        if check:
            print(f"record: {record}")
        method, accuracy = record
        if check:
            print(f"method: {method}")
            print(f"accuracy: {accuracy}")
        F = [ field for field in method if field in registered ]
        F = [ 'NN' if x == 'MM' else x for x in F ]
        F = [ 'True' if x == 'True]' else x for x in F ]
        F = [ 'False' if x == 'False]' else x for x in F ]
        F.append(accuracy)
        extracted.append(F)
    ##
    if check:
        print(f"extracted: {extracted}")
    return extracted

# %%
## extract values and create df
def process_files (data_files, registered_vals, check: bool = True):
    import pandas as pd
    dfs = [ ]
    for file in data_files:
        if check:
            print(f"opening {file}")
        ##
        with io.open(file, encoding = 'utf-8_sig') as f:
            lines = [ line.strip() for line in f.readlines() if len(line) > 0 ]
            if not len(lines) > 1:
                continue
            records = extract_values (select_lines (lines, check = False), registered_vals, check = False)
        if check:
            print(records)
        ##
        records_rev = [ ]
        for i, record in enumerate(records):
            if check:
                print(f"record {i:03d}: {record} [type: {type(record)}]")
            if len(record) < 6:
                print(f"found invalid record to modify")
                print(record)
                lang_present = any(map(lambda x: x in record, lang_names))
                print(f"lang_present: {lang_present}")
                if not lang_present:
                    record.insert(3, last_lang_name)
                term_present = any(map(lambda x: x in record, term_names))
                print(f"term_present: {term_present}")
                if not term_present:
                    record.insert(4, last_term_name)
                print(f"modified {i:03d} to:\n{record} [type: {type(record)}]")
                records_rev.append(record)
            else:
                print(f"found valid record")
                print(record)
                records_rev.append(record)
                last_lang_name = [ x for x in record if x in lang_names ][0]
                last_term_name = [ x for x in record if x in term_names ][0]
        ##
        df = pd.DataFrame(columns = [ 'lang', 'attribute', 'supplement', 'method', 'term_type', 'accuracy'])
        for i, record in enumerate(records_rev):
            if check:
                print(f"record {i:03d}: {record}")
            method, attr, supplement, lang, term, accuracy = record
            df.loc[i] = [lang, attr, supplement, method, term, accuracy]
        
        ## handle file name
        fn_fields = re.split(r"[.-]", re.split(r"/", file)[-1]) # split by "/" first
        print(f"fn_fields: {fn_fields}")
        if 'sk' in fn_fields or 'xsk' in fn_fields:
            _, lang, sample, term_setting, mgv, year, month, day, hour, minute, *_ = fn_fields
        else:
            _, lang, sample, mgv, year, month, day, hour, minute, *_ = fn_fields
            term_setting = ""
        ## define record
        key = (lang, sample, term_setting, mgv, month, day, hour, minute)
        #print(f"key: {key}")
        if key[0] == '':
            key = key[1:]
        print(f"key: {key}")
        dfs.append((key, df))
    ##
    return dfs

# %%
## transform df
import pandas as pd
def df_reconfigure (df, skippy_means_extended: bool = False, check_attribute_n: bool = True, check: bool = False):
    attributes = sorted (set(df['attribute']), reverse = True)
    if check:
        print(attributes)
    if check_attribute_n:
        lang_name = set(df['lang'])
        print(f"lang_name: {lang_name}")
        if lang_name in ['Czech', 'German', 'Irish'] and len(attributes) != 3:
            print(f"ignored input df")
            return
        elif lang_name in [ 'French' ] and len(attributes) != 2:
            print(f"ignored input df")
            return
    ##
    leader_vars = ['lang', 'attribute', 'supplement', 'method']
    dfs_attributes = [ ]
    for attribute in attributes:
        print(f"attribute: {attribute}")
        df_attr = df[df['attribute'] == attribute]
        if check:
            print(df_attr)
        ##
        dfs_suppl = [ ]
        supplements = set(df_attr['supplement'])
        for supplement in supplements:
            #print(f"supplement: {supplement}")
            df_suppl = df_attr[df_attr['supplement'] == supplement]
            suppl_leader_vals = df_suppl[leader_vars].iloc[0,:].T
            ## method
            dfs_method = [ ]
            methods = set(df_attr['method'])
            for method in methods:
                #print(f"method: {method}")
                method_group = [ ]
                df_method = df_suppl[df_suppl['method'] == method]
                
                # define vars
                term_types = df_method['term_type']
                ## rename skippy to xskippy if necessary
                if skippy_means_extended:
                    import re
                    term_types = [ re.sub('skippy', 'xskippy', t) for t in term_types ]
                ## simplify term_type names
                term_types = [ re.sub('skippy', 'sk', t) for t in term_types ]
                vars = leader_vars + list(term_types) # Crucially, list(term_types)
                
                # define leader_vals
                suppl_leader_vals = df_method[leader_vars].iloc[0,:].T
                method_group.extend(suppl_leader_vals)
                
                # define values
                values     = df_method['accuracy']
                method_group.extend(values)
                if check:
                    print(f"method_grouped: {method_group}")
                
                # define df
                temp_df = pd.DataFrame(columns = vars)
                temp_df.loc[0,:] = method_group
                if check:
                    print(f"temp_df: {temp_df}")
                dfs_method.append(temp_df)
            ##
            merged_df_method = pd.concat(dfs_method)
            if check:
                print(f"merged_df_method: {merged_df_method}")
            # update dfs_suppl
            dfs_suppl.append(merged_df_method)
        # update dfs_attributes
        dfs_attributes.extend(dfs_suppl)
    ##
    return pd.concat(dfs_attributes)

# %%
## process files
dfx = process_files(data_files, registered_vals, check = False)
for i, data in enumerate(dfx):
    print(f"data {i:02d}")
    key, df = data
    print(f"df key: {key}")
    print(df)
# Out:
# found valid record
# ['DT', 'gender', 'True', 'Czech', '2gram-no-hash', '0.88']
# found invalid record to modify
# ['RF', 'gender', 'True', '2gram-no-hash', '0.90']
# lang_present: False
# term_present: True
# modified 001 to:
# ['RF', 'gender', 'True', 'Czech', '2gram-no-hash', '0.90'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', '2gram-no-hash', '0.94']
# found valid record
# ['DT', 'gender', 'False', 'Czech', '2gram-no-hash', '0.63']
# found invalid record to modify
# ['RF', 'gender', 'False', '2gram-no-hash', '0.75']
# lang_present: False
# term_present: True
# modified 004 to:
# ['RF', 'gender', 'False', 'Czech', '2gram-no-hash', '0.75'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', '2gram-no-hash', '0.72']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', '2gram-no-hash', '0.85']
# found invalid record to modify
# ['RF', 'plurality', 'True', '2gram-no-hash', '0.86']
# lang_present: False
# term_present: True
# modified 007 to:
# ['RF', 'plurality', 'True', 'Czech', '2gram-no-hash', '0.86'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', '2gram-no-hash', '0.82']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', '2gram-no-hash', '0.80']
# found invalid record to modify
# ['RF', 'plurality', 'False', '2gram-no-hash', '0.81']
# lang_present: False
# term_present: True
# modified 010 to:
# ['RF', 'plurality', 'False', 'Czech', '2gram-no-hash', '0.81'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', '2gram-no-hash', '0.76']
# found valid record
# ['DT', 'case', 'True', 'Czech', '2gram-no-hash', '0.37']
# found invalid record to modify
# ['RF', 'case', 'True', '2gram-no-hash', '0.45']
# lang_present: False
# term_present: True
# modified 013 to:
# ['RF', 'case', 'True', 'Czech', '2gram-no-hash', '0.45'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', '2gram-no-hash', '0.40']
# found valid record
# ['DT', 'case', 'False', 'Czech', '2gram-no-hash', '0.36']
# found invalid record to modify
# ['RF', 'case', 'False', '2gram-no-hash', '0.37']
# lang_present: False
# term_present: True
# modified 016 to:
# ['RF', 'case', 'False', 'Czech', '2gram-no-hash', '0.37'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', '2gram-no-hash', '0.36']
# found valid record
# ['DT', 'gender', 'True', 'Czech', '3gram-no-hash', '0.88']
# found invalid record to modify
# ['RF', 'gender', 'True', '3gram-no-hash', '0.92']
# lang_present: False
# term_present: True
# modified 019 to:
# ['RF', 'gender', 'True', 'Czech', '3gram-no-hash', '0.92'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', '3gram-no-hash', '0.91']
# found valid record
# ['DT', 'gender', 'False', 'Czech', '3gram-no-hash', '0.61']
# found invalid record to modify
# ['RF', 'gender', 'False', '3gram-no-hash', '0.70']
# lang_present: False
# term_present: True
# modified 022 to:
# ['RF', 'gender', 'False', 'Czech', '3gram-no-hash', '0.70'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', '3gram-no-hash', '0.61']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', '3gram-no-hash', '0.89']
# found invalid record to modify
# ['RF', 'plurality', 'True', '3gram-no-hash', '0.93']
# lang_present: False
# term_present: True
# modified 025 to:
# ['RF', 'plurality', 'True', 'Czech', '3gram-no-hash', '0.93'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', '3gram-no-hash', '0.87']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', '3gram-no-hash', '0.83']
# found invalid record to modify
# ['RF', 'plurality', 'False', '3gram-no-hash', '0.87']
# lang_present: False
# term_present: True
# modified 028 to:
# ['RF', 'plurality', 'False', 'Czech', '3gram-no-hash', '0.87'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', '3gram-no-hash', '0.78']
# found valid record
# ['DT', 'case', 'True', 'Czech', '3gram-no-hash', '0.41']
# found invalid record to modify
# ['RF', 'case', 'True', '3gram-no-hash', '0.56']
# lang_present: False
# term_present: True
# modified 031 to:
# ['RF', 'case', 'True', 'Czech', '3gram-no-hash', '0.56'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', '3gram-no-hash', '0.37']
# found valid record
# ['DT', 'case', 'False', 'Czech', '3gram-no-hash', '0.37']
# found invalid record to modify
# ['RF', 'case', 'False', '3gram-no-hash', '0.46']
# lang_present: False
# term_present: True
# modified 034 to:
# ['RF', 'case', 'False', 'Czech', '3gram-no-hash', '0.46'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', '3gram-no-hash', '0.29']
# found valid record
# ['DT', 'gender', 'True', 'Czech', '4gram-no-hash', '0.74']
# found invalid record to modify
# ['RF', 'gender', 'True', '4gram-no-hash', '0.91']
# lang_present: False
# term_present: True
# modified 037 to:
# ['RF', 'gender', 'True', 'Czech', '4gram-no-hash', '0.91'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', '4gram-no-hash', '0.88']
# found valid record
# ['DT', 'gender', 'False', 'Czech', '4gram-no-hash', '0.58']
# found invalid record to modify
# ['RF', 'gender', 'False', '4gram-no-hash', '0.69']
# lang_present: False
# term_present: True
# modified 040 to:
# ['RF', 'gender', 'False', 'Czech', '4gram-no-hash', '0.69'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', '4gram-no-hash', '0.68']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', '4gram-no-hash', '0.84']
# found invalid record to modify
# ['RF', 'plurality', 'True', '4gram-no-hash', '0.81']
# lang_present: False
# term_present: True
# modified 043 to:
# ['RF', 'plurality', 'True', 'Czech', '4gram-no-hash', '0.81'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', '4gram-no-hash', '0.82']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', '4gram-no-hash', '0.78']
# found invalid record to modify
# ['RF', 'plurality', 'False', '4gram-no-hash', '0.79']
# lang_present: False
# term_present: True
# modified 046 to:
# ['RF', 'plurality', 'False', 'Czech', '4gram-no-hash', '0.79'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', '4gram-no-hash', '0.78']
# found valid record
# ['DT', 'case', 'True', 'Czech', '4gram-no-hash', '0.41']
# found invalid record to modify
# ['RF', 'case', 'True', '4gram-no-hash', '0.47']
# lang_present: False
# term_present: True
# modified 049 to:
# ['RF', 'case', 'True', 'Czech', '4gram-no-hash', '0.47'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', '4gram-no-hash', '0.39']
# found valid record
# ['DT', 'case', 'False', 'Czech', '4gram-no-hash', '0.44']
# found invalid record to modify
# ['RF', 'case', 'False', '4gram-no-hash', '0.41']
# lang_present: False
# term_present: True
# modified 052 to:
# ['RF', 'case', 'False', 'Czech', '4gram-no-hash', '0.41'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', '4gram-no-hash', '0.32']
# found valid record
# ['DT', 'gender', 'True', 'Czech', 'skippy2gram-no-hash', '0.75']
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy2gram-no-hash', '0.87']
# lang_present: False
# term_present: True
# modified 055 to:
# ['RF', 'gender', 'True', 'Czech', 'skippy2gram-no-hash', '0.87'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', 'skippy2gram-no-hash', '0.84']
# found valid record
# ['DT', 'gender', 'False', 'Czech', 'skippy2gram-no-hash', '0.56']
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy2gram-no-hash', '0.68']
# lang_present: False
# term_present: True
# modified 058 to:
# ['RF', 'gender', 'False', 'Czech', 'skippy2gram-no-hash', '0.68'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', 'skippy2gram-no-hash', '0.67']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', 'skippy2gram-no-hash', '0.82']
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy2gram-no-hash', '0.82']
# lang_present: False
# term_present: True
# modified 061 to:
# ['RF', 'plurality', 'True', 'Czech', 'skippy2gram-no-hash', '0.82'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', 'skippy2gram-no-hash', '0.82']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', 'skippy2gram-no-hash', '0.82']
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy2gram-no-hash', '0.82']
# lang_present: False
# term_present: True
# modified 064 to:
# ['RF', 'plurality', 'False', 'Czech', 'skippy2gram-no-hash', '0.82'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', 'skippy2gram-no-hash', '0.76']
# found valid record
# ['DT', 'case', 'True', 'Czech', 'skippy2gram-no-hash', '0.43']
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy2gram-no-hash', '0.47']
# lang_present: False
# term_present: True
# modified 067 to:
# ['RF', 'case', 'True', 'Czech', 'skippy2gram-no-hash', '0.47'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', 'skippy2gram-no-hash', '0.36']
# found valid record
# ['DT', 'case', 'False', 'Czech', 'skippy2gram-no-hash', '0.42']
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy2gram-no-hash', '0.44']
# lang_present: False
# term_present: True
# modified 070 to:
# ['RF', 'case', 'False', 'Czech', 'skippy2gram-no-hash', '0.44'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', 'skippy2gram-no-hash', '0.36']
# found valid record
# ['DT', 'gender', 'True', 'Czech', 'skippy3gram-no-hash', '0.55']
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy3gram-no-hash', '0.88']
# lang_present: False
# term_present: True
# modified 073 to:
# ['RF', 'gender', 'True', 'Czech', 'skippy3gram-no-hash', '0.88'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', 'skippy3gram-no-hash', '0.79']
# found valid record
# ['DT', 'gender', 'False', 'Czech', 'skippy3gram-no-hash', '0.50']
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy3gram-no-hash', '0.69']
# lang_present: False
# term_present: True
# modified 076 to:
# ['RF', 'gender', 'False', 'Czech', 'skippy3gram-no-hash', '0.69'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', 'skippy3gram-no-hash', '0.66']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', 'skippy3gram-no-hash', '0.76']
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy3gram-no-hash', '0.85']
# lang_present: False
# term_present: True
# modified 079 to:
# ['RF', 'plurality', 'True', 'Czech', 'skippy3gram-no-hash', '0.85'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', 'skippy3gram-no-hash', '0.81']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', 'skippy3gram-no-hash', '0.77']
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy3gram-no-hash', '0.86']
# lang_present: False
# term_present: True
# modified 082 to:
# ['RF', 'plurality', 'False', 'Czech', 'skippy3gram-no-hash', '0.86'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', 'skippy3gram-no-hash', '0.85']
# found valid record
# ['DT', 'case', 'True', 'Czech', 'skippy3gram-no-hash', '0.37']
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy3gram-no-hash', '0.50']
# lang_present: False
# term_present: True
# modified 085 to:
# ['RF', 'case', 'True', 'Czech', 'skippy3gram-no-hash', '0.50'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', 'skippy3gram-no-hash', '0.39']
# found valid record
# ['DT', 'case', 'False', 'Czech', 'skippy3gram-no-hash', '0.39']
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy3gram-no-hash', '0.41']
# lang_present: False
# term_present: True
# modified 088 to:
# ['RF', 'case', 'False', 'Czech', 'skippy3gram-no-hash', '0.41'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', 'skippy3gram-no-hash', '0.36']
# found valid record
# ['DT', 'gender', 'True', 'Czech', 'skippy4gram-no-hash', '0.66']
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy4gram-no-hash', '0.89']
# lang_present: False
# term_present: True
# modified 091 to:
# ['RF', 'gender', 'True', 'Czech', 'skippy4gram-no-hash', '0.89'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', 'skippy4gram-no-hash', '0.72']
# found valid record
# ['DT', 'gender', 'False', 'Czech', 'skippy4gram-no-hash', '0.57']
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy4gram-no-hash', '0.63']
# lang_present: False
# term_present: True
# modified 094 to:
# ['RF', 'gender', 'False', 'Czech', 'skippy4gram-no-hash', '0.63'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', 'skippy4gram-no-hash', '0.67']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', 'skippy4gram-no-hash', '0.77']
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy4gram-no-hash', '0.82']
# lang_present: False
# term_present: True
# modified 097 to:
# ['RF', 'plurality', 'True', 'Czech', 'skippy4gram-no-hash', '0.82'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', 'skippy4gram-no-hash', '0.84']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', 'skippy4gram-no-hash', '0.80']
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy4gram-no-hash', '0.82']
# lang_present: False
# term_present: True
# modified 100 to:
# ['RF', 'plurality', 'False', 'Czech', 'skippy4gram-no-hash', '0.82'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', 'skippy4gram-no-hash', '0.82']
# found valid record
# ['DT', 'case', 'True', 'Czech', 'skippy4gram-no-hash', '0.41']
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy4gram-no-hash', '0.50']
# lang_present: False
# term_present: True
# modified 103 to:
# ['RF', 'case', 'True', 'Czech', 'skippy4gram-no-hash', '0.50'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', 'skippy4gram-no-hash', '0.45']
# found valid record
# ['DT', 'case', 'False', 'Czech', 'skippy4gram-no-hash', '0.35']
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy4gram-no-hash', '0.44']
# lang_present: False
# term_present: True
# modified 106 to:
# ['RF', 'case', 'False', 'Czech', 'skippy4gram-no-hash', '0.44'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', 'skippy4gram-no-hash', '0.42']
# found valid record
# ['DT', 'gender', 'True', 'Czech', '2gram-hash-at-both', '0.91']
# found invalid record to modify
# ['RF', 'gender', 'True', '2gram-hash-at-both', '0.93']
# lang_present: False
# term_present: True
# modified 109 to:
# ['RF', 'gender', 'True', 'Czech', '2gram-hash-at-both', '0.93'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', '2gram-hash-at-both', '0.90']
# found valid record
# ['DT', 'gender', 'False', 'Czech', '2gram-hash-at-both', '0.63']
# found invalid record to modify
# ['RF', 'gender', 'False', '2gram-hash-at-both', '0.67']
# lang_present: False
# term_present: True
# modified 112 to:
# ['RF', 'gender', 'False', 'Czech', '2gram-hash-at-both', '0.67'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', '2gram-hash-at-both', '0.59']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', '2gram-hash-at-both', '0.89']
# found invalid record to modify
# ['RF', 'plurality', 'True', '2gram-hash-at-both', '0.92']
# lang_present: False
# term_present: True
# modified 115 to:
# ['RF', 'plurality', 'True', 'Czech', '2gram-hash-at-both', '0.92'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', '2gram-hash-at-both', '0.85']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', '2gram-hash-at-both', '0.80']
# found invalid record to modify
# ['RF', 'plurality', 'False', '2gram-hash-at-both', '0.84']
# lang_present: False
# term_present: True
# modified 118 to:
# ['RF', 'plurality', 'False', 'Czech', '2gram-hash-at-both', '0.84'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', '2gram-hash-at-both', '0.78']
# found valid record
# ['DT', 'case', 'True', 'Czech', '2gram-hash-at-both', '0.47']
# found invalid record to modify
# ['RF', 'case', 'True', '2gram-hash-at-both', '0.46']
# lang_present: False
# term_present: True
# modified 121 to:
# ['RF', 'case', 'True', 'Czech', '2gram-hash-at-both', '0.46'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', '2gram-hash-at-both', '0.44']
# found valid record
# ['DT', 'case', 'False', 'Czech', '2gram-hash-at-both', '0.38']
# found invalid record to modify
# ['RF', 'case', 'False', '2gram-hash-at-both', '0.42']
# lang_present: False
# term_present: True
# modified 124 to:
# ['RF', 'case', 'False', 'Czech', '2gram-hash-at-both', '0.42'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', '2gram-hash-at-both', '0.45']
# found valid record
# ['DT', 'gender', 'True', 'Czech', '3gram-hash-at-both', '0.65']
# found invalid record to modify
# ['RF', 'gender', 'True', '3gram-hash-at-both', '0.93']
# lang_present: False
# term_present: True
# modified 127 to:
# ['RF', 'gender', 'True', 'Czech', '3gram-hash-at-both', '0.93'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', '3gram-hash-at-both', '0.95']
# found valid record
# ['DT', 'gender', 'False', 'Czech', '3gram-hash-at-both', '0.59']
# found invalid record to modify
# ['RF', 'gender', 'False', '3gram-hash-at-both', '0.72']
# lang_present: False
# term_present: True
# modified 130 to:
# ['RF', 'gender', 'False', 'Czech', '3gram-hash-at-both', '0.72'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', '3gram-hash-at-both', '0.75']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', '3gram-hash-at-both', '0.86']
# found invalid record to modify
# ['RF', 'plurality', 'True', '3gram-hash-at-both', '0.84']
# lang_present: False
# term_present: True
# modified 133 to:
# ['RF', 'plurality', 'True', 'Czech', '3gram-hash-at-both', '0.84'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', '3gram-hash-at-both', '0.83']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', '3gram-hash-at-both', '0.82']
# found invalid record to modify
# ['RF', 'plurality', 'False', '3gram-hash-at-both', '0.83']
# lang_present: False
# term_present: True
# modified 136 to:
# ['RF', 'plurality', 'False', 'Czech', '3gram-hash-at-both', '0.83'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', '3gram-hash-at-both', '0.80']
# found valid record
# ['DT', 'case', 'True', 'Czech', '3gram-hash-at-both', '0.42']
# found invalid record to modify
# ['RF', 'case', 'True', '3gram-hash-at-both', '0.45']
# lang_present: False
# term_present: True
# modified 139 to:
# ['RF', 'case', 'True', 'Czech', '3gram-hash-at-both', '0.45'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', '3gram-hash-at-both', '0.38']
# found valid record
# ['DT', 'case', 'False', 'Czech', '3gram-hash-at-both', '0.39']
# found invalid record to modify
# ['RF', 'case', 'False', '3gram-hash-at-both', '0.36']
# lang_present: False
# term_present: True
# modified 142 to:
# ['RF', 'case', 'False', 'Czech', '3gram-hash-at-both', '0.36'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', '3gram-hash-at-both', '0.36']
# found valid record
# ['DT', 'gender', 'True', 'Czech', '4gram-hash-at-both', '0.66']
# found invalid record to modify
# ['RF', 'gender', 'True', '4gram-hash-at-both', '0.88']
# lang_present: False
# term_present: True
# modified 145 to:
# ['RF', 'gender', 'True', 'Czech', '4gram-hash-at-both', '0.88'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', '4gram-hash-at-both', '0.91']
# found valid record
# ['DT', 'gender', 'False', 'Czech', '4gram-hash-at-both', '0.64']
# found invalid record to modify
# ['RF', 'gender', 'False', '4gram-hash-at-both', '0.71']
# lang_present: False
# term_present: True
# modified 148 to:
# ['RF', 'gender', 'False', 'Czech', '4gram-hash-at-both', '0.71'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', '4gram-hash-at-both', '0.69']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', '4gram-hash-at-both', '0.82']
# found invalid record to modify
# ['RF', 'plurality', 'True', '4gram-hash-at-both', '0.87']
# lang_present: False
# term_present: True
# modified 151 to:
# ['RF', 'plurality', 'True', 'Czech', '4gram-hash-at-both', '0.87'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', '4gram-hash-at-both', '0.78']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', '4gram-hash-at-both', '0.77']
# found invalid record to modify
# ['RF', 'plurality', 'False', '4gram-hash-at-both', '0.79']
# lang_present: False
# term_present: True
# modified 154 to:
# ['RF', 'plurality', 'False', 'Czech', '4gram-hash-at-both', '0.79'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', '4gram-hash-at-both', '0.75']
# found valid record
# ['DT', 'case', 'True', 'Czech', '4gram-hash-at-both', '0.31']
# found invalid record to modify
# ['RF', 'case', 'True', '4gram-hash-at-both', '0.48']
# lang_present: False
# term_present: True
# modified 157 to:
# ['RF', 'case', 'True', 'Czech', '4gram-hash-at-both', '0.48'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', '4gram-hash-at-both', '0.42']
# found valid record
# ['DT', 'case', 'False', 'Czech', '4gram-hash-at-both', '0.42']
# found invalid record to modify
# ['RF', 'case', 'False', '4gram-hash-at-both', '0.35']
# lang_present: False
# term_present: True
# modified 160 to:
# ['RF', 'case', 'False', 'Czech', '4gram-hash-at-both', '0.35'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', '4gram-hash-at-both', '0.35']
# found valid record
# ['DT', 'gender', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.75']
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy2gram-hash-at-both', '0.84']
# lang_present: False
# term_present: True
# modified 163 to:
# ['RF', 'gender', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.84'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.86']
# found valid record
# ['DT', 'gender', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.57']
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy2gram-hash-at-both', '0.67']
# lang_present: False
# term_present: True
# modified 166 to:
# ['RF', 'gender', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.67'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.67']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.82']
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy2gram-hash-at-both', '0.88']
# lang_present: False
# term_present: True
# modified 169 to:
# ['RF', 'plurality', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.88'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.81']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.82']
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy2gram-hash-at-both', '0.88']
# lang_present: False
# term_present: True
# modified 172 to:
# ['RF', 'plurality', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.88'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.79']
# found valid record
# ['DT', 'case', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.40']
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy2gram-hash-at-both', '0.45']
# lang_present: False
# term_present: True
# modified 175 to:
# ['RF', 'case', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.45'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.42']
# found valid record
# ['DT', 'case', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.36']
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy2gram-hash-at-both', '0.37']
# lang_present: False
# term_present: True
# modified 178 to:
# ['RF', 'case', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.37'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.39']
# found valid record
# ['DT', 'gender', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.58']
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy3gram-hash-at-both', '0.84']
# lang_present: False
# term_present: True
# modified 181 to:
# ['RF', 'gender', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.84'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.84']
# found valid record
# ['DT', 'gender', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.59']
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy3gram-hash-at-both', '0.69']
# lang_present: False
# term_present: True
# modified 184 to:
# ['RF', 'gender', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.69'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.69']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.80']
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy3gram-hash-at-both', '0.87']
# lang_present: False
# term_present: True
# modified 187 to:
# ['RF', 'plurality', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.87'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.78']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.78']
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy3gram-hash-at-both', '0.85']
# lang_present: False
# term_present: True
# modified 190 to:
# ['RF', 'plurality', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.85'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.80']
# found valid record
# ['DT', 'case', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.42']
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy3gram-hash-at-both', '0.43']
# lang_present: False
# term_present: True
# modified 193 to:
# ['RF', 'case', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.43'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.38']
# found valid record
# ['DT', 'case', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.34']
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy3gram-hash-at-both', '0.42']
# lang_present: False
# term_present: True
# modified 196 to:
# ['RF', 'case', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.42'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.36']
# found valid record
# ['DT', 'gender', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.44']
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy4gram-hash-at-both', '0.78']
# lang_present: False
# term_present: True
# modified 199 to:
# ['RF', 'gender', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.78'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.80']
# found valid record
# ['DT', 'gender', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.52']
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy4gram-hash-at-both', '0.57']
# lang_present: False
# term_present: True
# modified 202 to:
# ['RF', 'gender', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.57'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.67']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.78']
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy4gram-hash-at-both', '0.82']
# lang_present: False
# term_present: True
# modified 205 to:
# ['RF', 'plurality', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.82'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.74']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.73']
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy4gram-hash-at-both', '0.82']
# lang_present: False
# term_present: True
# modified 208 to:
# ['RF', 'plurality', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.82'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.78']
# found valid record
# ['DT', 'case', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.38']
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy4gram-hash-at-both', '0.45']
# lang_present: False
# term_present: True
# modified 211 to:
# ['RF', 'case', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.45'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.29']
# found valid record
# ['DT', 'case', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.37']
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy4gram-hash-at-both', '0.36']
# lang_present: False
# term_present: True
# modified 214 to:
# ['RF', 'case', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.36'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.29']
# fn_fields: ['result', 'Czech2', 'sample1200', 'xsk', 'mgv6', '2025', '1', '9', '8', '57', 'txt']
# key: ('Czech2', 'sample1200', 'xsk', 'mgv6', '1', '9', '8', '57')
# found valid record
# ['DT', 'gender', 'True', 'Irish', '2gram-no-hash', '0.77']
# found invalid record to modify
# ['RF', 'gender', 'True', '2gram-no-hash', '0.76']
# lang_present: False
# term_present: True
# modified 001 to:
# ['RF', 'gender', 'True', 'Irish', '2gram-no-hash', '0.76'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Irish', '2gram-no-hash', '0.74']
# found valid record
# ['DT', 'gender', 'False', 'Irish', '2gram-no-hash', '0.71']
# found invalid record to modify
# ['RF', 'gender', 'False', '2gram-no-hash', '0.72']
# lang_present: False
# term_present: True
# modified 004 to:
# ['RF', 'gender', 'False', 'Irish', '2gram-no-hash', '0.72'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Irish', '2gram-no-hash', '0.71']
# found valid record
# ['DT', 'plurality', 'True', 'Irish', '2gram-no-hash', '0.60']
# found invalid record to modify
# ['RF', 'plurality', 'True', '2gram-no-hash', '0.72']
# lang_present: False
# term_present: True
# modified 007 to:
# ['RF', 'plurality', 'True', 'Irish', '2gram-no-hash', '0.72'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Irish', '2gram-no-hash', '0.59']
# found valid record
# ['DT', 'plurality', 'False', 'Irish', '2gram-no-hash', '0.66']
# found invalid record to modify
# ['RF', 'plurality', 'False', '2gram-no-hash', '0.66']
# lang_present: False
# term_present: True
# modified 010 to:
# ['RF', 'plurality', 'False', 'Irish', '2gram-no-hash', '0.66'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Irish', '2gram-no-hash', '0.58']
# found valid record
# ['DT', 'case', 'True', 'Irish', '2gram-no-hash', '0.98']
# found invalid record to modify
# ['RF', 'case', 'True', '2gram-no-hash', '0.98']
# lang_present: False
# term_present: True
# modified 013 to:
# ['RF', 'case', 'True', 'Irish', '2gram-no-hash', '0.98'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Irish', '2gram-no-hash', '0.98']
# found valid record
# ['DT', 'case', 'False', 'Irish', '2gram-no-hash', '0.98']
# found invalid record to modify
# ['RF', 'case', 'False', '2gram-no-hash', '0.98']
# lang_present: False
# term_present: True
# modified 016 to:
# ['RF', 'case', 'False', 'Irish', '2gram-no-hash', '0.98'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Irish', '2gram-no-hash', '0.98']
# found valid record
# ['DT', 'gender', 'True', 'Irish', '3gram-no-hash', '0.72']
# found invalid record to modify
# ['RF', 'gender', 'True', '3gram-no-hash', '0.75']
# lang_present: False
# term_present: True
# modified 019 to:
# ['RF', 'gender', 'True', 'Irish', '3gram-no-hash', '0.75'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Irish', '3gram-no-hash', '0.73']
# found valid record
# ['DT', 'gender', 'False', 'Irish', '3gram-no-hash', '0.67']
# found invalid record to modify
# ['RF', 'gender', 'False', '3gram-no-hash', '0.76']
# lang_present: False
# term_present: True
# modified 022 to:
# ['RF', 'gender', 'False', 'Irish', '3gram-no-hash', '0.76'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Irish', '3gram-no-hash', '0.70']
# found valid record
# ['DT', 'plurality', 'True', 'Irish', '3gram-no-hash', '0.65']
# found invalid record to modify
# ['RF', 'plurality', 'True', '3gram-no-hash', '0.67']
# lang_present: False
# term_present: True
# modified 025 to:
# ['RF', 'plurality', 'True', 'Irish', '3gram-no-hash', '0.67'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Irish', '3gram-no-hash', '0.64']
# found valid record
# ['DT', 'plurality', 'False', 'Irish', '3gram-no-hash', '0.67']
# found invalid record to modify
# ['RF', 'plurality', 'False', '3gram-no-hash', '0.66']
# lang_present: False
# term_present: True
# modified 028 to:
# ['RF', 'plurality', 'False', 'Irish', '3gram-no-hash', '0.66'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Irish', '3gram-no-hash', '0.59']
# found valid record
# ['DT', 'case', 'True', 'Irish', '3gram-no-hash', '0.97']
# found invalid record to modify
# ['RF', 'case', 'True', '3gram-no-hash', '0.99']
# lang_present: False
# term_present: True
# modified 031 to:
# ['RF', 'case', 'True', 'Irish', '3gram-no-hash', '0.99'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Irish', '3gram-no-hash', '0.99']
# found valid record
# ['DT', 'case', 'False', 'Irish', '3gram-no-hash', '0.94']
# found invalid record to modify
# ['RF', 'case', 'False', '3gram-no-hash', '0.99']
# lang_present: False
# term_present: True
# modified 034 to:
# ['RF', 'case', 'False', 'Irish', '3gram-no-hash', '0.99'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Irish', '3gram-no-hash', '0.99']
# found valid record
# ['DT', 'gender', 'True', 'Irish', '4gram-no-hash', '0.64']
# found invalid record to modify
# ['RF', 'gender', 'True', '4gram-no-hash', '0.75']
# lang_present: False
# term_present: True
# modified 037 to:
# ['RF', 'gender', 'True', 'Irish', '4gram-no-hash', '0.75'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Irish', '4gram-no-hash', '0.75']
# found valid record
# ['DT', 'gender', 'False', 'Irish', '4gram-no-hash', '0.63']
# found invalid record to modify
# ['RF', 'gender', 'False', '4gram-no-hash', '0.71']
# lang_present: False
# term_present: True
# modified 040 to:
# ['RF', 'gender', 'False', 'Irish', '4gram-no-hash', '0.71'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Irish', '4gram-no-hash', '0.61']
# found valid record
# ['DT', 'plurality', 'True', 'Irish', '4gram-no-hash', '0.63']
# found invalid record to modify
# ['RF', 'plurality', 'True', '4gram-no-hash', '0.76']
# lang_present: False
# term_present: True
# modified 043 to:
# ['RF', 'plurality', 'True', 'Irish', '4gram-no-hash', '0.76'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Irish', '4gram-no-hash', '0.66']
# found valid record
# ['DT', 'plurality', 'False', 'Irish', '4gram-no-hash', '0.66']
# found invalid record to modify
# ['RF', 'plurality', 'False', '4gram-no-hash', '0.72']
# lang_present: False
# term_present: True
# modified 046 to:
# ['RF', 'plurality', 'False', 'Irish', '4gram-no-hash', '0.72'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Irish', '4gram-no-hash', '0.61']
# found valid record
# ['DT', 'case', 'True', 'Irish', '4gram-no-hash', '0.97']
# found invalid record to modify
# ['RF', 'case', 'True', '4gram-no-hash', '0.99']
# lang_present: False
# term_present: True
# modified 049 to:
# ['RF', 'case', 'True', 'Irish', '4gram-no-hash', '0.99'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Irish', '4gram-no-hash', '0.99']
# found valid record
# ['DT', 'case', 'False', 'Irish', '4gram-no-hash', '0.99']
# found invalid record to modify
# ['RF', 'case', 'False', '4gram-no-hash', '0.99']
# lang_present: False
# term_present: True
# modified 052 to:
# ['RF', 'case', 'False', 'Irish', '4gram-no-hash', '0.99'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Irish', '4gram-no-hash', '0.99']
# found valid record
# ['DT', 'gender', 'True', 'Irish', 'skippy2gram-no-hash', '0.71']
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy2gram-no-hash', '0.81']
# lang_present: False
# term_present: True
# modified 055 to:
# ['RF', 'gender', 'True', 'Irish', 'skippy2gram-no-hash', '0.81'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Irish', 'skippy2gram-no-hash', '0.74']
# found valid record
# ['DT', 'gender', 'False', 'Irish', 'skippy2gram-no-hash', '0.73']
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy2gram-no-hash', '0.77']
# lang_present: False
# term_present: True
# modified 058 to:
# ['RF', 'gender', 'False', 'Irish', 'skippy2gram-no-hash', '0.77'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Irish', 'skippy2gram-no-hash', '0.70']
# found valid record
# ['DT', 'plurality', 'True', 'Irish', 'skippy2gram-no-hash', '0.63']
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy2gram-no-hash', '0.67']
# lang_present: False
# term_present: True
# modified 061 to:
# ['RF', 'plurality', 'True', 'Irish', 'skippy2gram-no-hash', '0.67'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Irish', 'skippy2gram-no-hash', '0.60']
# found valid record
# ['DT', 'plurality', 'False', 'Irish', 'skippy2gram-no-hash', '0.63']
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy2gram-no-hash', '0.63']
# lang_present: False
# term_present: True
# modified 064 to:
# ['RF', 'plurality', 'False', 'Irish', 'skippy2gram-no-hash', '0.63'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Irish', 'skippy2gram-no-hash', '0.63']
# found valid record
# ['DT', 'case', 'True', 'Irish', 'skippy2gram-no-hash', '0.99']
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy2gram-no-hash', '0.98']
# lang_present: False
# term_present: True
# modified 067 to:
# ['RF', 'case', 'True', 'Irish', 'skippy2gram-no-hash', '0.98'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Irish', 'skippy2gram-no-hash', '0.98']
# found valid record
# ['DT', 'case', 'False', 'Irish', 'skippy2gram-no-hash', '0.98']
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy2gram-no-hash', '0.98']
# lang_present: False
# term_present: True
# modified 070 to:
# ['RF', 'case', 'False', 'Irish', 'skippy2gram-no-hash', '0.98'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Irish', 'skippy2gram-no-hash', '0.98']
# found valid record
# ['DT', 'gender', 'True', 'Irish', 'skippy3gram-no-hash', '0.77']
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy3gram-no-hash', '0.82']
# lang_present: False
# term_present: True
# modified 073 to:
# ['RF', 'gender', 'True', 'Irish', 'skippy3gram-no-hash', '0.82'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Irish', 'skippy3gram-no-hash', '0.78']
# found valid record
# ['DT', 'gender', 'False', 'Irish', 'skippy3gram-no-hash', '0.79']
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy3gram-no-hash', '0.78']
# lang_present: False
# term_present: True
# modified 076 to:
# ['RF', 'gender', 'False', 'Irish', 'skippy3gram-no-hash', '0.78'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Irish', 'skippy3gram-no-hash', '0.72']
# found valid record
# ['DT', 'plurality', 'True', 'Irish', 'skippy3gram-no-hash', '0.71']
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy3gram-no-hash', '0.73']
# lang_present: False
# term_present: True
# modified 079 to:
# ['RF', 'plurality', 'True', 'Irish', 'skippy3gram-no-hash', '0.73'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Irish', 'skippy3gram-no-hash', '0.68']
# found valid record
# ['DT', 'plurality', 'False', 'Irish', 'skippy3gram-no-hash', '0.69']
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy3gram-no-hash', '0.73']
# lang_present: False
# term_present: True
# modified 082 to:
# ['RF', 'plurality', 'False', 'Irish', 'skippy3gram-no-hash', '0.73'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Irish', 'skippy3gram-no-hash', '0.71']
# found valid record
# ['DT', 'case', 'True', 'Irish', 'skippy3gram-no-hash', '0.96']
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy3gram-no-hash', '0.96']
# lang_present: False
# term_present: True
# modified 085 to:
# ['RF', 'case', 'True', 'Irish', 'skippy3gram-no-hash', '0.96'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Irish', 'skippy3gram-no-hash', '0.96']
# found valid record
# ['DT', 'case', 'False', 'Irish', 'skippy3gram-no-hash', '0.96']
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy3gram-no-hash', '0.96']
# lang_present: False
# term_present: True
# modified 088 to:
# ['RF', 'case', 'False', 'Irish', 'skippy3gram-no-hash', '0.96'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Irish', 'skippy3gram-no-hash', '0.96']
# found valid record
# ['DT', 'gender', 'True', 'Irish', 'skippy4gram-no-hash', '0.71']
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy4gram-no-hash', '0.72']
# lang_present: False
# term_present: True
# modified 091 to:
# ['RF', 'gender', 'True', 'Irish', 'skippy4gram-no-hash', '0.72'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Irish', 'skippy4gram-no-hash', '0.72']
# found valid record
# ['DT', 'gender', 'False', 'Irish', 'skippy4gram-no-hash', '0.66']
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy4gram-no-hash', '0.69']
# lang_present: False
# term_present: True
# modified 094 to:
# ['RF', 'gender', 'False', 'Irish', 'skippy4gram-no-hash', '0.69'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Irish', 'skippy4gram-no-hash', '0.67']
# found valid record
# ['DT', 'plurality', 'True', 'Irish', 'skippy4gram-no-hash', '0.61']
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy4gram-no-hash', '0.62']
# lang_present: False
# term_present: True
# modified 097 to:
# ['RF', 'plurality', 'True', 'Irish', 'skippy4gram-no-hash', '0.62'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Irish', 'skippy4gram-no-hash', '0.54']
# found valid record
# ['DT', 'plurality', 'False', 'Irish', 'skippy4gram-no-hash', '0.60']
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy4gram-no-hash', '0.61']
# lang_present: False
# term_present: True
# modified 100 to:
# ['RF', 'plurality', 'False', 'Irish', 'skippy4gram-no-hash', '0.61'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Irish', 'skippy4gram-no-hash', '0.52']
# found valid record
# ['DT', 'case', 'True', 'Irish', 'skippy4gram-no-hash', '0.97']
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy4gram-no-hash', '0.97']
# lang_present: False
# term_present: True
# modified 103 to:
# ['RF', 'case', 'True', 'Irish', 'skippy4gram-no-hash', '0.97'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Irish', 'skippy4gram-no-hash', '0.97']
# found valid record
# ['DT', 'case', 'False', 'Irish', 'skippy4gram-no-hash', '0.97']
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy4gram-no-hash', '0.97']
# lang_present: False
# term_present: True
# modified 106 to:
# ['RF', 'case', 'False', 'Irish', 'skippy4gram-no-hash', '0.97'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Irish', 'skippy4gram-no-hash', '0.97']
# found valid record
# ['DT', 'gender', 'True', 'Irish', '2gram-hash-at-both', '0.75']
# found invalid record to modify
# ['RF', 'gender', 'True', '2gram-hash-at-both', '0.71']
# lang_present: False
# term_present: True
# modified 109 to:
# ['RF', 'gender', 'True', 'Irish', '2gram-hash-at-both', '0.71'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Irish', '2gram-hash-at-both', '0.66']
# found valid record
# ['DT', 'gender', 'False', 'Irish', '2gram-hash-at-both', '0.68']
# found invalid record to modify
# ['RF', 'gender', 'False', '2gram-hash-at-both', '0.68']
# lang_present: False
# term_present: True
# modified 112 to:
# ['RF', 'gender', 'False', 'Irish', '2gram-hash-at-both', '0.68'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Irish', '2gram-hash-at-both', '0.60']
# found valid record
# ['DT', 'plurality', 'True', 'Irish', '2gram-hash-at-both', '0.64']
# found invalid record to modify
# ['RF', 'plurality', 'True', '2gram-hash-at-both', '0.63']
# lang_present: False
# term_present: True
# modified 115 to:
# ['RF', 'plurality', 'True', 'Irish', '2gram-hash-at-both', '0.63'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Irish', '2gram-hash-at-both', '0.71']
# found valid record
# ['DT', 'plurality', 'False', 'Irish', '2gram-hash-at-both', '0.59']
# found invalid record to modify
# ['RF', 'plurality', 'False', '2gram-hash-at-both', '0.59']
# lang_present: False
# term_present: True
# modified 118 to:
# ['RF', 'plurality', 'False', 'Irish', '2gram-hash-at-both', '0.59'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Irish', '2gram-hash-at-both', '0.55']
# found valid record
# ['DT', 'case', 'True', 'Irish', '2gram-hash-at-both', '0.98']
# found invalid record to modify
# ['RF', 'case', 'True', '2gram-hash-at-both', '1.00']
# lang_present: False
# term_present: True
# modified 121 to:
# ['RF', 'case', 'True', 'Irish', '2gram-hash-at-both', '1.00'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Irish', '2gram-hash-at-both', '1.00']
# found valid record
# ['DT', 'case', 'False', 'Irish', '2gram-hash-at-both', '0.97']
# found invalid record to modify
# ['RF', 'case', 'False', '2gram-hash-at-both', '1.00']
# lang_present: False
# term_present: True
# modified 124 to:
# ['RF', 'case', 'False', 'Irish', '2gram-hash-at-both', '1.00'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Irish', '2gram-hash-at-both', '1.00']
# found valid record
# ['DT', 'gender', 'True', 'Irish', '3gram-hash-at-both', '0.76']
# found invalid record to modify
# ['RF', 'gender', 'True', '3gram-hash-at-both', '0.77']
# lang_present: False
# term_present: True
# modified 127 to:
# ['RF', 'gender', 'True', 'Irish', '3gram-hash-at-both', '0.77'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Irish', '3gram-hash-at-both', '0.75']
# found valid record
# ['DT', 'gender', 'False', 'Irish', '3gram-hash-at-both', '0.79']
# found invalid record to modify
# ['RF', 'gender', 'False', '3gram-hash-at-both', '0.83']
# lang_present: False
# term_present: True
# modified 130 to:
# ['RF', 'gender', 'False', 'Irish', '3gram-hash-at-both', '0.83'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Irish', '3gram-hash-at-both', '0.74']
# found valid record
# ['DT', 'plurality', 'True', 'Irish', '3gram-hash-at-both', '0.65']
# found invalid record to modify
# ['RF', 'plurality', 'True', '3gram-hash-at-both', '0.68']
# lang_present: False
# term_present: True
# modified 133 to:
# ['RF', 'plurality', 'True', 'Irish', '3gram-hash-at-both', '0.68'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Irish', '3gram-hash-at-both', '0.61']
# found valid record
# ['DT', 'plurality', 'False', 'Irish', '3gram-hash-at-both', '0.69']
# found invalid record to modify
# ['RF', 'plurality', 'False', '3gram-hash-at-both', '0.70']
# lang_present: False
# term_present: True
# modified 136 to:
# ['RF', 'plurality', 'False', 'Irish', '3gram-hash-at-both', '0.70'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Irish', '3gram-hash-at-both', '0.66']
# found valid record
# ['DT', 'case', 'True', 'Irish', '3gram-hash-at-both', '0.97']
# found invalid record to modify
# ['RF', 'case', 'True', '3gram-hash-at-both', '0.99']
# lang_present: False
# term_present: True
# modified 139 to:
# ['RF', 'case', 'True', 'Irish', '3gram-hash-at-both', '0.99'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Irish', '3gram-hash-at-both', '0.99']
# found valid record
# ['DT', 'case', 'False', 'Irish', '3gram-hash-at-both', '0.99']
# found invalid record to modify
# ['RF', 'case', 'False', '3gram-hash-at-both', '0.99']
# lang_present: False
# term_present: True
# modified 142 to:
# ['RF', 'case', 'False', 'Irish', '3gram-hash-at-both', '0.99'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Irish', '3gram-hash-at-both', '0.99']
# found valid record
# ['DT', 'gender', 'True', 'Irish', '4gram-hash-at-both', '0.77']
# found invalid record to modify
# ['RF', 'gender', 'True', '4gram-hash-at-both', '0.81']
# ...
# lang_present: False
# term_present: True
# modified 145 to:
# ['RF', 'gender', 'True', 'Czech', '4gram-hash-at-both', '0.59'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', '4gram-hash-at-both', '0.62']
# found valid record
# ['DT', 'gender', 'False', 'Czech', '4gram-hash-at-both', '0.45']
# found invalid record to modify
# ['RF', 'gender', 'False', '4gram-hash-at-both', '0.53']
# lang_present: False
# term_present: True
# modified 148 to:
# ['RF', 'gender', 'False', 'Czech', '4gram-hash-at-both', '0.53'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', '4gram-hash-at-both', '0.61']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', '4gram-hash-at-both', '0.97']
# found invalid record to modify
# ['RF', 'plurality', 'True', '4gram-hash-at-both', '0.85']
# lang_present: False
# term_present: True
# modified 151 to:
# ['RF', 'plurality', 'True', 'Czech', '4gram-hash-at-both', '0.85'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', '4gram-hash-at-both', '0.84']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', '4gram-hash-at-both', '0.82']
# found invalid record to modify
# ['RF', 'plurality', 'False', '4gram-hash-at-both', '0.84']
# lang_present: False
# term_present: True
# modified 154 to:
# ['RF', 'plurality', 'False', 'Czech', '4gram-hash-at-both', '0.84'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', '4gram-hash-at-both', '0.72']
# found valid record
# ['DT', 'case', 'True', 'Czech', '4gram-hash-at-both', '0.42']
# found invalid record to modify
# ['RF', 'case', 'True', '4gram-hash-at-both', '0.47']
# lang_present: False
# term_present: True
# modified 157 to:
# ['RF', 'case', 'True', 'Czech', '4gram-hash-at-both', '0.47'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', '4gram-hash-at-both', '0.36']
# found valid record
# ['DT', 'case', 'False', 'Czech', '4gram-hash-at-both', '0.34']
# found invalid record to modify
# ['RF', 'case', 'False', '4gram-hash-at-both', '0.41']
# lang_present: False
# term_present: True
# modified 160 to:
# ['RF', 'case', 'False', 'Czech', '4gram-hash-at-both', '0.41'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', '4gram-hash-at-both', '0.31']
# found valid record
# ['DT', 'gender', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.53']
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy2gram-hash-at-both', '0.59']
# lang_present: False
# term_present: True
# modified 163 to:
# ['RF', 'gender', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.59'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.62']
# found valid record
# ['DT', 'gender', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.56']
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy2gram-hash-at-both', '0.67']
# lang_present: False
# term_present: True
# modified 166 to:
# ['RF', 'gender', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.67'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.62']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.86']
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy2gram-hash-at-both', '0.89']
# lang_present: False
# term_present: True
# modified 169 to:
# ['RF', 'plurality', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.89'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.87']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.81']
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy2gram-hash-at-both', '0.87']
# lang_present: False
# term_present: True
# modified 172 to:
# ['RF', 'plurality', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.87'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.81']
# found valid record
# ['DT', 'case', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.35']
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy2gram-hash-at-both', '0.39']
# lang_present: False
# term_present: True
# modified 175 to:
# ['RF', 'case', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.39'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.44']
# found valid record
# ['DT', 'case', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.36']
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy2gram-hash-at-both', '0.36']
# lang_present: False
# term_present: True
# modified 178 to:
# ['RF', 'case', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.36'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.35']
# found valid record
# ['DT', 'gender', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.51']
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy3gram-hash-at-both', '0.57']
# lang_present: False
# term_present: True
# modified 181 to:
# ['RF', 'gender', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.57'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.68']
# found valid record
# ['DT', 'gender', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.47']
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy3gram-hash-at-both', '0.55']
# lang_present: False
# term_present: True
# modified 184 to:
# ['RF', 'gender', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.55'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.61']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.79']
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy3gram-hash-at-both', '0.78']
# lang_present: False
# term_present: True
# modified 187 to:
# ['RF', 'plurality', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.78'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.80']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.75']
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy3gram-hash-at-both', '0.75']
# lang_present: False
# term_present: True
# modified 190 to:
# ['RF', 'plurality', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.75'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.79']
# found valid record
# ['DT', 'case', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.38']
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy3gram-hash-at-both', '0.50']
# lang_present: False
# term_present: True
# modified 193 to:
# ['RF', 'case', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.50'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.39']
# found valid record
# ['DT', 'case', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.31']
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy3gram-hash-at-both', '0.44']
# lang_present: False
# term_present: True
# modified 196 to:
# ['RF', 'case', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.44'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.41']
# found valid record
# ['DT', 'gender', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.45']
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy4gram-hash-at-both', '0.55']
# lang_present: False
# term_present: True
# modified 199 to:
# ['RF', 'gender', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.55'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.54']
# found valid record
# ['DT', 'gender', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.44']
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy4gram-hash-at-both', '0.57']
# lang_present: False
# term_present: True
# modified 202 to:
# ['RF', 'gender', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.57'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.57']
# found valid record
# ['DT', 'plurality', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.72']
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy4gram-hash-at-both', '0.79']
# lang_present: False
# term_present: True
# modified 205 to:
# ['RF', 'plurality', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.79'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.75']
# found valid record
# ['DT', 'plurality', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.72']
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy4gram-hash-at-both', '0.77']
# lang_present: False
# term_present: True
# modified 208 to:
# ['RF', 'plurality', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.77'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.75']
# found valid record
# ['DT', 'case', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.38']
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy4gram-hash-at-both', '0.44']
# lang_present: False
# term_present: True
# modified 211 to:
# ['RF', 'case', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.44'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.31']
# found valid record
# ['DT', 'case', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.33']
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy4gram-hash-at-both', '0.34']
# lang_present: False
# term_present: True
# modified 214 to:
# ['RF', 'case', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.34'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.29']
# fn_fields: ['result', 'Czech', 'sample1200', 'xsk', 'mgv6', '2025', '1', '4', '17', '4', 'txt']
# key: ('Czech', 'sample1200', 'xsk', 'mgv6', '1', '4', '17', '4')
# data 00
# df key: ('Czech2', 'sample1200', 'xsk', 'mgv6', '1', '9', '8', '57')
#       lang attribute supplement method                 term_type accuracy
# 0    Czech    gender       True     DT             2gram-no-hash     0.88
# 1    Czech    gender       True     RF             2gram-no-hash     0.90
# 2    Czech    gender       True     NN             2gram-no-hash     0.94
# 3    Czech    gender      False     DT             2gram-no-hash     0.63
# 4    Czech    gender      False     RF             2gram-no-hash     0.75
# ..     ...       ...        ...    ...                       ...      ...
# 211  Czech      case       True     RF  skippy4gram-hash-at-both     0.45
# 212  Czech      case       True     NN  skippy4gram-hash-at-both     0.29
# 213  Czech      case      False     DT  skippy4gram-hash-at-both     0.37
# 214  Czech      case      False     RF  skippy4gram-hash-at-both     0.36
# 215  Czech      case      False     NN  skippy4gram-hash-at-both     0.29
#
# [216 rows x 6 columns]
# data 01
# df key: ('Irish', 'sample1200', 'xsk', 'mgv6', '1', '7', '9', '23')
#       lang attribute supplement method                 term_type accuracy
# 0    Irish    gender       True     DT             2gram-no-hash     0.77
# 1    Irish    gender       True     RF             2gram-no-hash     0.76
# 2    Irish    gender       True     NN             2gram-no-hash     0.74
# 3    Irish    gender      False     DT             2gram-no-hash     0.71
# 4    Irish    gender      False     RF             2gram-no-hash     0.72
# ..     ...       ...        ...    ...                       ...      ...
# 211  Irish      case       True     RF  skippy4gram-hash-at-both     0.97
# 212  Irish      case       True     NN  skippy4gram-hash-at-both     0.97
# 213  Irish      case      False     DT  skippy4gram-hash-at-both     0.97
# 214  Irish      case      False     RF  skippy4gram-hash-at-both     0.97
# 215  Irish      case      False     NN  skippy4gram-hash-at-both     0.97
#
# [216 rows x 6 columns]
# data 02
# df key: ('French', 'sample1200', 'xsk', 'mgv6', '1', '4', '19', '27')
#        lang  attribute supplement method                 term_type accuracy
# 0    French     gender       True     DT             2gram-no-hash     0.74
# 1    French     gender       True     RF             2gram-no-hash     0.77
# 2    French     gender       True     NN             2gram-no-hash     0.79
# 3    French     gender      False     DT             2gram-no-hash     0.73
# 4    French     gender      False     RF             2gram-no-hash     0.75
# ..      ...        ...        ...    ...                       ...      ...
# 139  French  plurality       True     RF  skippy4gram-hash-at-both     0.97
# 140  French  plurality       True     NN  skippy4gram-hash-at-both     0.95
# 141  French  plurality      False     DT  skippy4gram-hash-at-both     0.91
# 142  French  plurality      False     RF  skippy4gram-hash-at-both     0.96
# 143  French  plurality      False     NN  skippy4gram-hash-at-both     0.96
#
# [144 rows x 6 columns]
# data 03
# df key: ('German', 'sample1200', 'xsk', 'mgv6', '1', '7', '8', '43')
#        lang attribute supplement method                 term_type accuracy
# 0    German    gender       True     DT             2gram-no-hash     0.53
# 1    German    gender       True     RF             2gram-no-hash     0.58
# 2    German    gender       True     NN             2gram-no-hash     0.55
# 3    German    gender      False     DT             2gram-no-hash     0.47
# 4    German    gender      False     RF             2gram-no-hash     0.56
# ..      ...       ...        ...    ...                       ...      ...
# 211  German      case       True     RF  skippy4gram-hash-at-both     0.42
# 212  German      case       True     NN  skippy4gram-hash-at-both     0.34
# 213  German      case      False     DT  skippy4gram-hash-at-both     0.34
# 214  German      case      False     RF  skippy4gram-hash-at-both     0.45
# 215  German      case      False     NN  skippy4gram-hash-at-both     0.32
#
# [216 rows x 6 columns]
# data 04
# df key: ('Czech2', 'sample1200', 'xsk', 'mgv6', '1', '10', '8', '31')
#       lang attribute supplement method                 term_type accuracy
# 0    Czech    gender       True     DT             2gram-no-hash     0.78
# 1    Czech    gender       True     RF             2gram-no-hash     0.88
# 2    Czech    gender       True     NN             2gram-no-hash     0.87
# 3    Czech    gender      False     DT             2gram-no-hash     0.60
# 4    Czech    gender      False     RF             2gram-no-hash     0.62
# ..     ...       ...        ...    ...                       ...      ...
# 211  Czech      case       True     RF  skippy4gram-hash-at-both     0.44
# 212  Czech      case       True     NN  skippy4gram-hash-at-both     0.35
# 213  Czech      case      False     DT  skippy4gram-hash-at-both     0.38
# 214  Czech      case      False     RF  skippy4gram-hash-at-both     0.41
# 215  Czech      case      False     NN  skippy4gram-hash-at-both     0.35
#
# [216 rows x 6 columns]
# data 05
# df key: ('Czech', 'sample1200', 'xsk', 'mgv6', '1', '4', '17', '4')
#       lang attribute supplement method                 term_type accuracy
# 0    Czech    gender       True     DT             2gram-no-hash     0.53
# 1    Czech    gender       True     RF             2gram-no-hash     0.66
# 2    Czech    gender       True     NN             2gram-no-hash     0.59
# 3    Czech    gender      False     DT             2gram-no-hash     0.48
# 4    Czech    gender      False     RF             2gram-no-hash     0.67
# ..     ...       ...        ...    ...                       ...      ...
# 211  Czech      case       True     RF  skippy4gram-hash-at-both     0.44
# 212  Czech      case       True     NN  skippy4gram-hash-at-both     0.31
# 213  Czech      case      False     DT  skippy4gram-hash-at-both     0.33
# 214  Czech      case      False     RF  skippy4gram-hash-at-both     0.34
# 215  Czech      case      False     NN  skippy4gram-hash-at-both     0.29
#
# [216 rows x 6 columns]

# %%
## output reconfigured dfs
reconfigure_df = True
save_files     = True
override_files = False
for d in dfx:
    key, df = d
    print(f"key: {key}")
    ## set skippy_means_extended value
    if 'xsk' in key:
        skippy_means_extended = True
    else:
        skippy_means_extended = False
    print(f"skippy_means_extended: {skippy_means_extended}")
    ## reconfigure df
    if reconfigure_df:
        df = df_reconfigure (df, skippy_means_extended = skippy_means_extended, check = False)
    print(df)

    ## save data
    if save_files:
        output_fname = f"{target_dir_path}/extracts-{'-'.join(key)}.csv"
        print(f"output_name: {output_fname}")
        try:
            import os
            if os.path.exists(output_fname):
                if override_files:
                    df.to_csv(output_fname, index = False)
                else:
                    pass
            else:
                df.to_csv(output_fname, index = False)
        except AttributeError:
            pass
# Out:
# key: ('Czech2', 'sample1200', 'xsk', 'mgv6', '1', '9', '8', '57')
# skippy_means_extended: True
# lang_name: {'Czech'}
# attribute: plurality
# attribute: gender
# attribute: case
#     lang  attribute supplement method 2gram-no-hash 3gram-no-hash  \
# 0  Czech  plurality      False     RF          0.81          0.87
# 0  Czech  plurality      False     NN          0.76          0.78
# 0  Czech  plurality      False     DT          0.80          0.83
# 0  Czech  plurality       True     RF          0.86          0.93
# 0  Czech  plurality       True     NN          0.82          0.87
# 0  Czech  plurality       True     DT          0.85          0.89
# 0  Czech     gender      False     RF          0.75          0.70
# 0  Czech     gender      False     NN          0.72          0.61
# 0  Czech     gender      False     DT          0.63          0.61
# 0  Czech     gender       True     RF          0.90          0.92
# 0  Czech     gender       True     NN          0.94          0.91
# 0  Czech     gender       True     DT          0.88          0.88
# 0  Czech       case      False     RF          0.37          0.46
# 0  Czech       case      False     NN          0.36          0.29
# 0  Czech       case      False     DT          0.36          0.37
# 0  Czech       case       True     RF          0.45          0.56
# 0  Czech       case       True     NN          0.40          0.37
# 0  Czech       case       True     DT          0.37          0.41
#
#   4gram-no-hash xsk2gram-no-hash xsk3gram-no-hash xsk4gram-no-hash  \
# 0          0.79             0.82             0.86             0.82
# 0          0.78             0.76             0.85             0.82
# 0          0.78             0.82             0.77             0.80
# 0          0.81             0.82             0.85             0.82
# 0          0.82             0.82             0.81             0.84
# 0          0.84             0.82             0.76             0.77
# 0          0.69             0.68             0.69             0.63
# 0          0.68             0.67             0.66             0.67
# 0          0.58             0.56             0.50             0.57
# 0          0.91             0.87             0.88             0.89
# 0          0.88             0.84             0.79             0.72
# 0          0.74             0.75             0.55             0.66
# 0          0.41             0.44             0.41             0.44
# 0          0.32             0.36             0.36             0.42
# 0          0.44             0.42             0.39             0.35
# 0          0.47             0.47             0.50             0.50
# 0          0.39             0.36             0.39             0.45
# 0          0.41             0.43             0.37             0.41
#
#   2gram-hash-at-both 3gram-hash-at-both 4gram-hash-at-both  \
# 0               0.84               0.83               0.79
# 0               0.78               0.80               0.75
# 0               0.80               0.82               0.77
# 0               0.92               0.84               0.87
# 0               0.85               0.83               0.78
# 0               0.89               0.86               0.82
# 0               0.67               0.72               0.71
# 0               0.59               0.75               0.69
# 0               0.63               0.59               0.64
# 0               0.93               0.93               0.88
# 0               0.90               0.95               0.91
# 0               0.91               0.65               0.66
# 0               0.42               0.36               0.35
# 0               0.45               0.36               0.35
# 0               0.38               0.39               0.42
# 0               0.46               0.45               0.48
# 0               0.44               0.38               0.42
# 0               0.47               0.42               0.31
#
#   xsk2gram-hash-at-both xsk3gram-hash-at-both xsk4gram-hash-at-both
# 0                  0.88                  0.85                  0.82
# 0                  0.79                  0.80                  0.78
# 0                  0.82                  0.78                  0.73
# 0                  0.88                  0.87                  0.82
# 0                  0.81                  0.78                  0.74
# 0                  0.82                  0.80                  0.78
# 0                  0.67                  0.69                  0.57
# 0                  0.67                  0.69                  0.67
# 0                  0.57                  0.59                  0.52
# 0                  0.84                  0.84                  0.78
# 0                  0.86                  0.84                  0.80
# 0                  0.75                  0.58                  0.44
# 0                  0.37                  0.42                  0.36
# 0                  0.39                  0.36                  0.29
# 0                  0.36                  0.34                  0.37
# 0                  0.45                  0.43                  0.45
# 0                  0.42                  0.38                  0.29
# 0                  0.40                  0.42                  0.38
# output_name: results/1.2k/mgv6-xsk/extracts-Czech2-sample1200-xsk-mgv6-1-9-8-57.csv
# key: ('Irish', 'sample1200', 'xsk', 'mgv6', '1', '7', '9', '23')
# skippy_means_extended: True
# lang_name: {'Irish'}
# attribute: plurality
# attribute: gender
# attribute: case
#     lang  attribute supplement method 2gram-no-hash 3gram-no-hash  \
# 0  Irish  plurality      False     RF          0.66          0.66
# 0  Irish  plurality      False     NN          0.58          0.59
# 0  Irish  plurality      False     DT          0.66          0.67
# 0  Irish  plurality       True     RF          0.72          0.67
# 0  Irish  plurality       True     NN          0.59          0.64
# 0  Irish  plurality       True     DT          0.60          0.65
# 0  Irish     gender      False     RF          0.72          0.76
# 0  Irish     gender      False     NN          0.71          0.70
# 0  Irish     gender      False     DT          0.71          0.67
# 0  Irish     gender       True     RF          0.76          0.75
# 0  Irish     gender       True     NN          0.74          0.73
# 0  Irish     gender       True     DT          0.77          0.72
# 0  Irish       case      False     RF          0.98          0.99
# 0  Irish       case      False     NN          0.98          0.99
# 0  Irish       case      False     DT          0.98          0.94
# 0  Irish       case       True     RF          0.98          0.99
# 0  Irish       case       True     NN          0.98          0.99
# 0  Irish       case       True     DT          0.98          0.97
#
#   4gram-no-hash xsk2gram-no-hash xsk3gram-no-hash xsk4gram-no-hash  \
# 0          0.72             0.63             0.73             0.61
# 0          0.61             0.63             0.71             0.52
# 0          0.66             0.63             0.69             0.60
# 0          0.76             0.67             0.73             0.62
# 0          0.66             0.60             0.68             0.54
# 0          0.63             0.63             0.71             0.61
# 0          0.71             0.77             0.78             0.69
# 0          0.61             0.70             0.72             0.67
# 0          0.63             0.73             0.79             0.66
# 0          0.75             0.81             0.82             0.72
# 0          0.75             0.74             0.78             0.72
# 0          0.64             0.71             0.77             0.71
# 0          0.99             0.98             0.96             0.97
# 0          0.99             0.98             0.96             0.97
# 0          0.99             0.98             0.96             0.97
# 0          0.99             0.98             0.96             0.97
# 0          0.99             0.98             0.96             0.97
# 0          0.97             0.99             0.96             0.97
#
#   2gram-hash-at-both 3gram-hash-at-both 4gram-hash-at-both  \
# 0               0.59               0.70               0.68
# 0               0.55               0.66               0.58
# 0               0.59               0.69               0.68
# 0               0.63               0.68               0.68
# 0               0.71               0.61               0.63
# 0               0.64               0.65               0.66
# 0               0.68               0.83               0.75
# 0               0.60               0.74               0.71
# 0               0.68               0.79               0.69
# 0               0.71               0.77               0.81
# 0               0.66               0.75               0.71
# 0               0.75               0.76               0.77
# 0               1.00               0.99               0.96
# 0               1.00               0.99               0.96
# 0               0.97               0.99               0.96
# 0               1.00               0.99               0.96
# 0               1.00               0.99               0.96
# 0               0.98               0.97               0.94
#
#   xsk2gram-hash-at-both xsk3gram-hash-at-both xsk4gram-hash-at-both
# 0                  0.63                  0.61                  0.62
# 0                  0.61                  0.62                  0.61
# 0                  0.58                  0.61                  0.59
# 0                  0.59                  0.62                  0.64
# 0                  0.65                  0.64                  0.66
# 0                  0.59                  0.62                  0.58
# 0                  0.68                  0.72                  0.77
# 0                  0.64                  0.70                  0.74
# 0                  0.66                  0.75                  0.74
# 0                  0.73                  0.72                  0.75
# 0                  0.67                  0.74                  0.74
# 0                  0.68                  0.68                  0.77
# 0                  0.94                  0.97                  0.97
# 0                  0.94                  0.97                  0.97
# 0                  0.94                  0.97                  0.97
# 0                  0.94                  0.97                  0.97
# 0                  0.94                  0.97                  0.97
# 0                  0.94                  0.96                  0.96
# output_name: results/1.2k/mgv6-xsk/extracts-Irish-sample1200-xsk-mgv6-1-7-9-23.csv
# key: ('French', 'sample1200', 'xsk', 'mgv6', '1', '4', '19', '27')
# skippy_means_extended: True
# lang_name: {'French'}
# attribute: plurality
# attribute: gender
#      lang  attribute supplement method 2gram-no-hash 3gram-no-hash  \
# 0  French  plurality      False     RF          0.93          0.93
# 0  French  plurality      False     NN          0.93          0.93
# 0  French  plurality      False     DT          0.89          0.89
# 0  French  plurality       True     RF          0.94          0.93
# 0  French  plurality       True     NN          0.90          0.90
# 0  French  plurality       True     DT          0.93          0.93
# 0  French     gender      False     RF          0.75          0.69
# 0  French     gender      False     NN          0.78          0.71
# 0  French     gender      False     DT          0.73          0.71
# 0  French     gender       True     RF          0.77          0.71
# 0  French     gender       True     NN          0.79          0.69
# 0  French     gender       True     DT          0.74          0.66
#
#   4gram-no-hash xsk2gram-no-hash xsk3gram-no-hash xsk4gram-no-hash  \
# 0          0.91             0.93             0.95             0.90
# 0          0.93             0.94             0.93             0.93
# 0          0.86             0.94             0.88             0.86
# 0          0.92             0.93             0.94             0.89
# 0          0.93             0.94             0.93             0.95
# 0          0.86             0.88             0.94             0.82
# 0          0.81             0.78             0.76             0.84
# 0          0.74             0.77             0.78             0.78
# 0          0.73             0.68             0.63             0.76
# 0          0.80             0.79             0.78             0.83
# 0          0.74             0.78             0.75             0.75
# 0          0.81             0.66             0.68             0.74
#
#   2gram-hash-at-both 3gram-hash-at-both 4gram-hash-at-both  \
# 0               0.91               0.91               0.88
# 0               0.93               0.93               0.86
# 0               0.88               0.92               0.91
# 0               0.92               0.89               0.92
# 0               0.93               0.91               0.86
# 0               0.88               0.89               0.87
# 0               0.73               0.79               0.78
# 0               0.72               0.77               0.77
# 0               0.71               0.70               0.69
# 0               0.74               0.82               0.83
# 0               0.68               0.75               0.75
# 0               0.71               0.71               0.76
#
#   xsk2gram-hash-at-both xsk3gram-hash-at-both xsk4gram-hash-at-both
# 0                  0.97                  0.95                  0.96
# 0                  0.97                  0.97                  0.96
# 0                  0.92                  0.85                  0.91
# 0                  0.97                  0.96                  0.97
# 0                  0.99                  0.96                  0.95
# 0                  0.94                  0.87                  0.88
# 0                  0.79                  0.80                  0.68
# 0                  0.75                  0.77                  0.69
# 0                  0.63                  0.66                  0.63
# 0                  0.77                  0.80                  0.68
# 0                  0.77                  0.78                  0.71
# 0                  0.68                  0.70                  0.57
# output_name: results/1.2k/mgv6-xsk/extracts-French-sample1200-xsk-mgv6-1-4-19-27.csv
# key: ('German', 'sample1200', 'xsk', 'mgv6', '1', '7', '8', '43')
# skippy_means_extended: True
# lang_name: {'German'}
# attribute: plurality
# attribute: gender
# attribute: case
#      lang  attribute supplement method 2gram-no-hash 3gram-no-hash  \
# 0  German  plurality      False     RF          0.79          0.81
# 0  German  plurality      False     NN          0.70          0.73
# 0  German  plurality      False     DT          0.73          0.81
# 0  German  plurality       True     RF          0.86          0.87
# 0  German  plurality       True     NN          0.78          0.76
# 0  German  plurality       True     DT          0.76          0.85
# 0  German     gender      False     RF          0.56          0.49
# 0  German     gender      False     NN          0.52          0.51
# 0  German     gender      False     DT          0.47          0.45
# 0  German     gender       True     RF          0.58          0.52
# 0  German     gender       True     NN          0.55          0.54
# 0  German     gender       True     DT          0.53          0.56
# 0  German       case      False     RF          0.34          0.38
# 0  German       case      False     NN          0.39          0.32
# 0  German       case      False     DT          0.38          0.39
# 0  German       case       True     RF          0.37          0.43
# 0  German       case       True     NN          0.32          0.30
# 0  German       case       True     DT          0.27          0.37
#
#   4gram-no-hash xsk2gram-no-hash xsk3gram-no-hash xsk4gram-no-hash  \
# 0          0.84             0.81             0.79             0.78
# 0          0.80             0.78             0.78             0.81
# 0          0.82             0.78             0.78             0.83
# 0          0.86             0.82             0.83             0.78
# 0          0.85             0.77             0.75             0.86
# 0          0.78             0.78             0.75             0.80
# 0          0.53             0.55             0.49             0.49
# 0          0.51             0.52             0.48             0.50
# 0          0.45             0.49             0.45             0.45
# 0          0.56             0.60             0.45             0.50
# 0          0.48             0.51             0.43             0.49
# 0          0.49             0.47             0.47             0.39
# 0          0.46             0.31             0.39             0.42
# 0          0.40             0.38             0.35             0.29
# 0          0.37             0.34             0.36             0.33
# 0          0.50             0.29             0.42             0.46
# 0          0.37             0.33             0.31             0.34
# 0          0.40             0.33             0.35             0.44
#
#   2gram-hash-at-both 3gram-hash-at-both 4gram-hash-at-both  \
# 0               0.76               0.83               0.81
# 0               0.75               0.80               0.80
# 0               0.75               0.84               0.81
# 0               0.85               0.87               0.85
# 0               0.82               0.82               0.81
# 0               0.88               0.77               0.86
# 0               0.52               0.61               0.52
# 0               0.44               0.55               0.58
# 0               0.45               0.55               0.42
# 0               0.55               0.61               0.54
# 0               0.45               0.54               0.51
# 0               0.41               0.53               0.50
# 0               0.46               0.42               0.33
# 0               0.36               0.33               0.36
# 0               0.39               0.43               0.33
# 0               0.38               0.45               0.32
# 0               0.31               0.32               0.39
# 0               0.40               0.41               0.33
#
#   xsk2gram-hash-at-both xsk3gram-hash-at-both xsk4gram-hash-at-both
# 0                  0.80                  0.84                  0.78
# 0                  0.77                  0.79                  0.75
# 0                  0.75                  0.78                  0.78
# 0                  0.82                  0.86                  0.82
# 0                  0.79                  0.77                  0.79
# 0                  0.76                  0.72                  0.76
# 0                  0.56                  0.53                  0.52
# 0                  0.56                  0.50                  0.51
# 0                  0.47                  0.48                  0.53
# 0                  0.56                  0.50                  0.53
# 0                  0.59                  0.51                  0.53
# 0                  0.51                  0.44                  0.49
# 0                  0.38                  0.36                  0.45
# 0                  0.36                  0.35                  0.32
# 0                  0.28                  0.36                  0.34
# 0                  0.38                  0.38                  0.42
# 0                  0.36                  0.37                  0.34
# 0                  0.28                  0.34                  0.28
# output_name: results/1.2k/mgv6-xsk/extracts-German-sample1200-xsk-mgv6-1-7-8-43.csv
# key: ('Czech2', 'sample1200', 'xsk', 'mgv6', '1', '10', '8', '31')
# skippy_means_extended: True
# lang_name: {'Czech'}
# attribute: plurality
# attribute: gender
# attribute: case
#     lang  attribute supplement method 2gram-no-hash 3gram-no-hash  \
# 0  Czech  plurality      False     RF          0.75          0.88
# 0  Czech  plurality      False     NN          0.75          0.85
# 0  Czech  plurality      False     DT          0.71          0.82
# 0  Czech  plurality       True     RF          0.82          0.93
# 0  Czech  plurality       True     NN          0.80          0.87
# 0  Czech  plurality       True     DT          0.78          0.88
# 0  Czech     gender      False     RF          0.62          0.72
# 0  Czech     gender      False     NN          0.63          0.71
# 0  Czech     gender      False     DT          0.60          0.65
# 0  Czech     gender       True     RF          0.88          0.91
# 0  Czech     gender       True     NN          0.87          0.93
# 0  Czech     gender       True     DT          0.78          0.87
# 0  Czech       case      False     RF          0.49          0.34
# 0  Czech       case      False     NN          0.39          0.26
# 0  Czech       case      False     DT          0.47          0.32
# 0  Czech       case       True     RF          0.61          0.45
# 0  Czech       case       True     NN          0.39          0.32
# 0  Czech       case       True     DT          0.49          0.40
#
#   4gram-no-hash xsk2gram-no-hash xsk3gram-no-hash xsk4gram-no-hash  \
# 0          0.90             0.86             0.86             0.75
# 0          0.84             0.80             0.77             0.78
# 0          0.91             0.82             0.82             0.78
# 0          0.93             0.87             0.87             0.76
# 0          0.87             0.77             0.82             0.72
# 0          0.83             0.82             0.81             0.75
# 0          0.67             0.64             0.67             0.64
# 0          0.62             0.64             0.66             0.63
# 0          0.57             0.49             0.57             0.54
# 0          0.93             0.84             0.84             0.76
# 0          0.91             0.85             0.82             0.83
# 0          0.87             0.67             0.76             0.62
# 0          0.38             0.38             0.46             0.44
# 0          0.29             0.38             0.42             0.42
# 0          0.32             0.33             0.36             0.38
# 0          0.44             0.50             0.43             0.51
# 0          0.37             0.34             0.38             0.43
# 0          0.48             0.45             0.46             0.38
#
#   2gram-hash-at-both 3gram-hash-at-both 4gram-hash-at-both  \
# 0               0.80               0.86               0.78
# 0               0.76               0.80               0.76
# 0               0.82               0.82               0.79
# 0               0.84               0.88               0.82
# 0               0.78               0.83               0.80
# 0               0.87               0.88               0.82
# 0               0.62               0.66               0.58
# 0               0.52               0.64               0.60
# 0               0.57               0.58               0.55
# 0               0.91               0.91               0.88
# 0               0.89               0.93               0.86
# 0               0.88               0.86               0.84
# 0               0.42               0.39               0.43
# 0               0.36               0.31               0.41
# 0               0.36               0.32               0.38
# 0               0.50               0.47               0.57
# 0               0.45               0.31               0.44
# 0               0.40               0.44               0.44
#
#   xsk2gram-hash-at-both xsk3gram-hash-at-both xsk4gram-hash-at-both
# 0                  0.86                  0.84                  0.79
# 0                  0.82                  0.83                  0.79
# 0                  0.81                  0.83                  0.79
# 0                  0.88                  0.85                  0.79
# 0                  0.84                  0.80                  0.76
# 0                  0.88                  0.76                  0.78
# 0                  0.70                  0.63                  0.54
# 0                  0.70                  0.62                  0.64
# 0                  0.55                  0.56                  0.45
# 0                  0.93                  0.81                  0.78
# 0                  0.87                  0.78                  0.74
# 0                  0.88                  0.53                  0.43
# 0                  0.37                  0.47                  0.41
# 0                  0.38                  0.45                  0.35
# 0                  0.29                  0.35                  0.38
# 0                  0.47                  0.47                  0.44
# 0                  0.38                  0.40                  0.35
# 0                  0.44                  0.41                  0.39
# output_name: results/1.2k/mgv6-xsk/extracts-Czech2-sample1200-xsk-mgv6-1-10-8-31.csv
# key: ('Czech', 'sample1200', 'xsk', 'mgv6', '1', '4', '17', '4')
# skippy_means_extended: True
# lang_name: {'Czech'}
# attribute: plurality
# attribute: gender
# attribute: case
#     lang  attribute supplement method 2gram-no-hash 3gram-no-hash  \
# 0  Czech  plurality      False     RF          0.78          0.89
# 0  Czech  plurality      False     NN          0.78          0.85
# 0  Czech  plurality      False     DT          0.82          0.83
# 0  Czech  plurality       True     RF          0.89          0.92
# 0  Czech  plurality       True     NN          0.82          0.88
# 0  Czech  plurality       True     DT          0.86          0.86
# 0  Czech     gender      False     RF          0.67          0.60
# 0  Czech     gender      False     NN          0.60          0.57
# 0  Czech     gender      False     DT          0.48          0.54
# 0  Czech     gender       True     RF          0.66          0.64
# 0  Czech     gender       True     NN          0.59          0.56
# 0  Czech     gender       True     DT          0.53          0.45
# 0  Czech       case      False     RF          0.37          0.48
# 0  Czech       case      False     NN          0.26          0.41
# 0  Czech       case      False     DT          0.36          0.43
# 0  Czech       case       True     RF          0.39          0.50
# 0  Czech       case       True     NN          0.44          0.38
# 0  Czech       case       True     DT          0.43          0.45
#
#   4gram-no-hash xsk2gram-no-hash xsk3gram-no-hash xsk4gram-no-hash  \
# 0          0.76             0.87             0.83             0.88
# 0          0.75             0.78             0.77             0.84
# 0          0.77             0.78             0.79             0.82
# 0          0.80             0.90             0.81             0.88
# 0          0.82             0.83             0.75             0.82
# 0          0.76             0.74             0.77             0.81
# 0          0.57             0.57             0.53             0.53
# 0          0.61             0.59             0.60             0.51
# 0          0.47             0.42             0.34             0.42
# 0          0.56             0.63             0.57             0.60
# 0          0.53             0.61             0.61             0.59
# 0          0.51             0.53             0.40             0.38
# 0          0.39             0.41             0.38             0.42
# 0          0.30             0.30             0.30             0.32
# 0          0.40             0.24             0.29             0.34
# 0          0.53             0.44             0.43             0.46
# 0          0.34             0.37             0.34             0.41
# 0          0.41             0.32             0.32             0.48
#
#   2gram-hash-at-both 3gram-hash-at-both 4gram-hash-at-both  \
# 0               0.82               0.78               0.84
# 0               0.77               0.68               0.72
# 0               0.72               0.75               0.82
# 0               0.82               0.82               0.85
# 0               0.82               0.72               0.84
# 0               0.82               0.82               0.97
# 0               0.61               0.62               0.53
# 0               0.55               0.57               0.61
# 0               0.52               0.53               0.45
# 0               0.59               0.65               0.59
# 0               0.57               0.58               0.62
# 0               0.45               0.51               0.49
# 0               0.41               0.47               0.41
# 0               0.35               0.41               0.31
# 0               0.36               0.47               0.34
# 0               0.52               0.52               0.47
# 0               0.41               0.46               0.36
# 0               0.51               0.43               0.42
#
#   xsk2gram-hash-at-both xsk3gram-hash-at-both xsk4gram-hash-at-both
# 0                  0.87                  0.75                  0.77
# 0                  0.81                  0.79                  0.75
# 0                  0.81                  0.75                  0.72
# 0                  0.89                  0.78                  0.79
# 0                  0.87                  0.80                  0.75
# 0                  0.86                  0.79                  0.72
# 0                  0.67                  0.55                  0.57
# 0                  0.62                  0.61                  0.57
# 0                  0.56                  0.47                  0.44
# 0                  0.59                  0.57                  0.55
# 0                  0.62                  0.68                  0.54
# 0                  0.53                  0.51                  0.45
# 0                  0.36                  0.44                  0.34
# 0                  0.35                  0.41                  0.29
# 0                  0.36                  0.31                  0.33
# 0                  0.39                  0.50                  0.44
# 0                  0.44                  0.39                  0.31
# 0                  0.35                  0.38                  0.38
# output_name: results/1.2k/mgv6-xsk/extracts-Czech-sample1200-xsk-mgv6-1-4-17-4.csv
