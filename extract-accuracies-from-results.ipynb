# %% [markdown]
# # Python script that extracts accuracy values from results
#
# developed by Kow Kuroda

# %%
## extract values
import io, re
import pprint as pp
method_names = [ 'DT', 'RF', 'NN', 'MM' ]
attr_names   = [ 'case', 'gender', 'gender2', 'plurality' ]
trueness     = [ 'True]', 'False]' ]
max_n_for_ngram = 4
lang_names   = [ 'Czech', 'Czech2', 'French', 'German', 'Irish' ]
term_names   = [ f"{x}{y}gram{z}" for x in [ '', 'skippy', 'xskippy' ]
                                    for y in range(2, max_n_for_ngram + 1)
                                    for z in ['-no-hash', '-hash-at-both'] ]
pp.pprint(f"term_names: {term_names}")

## define registered vals
registered_vars = method_names + lang_names + attr_names + trueness + term_names
pp.pprint(f"registered_vars: {registered_vars}")

# %%
def extract_lines (lines, check: bool = False):
    import re
    lines = [ line.strip() for line in lines if len(line.strip()) > 0 ]
    extracts  = [ ]
    for i, line in enumerate(lines):
        fields = re.split(r"\s\s*", line)
        if check:
            print(f"fields raw: {fields}")
        ## define value
        if fields[0] in method_names:
            method_line = fields
        elif fields[0] in [ 'accuracy' ]:
            accuracy_val = fields[-2]
            ##
            value = (method_line, accuracy_val)
            if check:
                print(f"value {i:02d}: {value}")
            extracts.append(value)
    ##
    if check:
        print(f"values: {extracts}")
    return extracts

# %%
def parse_values (extracts, registered: list, check: bool = False):
    import re
    parsed = [ ]
    for extract in extracts:
        if check:
            print(f"extract: {extract}")
        ## define method, accuracy
        method, accuracy = extract
        if check:
            print(f"method: {method}")
            print(f"accuracy: {accuracy}")
        #
        F = [ field for field in method if field in registered ]
        F = [ 'NN' if x == 'MM' else x for x in F ]
        F = [ 'True' if x == 'True]' else x for x in F ]
        F = [ 'False' if x == 'False]' else x for x in F ]
        F.append(accuracy)
        parsed.append(F)
    ##
    if check:
        print(f"parsed: {parsed}")
    return parsed

# %%
## extract values and create df
def process_files (files, registered_vars, check: bool = True):
    import pandas as pd
    dfs = [ ]
    for i, file in enumerate(files):
        print(f"opening file {i:02d} {file}")
        ##
        with io.open(file, encoding = 'utf-8_sig') as f:
            lines = [ line.strip() for line in f.readlines() if len(line) > 0 ]
            if not len(lines) > 1:
                continue
            records = parse_values (extract_lines (lines, check = False), registered_vars, check = False)
        ##
        if check:
            print(f"records raw: {records}")
        ##
        records_parsed = [ ]
        last_term_name = ""
        for i, record in enumerate(records):
            print(f"record {i:03d}: {record} [type: {type(record)}]")
            if len(record) == 6:
                print(f"found valid record")
                print(record)
                records_parsed.append(record)
                last_lang_name = [ x for x in record if x in lang_names ][0]
                last_term_name = [ x for x in record if x in term_names ][0]
            elif len(record) < 6:
                print(f"found invalid record to modify")
                print(record)
                lang_present = any(map(lambda x: x in record, lang_names))
                print(f"lang_present: {lang_present}")
                if not lang_present:
                    record.insert(3, last_lang_name)
                term_present = any(map(lambda x: x in record, term_names))
                print(f"term_present: {term_present}")
                if not term_present:
                    record.insert(4, last_term_name)
                print(f"modified {i:03d} to:\n{record} [type: {type(record)}]")
                records_parsed.append(record)
            else:
                raise ValueError
        ##
        df = pd.DataFrame(columns = [ 'lang', 'attribute', 'supplement', 'method', 'term_type', 'accuracy'])
        ## parse records
        for i, record in enumerate(records_parsed):
            print(f"record {i:03d}: {record}")
            ## classify method line
            if len(record) == 6:
                if record[1] in lang_names:
                    method, lang, attr, supplement, term, accuracy = record
                else:
                    method, attr, supplement, lang, term, accuracy = record
                last_attr = attr
            elif len(record) == 5:
                if record[1] in lang_names:
                    if record[2] in [True, False]:
                        method, supplement, lang, term, accuracy = record
                    else:
                        method, lang, supplement, term, accuracy = record
                elif record[2] in lang_names:
                    method, supplement, lang, term, accuracy = record
                else:
                    method, supplement, term, lang, accuracy = record
                attr = last_attr
            else:
                raise "ParseError"
            #
            df.loc[i] = [lang, attr, supplement, method, term, accuracy]
        
        ## handle file name
        fn_fields = re.split(r"[-]", re.split(r"/", file)[-1]) # split by "/" first
        print(f"fn_fields: {fn_fields}")
        ## parse file name
        if any(term_key in fn_fields for term_key in [ 'sk', 'xsk' ]):
            _, lang, sample, term_setting, mgv, *other = fn_fields
        else:
            _, lang, sample, mgv, year, *other = fn_fields
            term_setting = "X"
        other = [ x.strip(".txt") for x in other ]
        ## parse date
        if check:
            print(f"other: {other}")
        if len(other) == 3:
            month, day, hour = other 
            year = str(2024)
            minute = str(0)
        elif len(other) == 4:
            year, month, day, hour = other 
            minute = str(0)
        elif len(other) == 5:
            year, month, day, hour, minute = other
        elif len(other) > 5:
            year, month, day, hour, minute, *_ = other
        else:
            year, month, day, hour = other
        ## define record
        fn_key = (lang, sample, term_setting, mgv, month, day, hour, minute)
        print(f"fn_key0: {fn_key}")
        if "txt" == fn_key[-1]:
            fn_key = fn_key[:-1] 
        if fn_key[0] == '':
            fn_key = fn_key[1:]
        print(f"fn_key1: {fn_key}")
        dfs.append((fn_key, df))
    ##
    return dfs

# %%
## reconfigure df
attribute_map = { "case": 3, "gender": 2, "gender2": 2, "plurality": 1 }
method_map    = { "DT": 1, "RF": 2, "NN": 3, "MN": 3 }
import pandas as pd
def df_reconfigure (df, df_key, check_attribute_n: bool = True, add_index_columns: bool = True, check: bool = False):
    ## set skippy_means_extended value
    if 'xsk' in df_key:
        skippy_means_extended = True
    else:
        skippy_means_extended = False
    print(f"skippy_means_extended: {skippy_means_extended}")
    ## check attributes
    import re
    attributes = sorted (set(df['attribute']), reverse = True)
    if check:
        print(attributes)
    if check_attribute_n:
        lang_name = set(df['lang'])
        print(f"lang_name: {lang_name}")
        if lang_name in ['Czech', 'Czech2', 'German', 'Irish'] and len(attributes) != 3:
            print(f"ignored input df")
            return
        elif lang_name in [ 'French' ] and len(attributes) != 2:
            print(f"ignored input df")
            return
    ##
    leader_vars = ['lang', 'attribute', 'supplement', 'method']
    dfs_attributes = [ ]
    for attribute in attributes:
        print(f"attribute: {attribute}")
        df_attr = df[df['attribute'] == attribute]
        if check:
            print(df_attr)
        ##
        dfs_suppl = [ ]
        supplements = set(df_attr['supplement'])
        for supplement in supplements:
            print(f"supplement: {supplement}")
            df_suppl = df_attr[df_attr['supplement'] == supplement]
            suppl_leader_vals = df_suppl[leader_vars].iloc[0,:].T
            ## method
            dfs_method = [ ]
            methods = set(df_attr['method'])
            for method in methods:
                if check:
                    print(f"method: {method}")
                method_group = [ ]
                df_method = df_suppl[df_suppl['method'] == method]
                
                # define vars
                term_types = df_method['term_type']
                #print(f"len(term_types): {len(term_types)}")
                ## rename skippy to xskippy if necessary
                skippy_term_types = list(set([ t for t in term_types if "skippy" in t ]))
                if any(re.match('xskippy.*', t) for t in skippy_term_types):
                    pass
                else:
                    if skippy_means_extended:
                        term_types = [ re.sub('skippy', 'xskippy', t) for t in term_types ]
                ## simplify term_type names
                term_types = [ re.sub('skippy', 'sk', t) for t in term_types ]
                term_types = [ re.sub('gram', 'g', t) for t in term_types ]
                vars = leader_vars + list(term_types) # Crucially, list(term_types)
                
                # define leader_vals
                suppl_leader_vals = df_method[leader_vars].iloc[0,:].T
                method_group.extend(suppl_leader_vals)
                
                # define values
                values     = df_method['accuracy']
                method_group.extend(values)
                if check:
                    print(f"method_grouped: {method_group}")
                
                # define df
                temp_df = pd.DataFrame(columns = vars)
                temp_df.loc[0,:] = method_group
                #temp_df = temp_df.drop_duplicates()
                if check:
                    print(f"temp_df: {temp_df}")
                dfs_method.append(temp_df)
            ##
            merged_df_method = pd.concat(dfs_method)
            if check:
                print(f"merged_df_method: {merged_df_method}")
            # update dfs_suppl
            dfs_suppl.append(merged_df_method)
        # update dfs_attributes
        dfs_attributes.extend(dfs_suppl)
    ##
    if add_index_columns:
        xdf = pd.concat(dfs_attributes)
        xdf.insert(1, "attribute.index", xdf['attribute'].apply(lambda x: attribute_map[x]))
        xdf.insert(4, "method.index", xdf['method'].apply(lambda x: method_map[x]))
        xdf.insert(len(xdf.columns), "max", None)
        xdf = xdf.sort_values(by = ['method.index'], ascending = True)
        xdf = xdf.sort_values(by = ['supplement'], ascending = False)
        xdf = xdf.sort_values(by = ['attribute.index'], ascending = True)
        return xdf
    else:
        return pd.concat(dfs_attributes)

# %% [markdown]
# # main

# %%
## select files
import glob
import pprint as pp

## set target files
use_Morfessor = True
if use_Morfessor:
    target_dir_root  = "results-Morfessor"
    target_subdir    = "ml4.0"
    target_dir_path  = f"{target_dir_root}/{target_subdir}/2k"
else:
    target_dir_root  = "results"
    target_subdir    = "xsk/3k/mgv3-xsk"
    target_dir_path  = f"{target_dir_root}/{target_subdir}"
files = glob.glob(f"{target_dir_path}/*")
#pprint.pprint(files)

## filter files
import re
filter_by_sample_n = False
lang_name = ""
if filter_by_sample_n:
    sample_n = 2000
    data_files = [ file for file in files if re.match(f".*result-{lang_name}.*{sample_n}.*.txt", file) ]
else:
    data_files = [ file for file in files if re.match(f".*result-{lang_name}.*.txt", file) ]
pp.pprint(data_files)

# %%
## process files
dfx = process_files (data_files, registered_vars, check = False)
for i, data in enumerate(dfx):
    print(f"data {i+1:02d}")
    key, df = data
    print(f"df key: {key}")
    print(df)

# %%
## reconfigure dfs and output
reconfigure_df = True
save_files     = True
override_files = True
from pandas.errors import InvalidIndexError
for i, d in enumerate(dfx):
    df_key, df = d
    print(f"d {i:02d}")
    print(f"df_key: {df_key}")
    ## reconfigure df
    if reconfigure_df:
        try:
            df2 = df_reconfigure (df, df_key, check = False)
            print(df2)
        except InvalidIndexError:
            df2 = None
    else:
        df2 = df

    ## save data
    if save_files:
        if not df2 is None:
            if reconfigure_df:
                output_fname = f"{target_dir_path}/x-{'-'.join(df_key)}.csv"
            else:
                output_fname = f"{target_dir_path}/raw-x-{'-'.join(df_key)}.csv"    
            print(f"output_name: {output_fname}")
            try:
                import os
                if os.path.exists(output_fname):
                    if override_files:
                        df2.to_csv(output_fname, index = False)
                        print(f"file generated")
                    else:
                        pass
                else:
                    df2.to_csv(output_fname, index = False)
                    print(f"file generated")
            except AttributeError:
                #pass
                print(f"AttributionError occurred")
                print(f"failed to generate {output_fname}")
