# %% [markdown]
# # Python script that extracts accuracy values from results
#
# developed by Kow Kuroda

# %%
## select files
import glob
import pprint as pp

## set target files
use_Morfessor = False
if use_Morfessor:
    target_dir_root  = "results-Morfessor"
    target_subdir    = "ml3.0"
    target_dir_path  = f"{target_dir_root}/{target_subdir}/3k"
else:
    target_dir_root  = "results"
    target_subdir    = "3k/mgv3-xsk"
    target_dir_path  = f"{target_dir_root}/{target_subdir}"
files = glob.glob(f"{target_dir_path}/*")
#pprint.pprint(files)

## filter files
import re
filter_by_sample_n = False
lang_name = ""
if filter_by_sample_n:
    sample_n = 2000
    data_files = [ file for file in files if re.match(f".*result-{lang_name}.*{sample_n}.*.txt", file) ]
else:
    data_files = [ file for file in files if re.match(f".*result-{lang_name}.*.txt", file) ]
pp.pprint(data_files)
# Out:
# ['results/3k/mgv3-xsk/result-German-sample3000-xsk-mgv3-2025-2-20-22-11.txt',
#  'results/3k/mgv3-xsk/result-Irish-sample3000-xsk-mgv3-2025-2-21-4-35.txt',
#  'results/3k/mgv3-xsk/result-Czech-sample3000-xsk-mgv3-2025-2-20-20-35.txt',
#  'results/3k/mgv3-xsk/result-French-sample3000-xsk-mgv3-2025-2-20-21-31.txt',
#  'results/3k/mgv3-xsk/result-Czech2-3000-xsk-mgv3-2025-3-3-12-48.txt']

# %%
## extract values
import io, re
import pprint as pp
method_names = [ 'DT', 'RF', 'NN', 'MM' ]
attr_names   = [ 'case', 'gender', 'gender2', 'plurality' ]
trueness     = [ 'True]', 'False]' ]
max_n_for_ngram = 4
lang_names   = [ 'Czech', 'Czech2', 'French', 'German', 'Irish' ]
term_names   = [ f"{x}{y}gram{z}" for x in [ '', 'skippy', 'xskippy' ]
                                    for y in range(2, max_n_for_ngram + 1)
                                    for z in ['-no-hash', '-hash-at-both'] ]
pp.pprint(f"term_names: {term_names}")

## define registered vals
registered_vars = method_names + lang_names + attr_names + trueness + term_names
pp.pprint(f"registered_vars: {registered_vars}")
# Out:
# ("term_names: ['2gram-no-hash', '2gram-hash-at-both', '3gram-no-hash', "
#  "'3gram-hash-at-both', '4gram-no-hash', '4gram-hash-at-both', "
#  "'skippy2gram-no-hash', 'skippy2gram-hash-at-both', 'skippy3gram-no-hash', "
#  "'skippy3gram-hash-at-both', 'skippy4gram-no-hash', "
#  "'skippy4gram-hash-at-both', 'xskippy2gram-no-hash', "
#  "'xskippy2gram-hash-at-both', 'xskippy3gram-no-hash', "
#  "'xskippy3gram-hash-at-both', 'xskippy4gram-no-hash', "
#  "'xskippy4gram-hash-at-both']")
# ("registered_vars: ['DT', 'RF', 'NN', 'MM', 'Czech', 'Czech2', 'French', "
#  "'German', 'Irish', 'case', 'gender', 'gender2', 'plurality', 'True]', "
#  "'False]', '2gram-no-hash', '2gram-hash-at-both', '3gram-no-hash', "
#  "'3gram-hash-at-both', '4gram-no-hash', '4gram-hash-at-both', "
#  "'skippy2gram-no-hash', 'skippy2gram-hash-at-both', 'skippy3gram-no-hash', "
#  "'skippy3gram-hash-at-both', 'skippy4gram-no-hash', "
#  "'skippy4gram-hash-at-both', 'xskippy2gram-no-hash', "
#  "'xskippy2gram-hash-at-both', 'xskippy3gram-no-hash', "
#  "'xskippy3gram-hash-at-both', 'xskippy4gram-no-hash', "
#  "'xskippy4gram-hash-at-both']")

# %%
def extract_lines (lines, check: bool = False):
    import re
    lines = [ line.strip() for line in lines if len(line.strip()) > 0 ]
    extracts  = [ ]
    for i, line in enumerate(lines):
        fields = re.split(r"\s\s*", line)
        if check:
            print(f"fields raw: {fields}")
        ## define value
        if fields[0] in method_names:
            method_line = fields
        elif fields[0] in [ 'accuracy' ]:
            accuracy_val = fields[-2]
            ##
            value = (method_line, accuracy_val)
            if check:
                print(f"value {i:02d}: {value}")
            extracts.append(value)
    ##
    if check:
        print(f"values: {extracts}")
    return extracts

# %%
def parse_values (extracts, registered: list, check: bool = False):
    import re
    parsed = [ ]
    for extract in extracts:
        if check:
            print(f"extract: {extract}")
        ## define method, accuracy
        method, accuracy = extract
        if check:
            print(f"method: {method}")
            print(f"accuracy: {accuracy}")
        #
        F = [ field for field in method if field in registered ]
        F = [ 'NN' if x == 'MM' else x for x in F ]
        F = [ 'True' if x == 'True]' else x for x in F ]
        F = [ 'False' if x == 'False]' else x for x in F ]
        F.append(accuracy)
        parsed.append(F)
    ##
    if check:
        print(f"parsed: {parsed}")
    return parsed

# %%
## extract values and create df
def process_files (files, registered_vars, check: bool = True):
    import pandas as pd
    dfs = [ ]
    for i, file in enumerate(files):
        print(f"opening file {i:02d} {file}")
        ##
        with io.open(file, encoding = 'utf-8_sig') as f:
            lines = [ line.strip() for line in f.readlines() if len(line) > 0 ]
            if not len(lines) > 1:
                continue
            records = parse_values (extract_lines (lines, check = False), registered_vars, check = False)
        ##
        if check:
            print(f"records raw: {records}")
        ##
        records_parsed = [ ]
        for i, record in enumerate(records):
            print(f"record {i:03d}: {record} [type: {type(record)}]")
            if len(record) == 6:
                print(f"found valid record")
                print(record)
                records_parsed.append(record)
                last_lang_name = [ x for x in record if x in lang_names ][0]
                last_term_name = [ x for x in record if x in term_names ][0]
            elif len(record) < 6:
                print(f"found invalid record to modify")
                print(record)
                lang_present = any(map(lambda x: x in record, lang_names))
                print(f"lang_present: {lang_present}")
                if not lang_present:
                    record.insert(3, last_lang_name)
                term_present = any(map(lambda x: x in record, term_names))
                print(f"term_present: {term_present}")
                if not term_present:
                    record.insert(4, last_term_name)
                print(f"modified {i:03d} to:\n{record} [type: {type(record)}]")
                records_parsed.append(record)
            else:
                raise ValueError
        ##
        df = pd.DataFrame(columns = [ 'lang', 'attribute', 'supplement', 'method', 'term_type', 'accuracy'])
        ## parse records
        for i, record in enumerate(records_parsed):
            print(f"record {i:03d}: {record}")
            ## classify method line
            if len(record) == 6:
                if record[1] in lang_names:
                    method, lang, attr, supplement, term, accuracy = record
                else:
                    method, attr, supplement, lang, term, accuracy = record
                last_attr = attr
            elif len(record) == 5:
                if record[1] in lang_names:
                    if record[2] in [True, False]:
                        method, supplement, lang, term, accuracy = record
                    else:
                        method, lang, supplement, term, accuracy = record
                elif record[2] in lang_names:
                    method, supplement, lang, term, accuracy = record
                else:
                    method, supplement, term, lang, accuracy = record
                attr = last_attr
            else:
                raise "ParseError"
            #
            df.loc[i] = [lang, attr, supplement, method, term, accuracy]
        
        ## handle file name
        fn_fields = re.split(r"[-]", re.split(r"/", file)[-1]) # split by "/" first
        print(f"fn_fields: {fn_fields}")
        ## parse file name
        if any(term_key in fn_fields for term_key in [ 'sk', 'xsk' ]):
            _, lang, sample, term_setting, mgv, *other = fn_fields
        else:
            _, lang, sample, mgv, year, *other = fn_fields
            term_setting = "X"
        other = [ x.strip(".txt") for x in other ]
        ## parse date
        if check:
            print(f"other: {other}")
        if len(other) == 3:
            month, day, hour = other 
            year = str(2024)
            minute = str(0)
        elif len(other) == 4:
            year, month, day, hour = other 
            minute = str(0)
        elif len(other) == 5:
            year, month, day, hour, minute = other
        elif len(other) > 5:
            year, month, day, hour, minute, *_ = other
        else:
            year, month, day, hour = other
        ## define record
        fn_key = (lang, sample, term_setting, mgv, month, day, hour, minute)
        print(f"fn_key0: {fn_key}")
        if "txt" == fn_key[-1]:
            fn_key = fn_key[:-1] 
        if fn_key[0] == '':
            fn_key = fn_key[1:]
        print(f"fn_key1: {fn_key}")
        dfs.append((fn_key, df))
    ##
    return dfs

# %%
## reconfigure df
attribute_map = { "case": 3, "gender": 2, "gender2": 2, "plurality": 1 }
method_map    = { "DT": 1, "RF": 2, "NN": 3, "MN": 3 }
import pandas as pd
def df_reconfigure (df, df_key, check_attribute_n: bool = True, add_index_columns: bool = True, check: bool = False):
    ## set skippy_means_extended value
    if 'xsk' in df_key:
        skippy_means_extended = True
    else:
        skippy_means_extended = False
    print(f"skippy_means_extended: {skippy_means_extended}")
    ## check attributes
    import re
    attributes = sorted (set(df['attribute']), reverse = True)
    if check:
        print(attributes)
    if check_attribute_n:
        lang_name = set(df['lang'])
        print(f"lang_name: {lang_name}")
        if lang_name in ['Czech', 'Czech2', 'German', 'Irish'] and len(attributes) != 3:
            print(f"ignored input df")
            return
        elif lang_name in [ 'French' ] and len(attributes) != 2:
            print(f"ignored input df")
            return
    ##
    leader_vars = ['lang', 'attribute', 'supplement', 'method']
    dfs_attributes = [ ]
    for attribute in attributes:
        print(f"attribute: {attribute}")
        df_attr = df[df['attribute'] == attribute]
        if check:
            print(df_attr)
        ##
        dfs_suppl = [ ]
        supplements = set(df_attr['supplement'])
        for supplement in supplements:
            print(f"supplement: {supplement}")
            df_suppl = df_attr[df_attr['supplement'] == supplement]
            suppl_leader_vals = df_suppl[leader_vars].iloc[0,:].T
            ## method
            dfs_method = [ ]
            methods = set(df_attr['method'])
            for method in methods:
                if check:
                    print(f"method: {method}")
                method_group = [ ]
                df_method = df_suppl[df_suppl['method'] == method]
                
                # define vars
                term_types = df_method['term_type']
                #print(f"len(term_types): {len(term_types)}")
                ## rename skippy to xskippy if necessary
                skippy_term_types = list(set([ t for t in term_types if "skippy" in t ]))
                if any(re.match('xskippy.*', t) for t in skippy_term_types):
                    pass
                else:
                    if skippy_means_extended:
                        term_types = [ re.sub('skippy', 'xskippy', t) for t in term_types ]
                ## simplify term_type names
                term_types = [ re.sub('skippy', 'sk', t) for t in term_types ]
                term_types = [ re.sub('gram', 'g', t) for t in term_types ]
                vars = leader_vars + list(term_types) # Crucially, list(term_types)
                
                # define leader_vals
                suppl_leader_vals = df_method[leader_vars].iloc[0,:].T
                method_group.extend(suppl_leader_vals)
                
                # define values
                values     = df_method['accuracy']
                method_group.extend(values)
                if check:
                    print(f"method_grouped: {method_group}")
                
                # define df
                temp_df = pd.DataFrame(columns = vars)
                temp_df.loc[0,:] = method_group
                #temp_df = temp_df.drop_duplicates()
                if check:
                    print(f"temp_df: {temp_df}")
                dfs_method.append(temp_df)
            ##
            merged_df_method = pd.concat(dfs_method)
            if check:
                print(f"merged_df_method: {merged_df_method}")
            # update dfs_suppl
            dfs_suppl.append(merged_df_method)
        # update dfs_attributes
        dfs_attributes.extend(dfs_suppl)
    ##
    if add_index_columns:
        xdf = pd.concat(dfs_attributes)
        xdf.insert(1, "attribute.index", xdf['attribute'].apply(lambda x: attribute_map[x]))
        xdf.insert(4, "method.index", xdf['method'].apply(lambda x: method_map[x]))
        xdf.insert(len(xdf.columns), "max", None)
        xdf = xdf.sort_values(by = ['method.index'], ascending = True)
        xdf = xdf.sort_values(by = ['supplement'], ascending = False)
        xdf = xdf.sort_values(by = ['attribute.index'], ascending = True)
        return xdf
    else:
        return pd.concat(dfs_attributes)

# %%
## main
dfx = process_files (data_files, registered_vars, check = False)
for i, data in enumerate(dfx):
    print(f"data {i+1:02d}")
    key, df = data
    print(f"df key: {key}")
    print(df)
# Out:
# opening file 00 results/3k/mgv3-xsk/result-German-sample3000-xsk-mgv3-2025-2-20-22-11.txt
# record 000: ['DT', 'gender', 'True', 'German', '2gram-no-hash', '0.55'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'True', 'German', '2gram-no-hash', '0.55']
# record 001: ['RF', 'gender', 'True', '2gram-no-hash', '0.63'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'True', '2gram-no-hash', '0.63']
# lang_present: False
# term_present: True
# modified 001 to:
# ['RF', 'gender', 'True', 'German', '2gram-no-hash', '0.63'] [type: <class 'list'>]
# record 002: ['NN', 'gender', 'True', 'German', '2gram-no-hash', '0.55'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'German', '2gram-no-hash', '0.55']
# record 003: ['DT', 'gender', 'False', 'German', '2gram-no-hash', '0.51'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'False', 'German', '2gram-no-hash', '0.51']
# record 004: ['RF', 'gender', 'False', '2gram-no-hash', '0.59'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'False', '2gram-no-hash', '0.59']
# lang_present: False
# term_present: True
# modified 004 to:
# ['RF', 'gender', 'False', 'German', '2gram-no-hash', '0.59'] [type: <class 'list'>]
# record 005: ['NN', 'gender', 'False', 'German', '2gram-no-hash', '0.54'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'German', '2gram-no-hash', '0.54']
# record 006: ['DT', 'plurality', 'True', 'German', '2gram-no-hash', '0.75'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'True', 'German', '2gram-no-hash', '0.75']
# record 007: ['RF', 'plurality', 'True', '2gram-no-hash', '0.85'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'True', '2gram-no-hash', '0.85']
# lang_present: False
# term_present: True
# modified 007 to:
# ['RF', 'plurality', 'True', 'German', '2gram-no-hash', '0.85'] [type: <class 'list'>]
# record 008: ['NN', 'plurality', 'True', 'German', '2gram-no-hash', '0.84'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'German', '2gram-no-hash', '0.84']
# record 009: ['DT', 'plurality', 'False', 'German', '2gram-no-hash', '0.79'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'False', 'German', '2gram-no-hash', '0.79']
# record 010: ['RF', 'plurality', 'False', '2gram-no-hash', '0.80'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'False', '2gram-no-hash', '0.80']
# lang_present: False
# term_present: True
# modified 010 to:
# ['RF', 'plurality', 'False', 'German', '2gram-no-hash', '0.80'] [type: <class 'list'>]
# record 011: ['NN', 'plurality', 'False', 'German', '2gram-no-hash', '0.81'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'German', '2gram-no-hash', '0.81']
# record 012: ['DT', 'case', 'True', 'German', '2gram-no-hash', '0.34'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'True', 'German', '2gram-no-hash', '0.34']
# record 013: ['RF', 'case', 'True', '2gram-no-hash', '0.44'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'True', '2gram-no-hash', '0.44']
# lang_present: False
# term_present: True
# modified 013 to:
# ['RF', 'case', 'True', 'German', '2gram-no-hash', '0.44'] [type: <class 'list'>]
# record 014: ['NN', 'case', 'True', 'German', '2gram-no-hash', '0.34'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'German', '2gram-no-hash', '0.34']
# record 015: ['DT', 'case', 'False', 'German', '2gram-no-hash', '0.35'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'False', 'German', '2gram-no-hash', '0.35']
# record 016: ['RF', 'case', 'False', '2gram-no-hash', '0.40'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'False', '2gram-no-hash', '0.40']
# lang_present: False
# term_present: True
# modified 016 to:
# ['RF', 'case', 'False', 'German', '2gram-no-hash', '0.40'] [type: <class 'list'>]
# record 017: ['NN', 'case', 'False', 'German', '2gram-no-hash', '0.35'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'German', '2gram-no-hash', '0.35']
# record 018: ['DT', 'gender', 'True', 'German', '3gram-no-hash', '0.53'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'True', 'German', '3gram-no-hash', '0.53']
# record 019: ['RF', 'gender', 'True', '3gram-no-hash', '0.61'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'True', '3gram-no-hash', '0.61']
# lang_present: False
# term_present: True
# modified 019 to:
# ['RF', 'gender', 'True', 'German', '3gram-no-hash', '0.61'] [type: <class 'list'>]
# record 020: ['NN', 'gender', 'True', 'German', '3gram-no-hash', '0.59'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'German', '3gram-no-hash', '0.59']
# record 021: ['DT', 'gender', 'False', 'German', '3gram-no-hash', '0.55'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'False', 'German', '3gram-no-hash', '0.55']
# record 022: ['RF', 'gender', 'False', '3gram-no-hash', '0.60'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'False', '3gram-no-hash', '0.60']
# lang_present: False
# term_present: True
# modified 022 to:
# ['RF', 'gender', 'False', 'German', '3gram-no-hash', '0.60'] [type: <class 'list'>]
# record 023: ['NN', 'gender', 'False', 'German', '3gram-no-hash', '0.56'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'German', '3gram-no-hash', '0.56']
# record 024: ['DT', 'plurality', 'True', 'German', '3gram-no-hash', '0.84'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'True', 'German', '3gram-no-hash', '0.84']
# record 025: ['RF', 'plurality', 'True', '3gram-no-hash', '0.89'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'True', '3gram-no-hash', '0.89']
# lang_present: False
# term_present: True
# modified 025 to:
# ['RF', 'plurality', 'True', 'German', '3gram-no-hash', '0.89'] [type: <class 'list'>]
# record 026: ['NN', 'plurality', 'True', 'German', '3gram-no-hash', '0.84'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'German', '3gram-no-hash', '0.84']
# record 027: ['DT', 'plurality', 'False', 'German', '3gram-no-hash', '0.84'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'False', 'German', '3gram-no-hash', '0.84']
# record 028: ['RF', 'plurality', 'False', '3gram-no-hash', '0.86'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'False', '3gram-no-hash', '0.86']
# lang_present: False
# term_present: True
# modified 028 to:
# ['RF', 'plurality', 'False', 'German', '3gram-no-hash', '0.86'] [type: <class 'list'>]
# record 029: ['NN', 'plurality', 'False', 'German', '3gram-no-hash', '0.80'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'German', '3gram-no-hash', '0.80']
# record 030: ['DT', 'case', 'True', 'German', '3gram-no-hash', '0.36'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'True', 'German', '3gram-no-hash', '0.36']
# record 031: ['RF', 'case', 'True', '3gram-no-hash', '0.39'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'True', '3gram-no-hash', '0.39']
# lang_present: False
# term_present: True
# modified 031 to:
# ['RF', 'case', 'True', 'German', '3gram-no-hash', '0.39'] [type: <class 'list'>]
# record 032: ['NN', 'case', 'True', 'German', '3gram-no-hash', '0.33'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'German', '3gram-no-hash', '0.33']
# record 033: ['DT', 'case', 'False', 'German', '3gram-no-hash', '0.35'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'False', 'German', '3gram-no-hash', '0.35']
# record 034: ['RF', 'case', 'False', '3gram-no-hash', '0.38'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'False', '3gram-no-hash', '0.38']
# lang_present: False
# term_present: True
# modified 034 to:
# ['RF', 'case', 'False', 'German', '3gram-no-hash', '0.38'] [type: <class 'list'>]
# record 035: ['NN', 'case', 'False', 'German', '3gram-no-hash', '0.33'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'German', '3gram-no-hash', '0.33']
# record 036: ['DT', 'gender', 'True', 'German', '4gram-no-hash', '0.56'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'True', 'German', '4gram-no-hash', '0.56']
# record 037: ['RF', 'gender', 'True', '4gram-no-hash', '0.66'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'True', '4gram-no-hash', '0.66']
# lang_present: False
# term_present: True
# modified 037 to:
# ['RF', 'gender', 'True', 'German', '4gram-no-hash', '0.66'] [type: <class 'list'>]
# record 038: ['NN', 'gender', 'True', 'German', '4gram-no-hash', '0.64'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'German', '4gram-no-hash', '0.64']
# record 039: ['DT', 'gender', 'False', 'German', '4gram-no-hash', '0.57'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'False', 'German', '4gram-no-hash', '0.57']
# record 040: ['RF', 'gender', 'False', '4gram-no-hash', '0.66'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'False', '4gram-no-hash', '0.66']
# lang_present: False
# term_present: True
# modified 040 to:
# ['RF', 'gender', 'False', 'German', '4gram-no-hash', '0.66'] [type: <class 'list'>]
# record 041: ['NN', 'gender', 'False', 'German', '4gram-no-hash', '0.65'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'German', '4gram-no-hash', '0.65']
# record 042: ['DT', 'plurality', 'True', 'German', '4gram-no-hash', '0.85'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'True', 'German', '4gram-no-hash', '0.85']
# record 043: ['RF', 'plurality', 'True', '4gram-no-hash', '0.85'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'True', '4gram-no-hash', '0.85']
# lang_present: False
# term_present: True
# modified 043 to:
# ['RF', 'plurality', 'True', 'German', '4gram-no-hash', '0.85'] [type: <class 'list'>]
# record 044: ['NN', 'plurality', 'True', 'German', '4gram-no-hash', '0.83'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'German', '4gram-no-hash', '0.83']
# record 045: ['DT', 'plurality', 'False', 'German', '4gram-no-hash', '0.79'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'False', 'German', '4gram-no-hash', '0.79']
# record 046: ['RF', 'plurality', 'False', '4gram-no-hash', '0.83'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'False', '4gram-no-hash', '0.83']
# lang_present: False
# term_present: True
# modified 046 to:
# ['RF', 'plurality', 'False', 'German', '4gram-no-hash', '0.83'] [type: <class 'list'>]
# record 047: ['NN', 'plurality', 'False', 'German', '4gram-no-hash', '0.79'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'German', '4gram-no-hash', '0.79']
# record 048: ['DT', 'case', 'True', 'German', '4gram-no-hash', '0.35'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'True', 'German', '4gram-no-hash', '0.35']
# record 049: ['RF', 'case', 'True', '4gram-no-hash', '0.41'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'True', '4gram-no-hash', '0.41']
# lang_present: False
# term_present: True
# modified 049 to:
# ['RF', 'case', 'True', 'German', '4gram-no-hash', '0.41'] [type: <class 'list'>]
# record 050: ['NN', 'case', 'True', 'German', '4gram-no-hash', '0.35'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'German', '4gram-no-hash', '0.35']
# record 051: ['DT', 'case', 'False', 'German', '4gram-no-hash', '0.42'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'False', 'German', '4gram-no-hash', '0.42']
# record 052: ['RF', 'case', 'False', '4gram-no-hash', '0.39'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'False', '4gram-no-hash', '0.39']
# lang_present: False
# term_present: True
# modified 052 to:
# ['RF', 'case', 'False', 'German', '4gram-no-hash', '0.39'] [type: <class 'list'>]
# record 053: ['NN', 'case', 'False', 'German', '4gram-no-hash', '0.37'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'German', '4gram-no-hash', '0.37']
# record 054: ['DT', 'gender', 'True', 'German', 'skippy2gram-no-hash', '0.53'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'True', 'German', 'skippy2gram-no-hash', '0.53']
# record 055: ['RF', 'gender', 'True', 'skippy2gram-no-hash', '0.62'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy2gram-no-hash', '0.62']
# lang_present: False
# term_present: True
# modified 055 to:
# ['RF', 'gender', 'True', 'German', 'skippy2gram-no-hash', '0.62'] [type: <class 'list'>]
# record 056: ['NN', 'gender', 'True', 'German', 'skippy2gram-no-hash', '0.58'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'German', 'skippy2gram-no-hash', '0.58']
# record 057: ['DT', 'gender', 'False', 'German', 'skippy2gram-no-hash', '0.49'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'False', 'German', 'skippy2gram-no-hash', '0.49']
# record 058: ['RF', 'gender', 'False', 'skippy2gram-no-hash', '0.54'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy2gram-no-hash', '0.54']
# lang_present: False
# term_present: True
# modified 058 to:
# ['RF', 'gender', 'False', 'German', 'skippy2gram-no-hash', '0.54'] [type: <class 'list'>]
# record 059: ['NN', 'gender', 'False', 'German', 'skippy2gram-no-hash', '0.53'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'German', 'skippy2gram-no-hash', '0.53']
# record 060: ['DT', 'plurality', 'True', 'German', 'skippy2gram-no-hash', '0.78'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'True', 'German', 'skippy2gram-no-hash', '0.78']
# record 061: ['RF', 'plurality', 'True', 'skippy2gram-no-hash', '0.82'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy2gram-no-hash', '0.82']
# lang_present: False
# term_present: True
# modified 061 to:
# ['RF', 'plurality', 'True', 'German', 'skippy2gram-no-hash', '0.82'] [type: <class 'list'>]
# record 062: ['NN', 'plurality', 'True', 'German', 'skippy2gram-no-hash', '0.82'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'German', 'skippy2gram-no-hash', '0.82']
# record 063: ['DT', 'plurality', 'False', 'German', 'skippy2gram-no-hash', '0.78'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'False', 'German', 'skippy2gram-no-hash', '0.78']
# record 064: ['RF', 'plurality', 'False', 'skippy2gram-no-hash', '0.82'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy2gram-no-hash', '0.82']
# lang_present: False
# term_present: True
# modified 064 to:
# ['RF', 'plurality', 'False', 'German', 'skippy2gram-no-hash', '0.82'] [type: <class 'list'>]
# record 065: ['NN', 'plurality', 'False', 'German', 'skippy2gram-no-hash', '0.79'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'German', 'skippy2gram-no-hash', '0.79']
# record 066: ['DT', 'case', 'True', 'German', 'skippy2gram-no-hash', '0.38'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'True', 'German', 'skippy2gram-no-hash', '0.38']
# record 067: ['RF', 'case', 'True', 'skippy2gram-no-hash', '0.46'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy2gram-no-hash', '0.46']
# lang_present: False
# term_present: True
# modified 067 to:
# ['RF', 'case', 'True', 'German', 'skippy2gram-no-hash', '0.46'] [type: <class 'list'>]
# record 068: ['NN', 'case', 'True', 'German', 'skippy2gram-no-hash', '0.35'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'German', 'skippy2gram-no-hash', '0.35']
# record 069: ['DT', 'case', 'False', 'German', 'skippy2gram-no-hash', '0.37'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'False', 'German', 'skippy2gram-no-hash', '0.37']
# record 070: ['RF', 'case', 'False', 'skippy2gram-no-hash', '0.46'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy2gram-no-hash', '0.46']
# lang_present: False
# term_present: True
# modified 070 to:
# ['RF', 'case', 'False', 'German', 'skippy2gram-no-hash', '0.46'] [type: <class 'list'>]
# record 071: ['NN', 'case', 'False', 'German', 'skippy2gram-no-hash', '0.37'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'German', 'skippy2gram-no-hash', '0.37']
# record 072: ['DT', 'gender', 'True', 'German', 'skippy3gram-no-hash', '0.53'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'True', 'German', 'skippy3gram-no-hash', '0.53']
# record 073: ['RF', 'gender', 'True', 'skippy3gram-no-hash', '0.61'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy3gram-no-hash', '0.61']
# lang_present: False
# term_present: True
# modified 073 to:
# ['RF', 'gender', 'True', 'German', 'skippy3gram-no-hash', '0.61'] [type: <class 'list'>]
# record 074: ['NN', 'gender', 'True', 'German', 'skippy3gram-no-hash', '0.58'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'German', 'skippy3gram-no-hash', '0.58']
# record 075: ['DT', 'gender', 'False', 'German', 'skippy3gram-no-hash', '0.51'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'False', 'German', 'skippy3gram-no-hash', '0.51']
# record 076: ['RF', 'gender', 'False', 'skippy3gram-no-hash', '0.61'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy3gram-no-hash', '0.61']
# lang_present: False
# term_present: True
# modified 076 to:
# ['RF', 'gender', 'False', 'German', 'skippy3gram-no-hash', '0.61'] [type: <class 'list'>]
# record 077: ['NN', 'gender', 'False', 'German', 'skippy3gram-no-hash', '0.62'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'German', 'skippy3gram-no-hash', '0.62']
# record 078: ['DT', 'plurality', 'True', 'German', 'skippy3gram-no-hash', '0.79'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'True', 'German', 'skippy3gram-no-hash', '0.79']
# record 079: ['RF', 'plurality', 'True', 'skippy3gram-no-hash', '0.84'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy3gram-no-hash', '0.84']
# lang_present: False
# term_present: True
# modified 079 to:
# ['RF', 'plurality', 'True', 'German', 'skippy3gram-no-hash', '0.84'] [type: <class 'list'>]
# record 080: ['NN', 'plurality', 'True', 'German', 'skippy3gram-no-hash', '0.78'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'German', 'skippy3gram-no-hash', '0.78']
# record 081: ['DT', 'plurality', 'False', 'German', 'skippy3gram-no-hash', '0.74'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'False', 'German', 'skippy3gram-no-hash', '0.74']
# record 082: ['RF', 'plurality', 'False', 'skippy3gram-no-hash', '0.82'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy3gram-no-hash', '0.82']
# lang_present: False
# term_present: True
# modified 082 to:
# ['RF', 'plurality', 'False', 'German', 'skippy3gram-no-hash', '0.82'] [type: <class 'list'>]
# record 083: ['NN', 'plurality', 'False', 'German', 'skippy3gram-no-hash', '0.78'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'German', 'skippy3gram-no-hash', '0.78']
# record 084: ['DT', 'case', 'True', 'German', 'skippy3gram-no-hash', '0.40'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'True', 'German', 'skippy3gram-no-hash', '0.40']
# record 085: ['RF', 'case', 'True', 'skippy3gram-no-hash', '0.38'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy3gram-no-hash', '0.38']
# lang_present: False
# term_present: True
# modified 085 to:
# ['RF', 'case', 'True', 'German', 'skippy3gram-no-hash', '0.38'] [type: <class 'list'>]
# record 086: ['NN', 'case', 'True', 'German', 'skippy3gram-no-hash', '0.32'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'German', 'skippy3gram-no-hash', '0.32']
# record 087: ['DT', 'case', 'False', 'German', 'skippy3gram-no-hash', '0.34'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'False', 'German', 'skippy3gram-no-hash', '0.34']
# record 088: ['RF', 'case', 'False', 'skippy3gram-no-hash', '0.39'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy3gram-no-hash', '0.39']
# lang_present: False
# term_present: True
# modified 088 to:
# ['RF', 'case', 'False', 'German', 'skippy3gram-no-hash', '0.39'] [type: <class 'list'>]
# record 089: ['NN', 'case', 'False', 'German', 'skippy3gram-no-hash', '0.36'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'German', 'skippy3gram-no-hash', '0.36']
# record 090: ['DT', 'gender', 'True', 'German', 'skippy4gram-no-hash', '0.53'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'True', 'German', 'skippy4gram-no-hash', '0.53']
# record 091: ['RF', 'gender', 'True', 'skippy4gram-no-hash', '0.60'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy4gram-no-hash', '0.60']
# lang_present: False
# term_present: True
# modified 091 to:
# ['RF', 'gender', 'True', 'German', 'skippy4gram-no-hash', '0.60'] [type: <class 'list'>]
# record 092: ['NN', 'gender', 'True', 'German', 'skippy4gram-no-hash', '0.60'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'German', 'skippy4gram-no-hash', '0.60']
# record 093: ['DT', 'gender', 'False', 'German', 'skippy4gram-no-hash', '0.51'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'False', 'German', 'skippy4gram-no-hash', '0.51']
# record 094: ['RF', 'gender', 'False', 'skippy4gram-no-hash', '0.59'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy4gram-no-hash', '0.59']
# lang_present: False
# term_present: True
# modified 094 to:
# ['RF', 'gender', 'False', 'German', 'skippy4gram-no-hash', '0.59'] [type: <class 'list'>]
# record 095: ['NN', 'gender', 'False', 'German', 'skippy4gram-no-hash', '0.63'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'German', 'skippy4gram-no-hash', '0.63']
# record 096: ['DT', 'plurality', 'True', 'German', 'skippy4gram-no-hash', '0.79'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'True', 'German', 'skippy4gram-no-hash', '0.79']
# record 097: ['RF', 'plurality', 'True', 'skippy4gram-no-hash', '0.85'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy4gram-no-hash', '0.85']
# lang_present: False
# term_present: True
# modified 097 to:
# ['RF', 'plurality', 'True', 'German', 'skippy4gram-no-hash', '0.85'] [type: <class 'list'>]
# record 098: ['NN', 'plurality', 'True', 'German', 'skippy4gram-no-hash', '0.78'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'German', 'skippy4gram-no-hash', '0.78']
# record 099: ['DT', 'plurality', 'False', 'German', 'skippy4gram-no-hash', '0.74'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'False', 'German', 'skippy4gram-no-hash', '0.74']
# record 100: ['RF', 'plurality', 'False', 'skippy4gram-no-hash', '0.82'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy4gram-no-hash', '0.82']
# lang_present: False
# term_present: True
# modified 100 to:
# ['RF', 'plurality', 'False', 'German', 'skippy4gram-no-hash', '0.82'] [type: <class 'list'>]
# record 101: ['NN', 'plurality', 'False', 'German', 'skippy4gram-no-hash', '0.80'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'German', 'skippy4gram-no-hash', '0.80']
# record 102: ['DT', 'case', 'True', 'German', 'skippy4gram-no-hash', '0.33'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'True', 'German', 'skippy4gram-no-hash', '0.33']
# record 103: ['RF', 'case', 'True', 'skippy4gram-no-hash', '0.39'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy4gram-no-hash', '0.39']
# lang_present: False
# term_present: True
# modified 103 to:
# ['RF', 'case', 'True', 'German', 'skippy4gram-no-hash', '0.39'] [type: <class 'list'>]
# record 104: ['NN', 'case', 'True', 'German', 'skippy4gram-no-hash', '0.34'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'German', 'skippy4gram-no-hash', '0.34']
# record 105: ['DT', 'case', 'False', 'German', 'skippy4gram-no-hash', '0.32'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'False', 'German', 'skippy4gram-no-hash', '0.32']
# record 106: ['RF', 'case', 'False', 'skippy4gram-no-hash', '0.40'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy4gram-no-hash', '0.40']
# lang_present: False
# term_present: True
# modified 106 to:
# ['RF', 'case', 'False', 'German', 'skippy4gram-no-hash', '0.40'] [type: <class 'list'>]
# record 107: ['NN', 'case', 'False', 'German', 'skippy4gram-no-hash', '0.34'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'German', 'skippy4gram-no-hash', '0.34']
# record 108: ['DT', 'gender', 'True', 'German', '2gram-hash-at-both', '0.51'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'True', 'German', '2gram-hash-at-both', '0.51']
# record 109: ['RF', 'gender', 'True', '2gram-hash-at-both', '0.61'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'True', '2gram-hash-at-both', '0.61']
# lang_present: False
# term_present: True
# modified 109 to:
# ['RF', 'gender', 'True', 'German', '2gram-hash-at-both', '0.61'] [type: <class 'list'>]
# record 110: ['NN', 'gender', 'True', 'German', '2gram-hash-at-both', '0.57'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'German', '2gram-hash-at-both', '0.57']
# record 111: ['DT', 'gender', 'False', 'German', '2gram-hash-at-both', '0.50'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'False', 'German', '2gram-hash-at-both', '0.50']
# record 112: ['RF', 'gender', 'False', '2gram-hash-at-both', '0.56'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'False', '2gram-hash-at-both', '0.56']
# lang_present: False
# term_present: True
# modified 112 to:
# ['RF', 'gender', 'False', 'German', '2gram-hash-at-both', '0.56'] [type: <class 'list'>]
# record 113: ['NN', 'gender', 'False', 'German', '2gram-hash-at-both', '0.57'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'German', '2gram-hash-at-both', '0.57']
# record 114: ['DT', 'plurality', 'True', 'German', '2gram-hash-at-both', '0.80'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'True', 'German', '2gram-hash-at-both', '0.80']
# record 115: ['RF', 'plurality', 'True', '2gram-hash-at-both', '0.83'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'True', '2gram-hash-at-both', '0.83']
# lang_present: False
# term_present: True
# modified 115 to:
# ['RF', 'plurality', 'True', 'German', '2gram-hash-at-both', '0.83'] [type: <class 'list'>]
# record 116: ['NN', 'plurality', 'True', 'German', '2gram-hash-at-both', '0.82'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'German', '2gram-hash-at-both', '0.82']
# record 117: ['DT', 'plurality', 'False', 'German', '2gram-hash-at-both', '0.77'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'False', 'German', '2gram-hash-at-both', '0.77']
# record 118: ['RF', 'plurality', 'False', '2gram-hash-at-both', '0.81'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'False', '2gram-hash-at-both', '0.81']
# lang_present: False
# term_present: True
# modified 118 to:
# ['RF', 'plurality', 'False', 'German', '2gram-hash-at-both', '0.81'] [type: <class 'list'>]
# record 119: ['NN', 'plurality', 'False', 'German', '2gram-hash-at-both', '0.78'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'German', '2gram-hash-at-both', '0.78']
# record 120: ['DT', 'case', 'True', 'German', '2gram-hash-at-both', '0.33'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'True', 'German', '2gram-hash-at-both', '0.33']
# record 121: ['RF', 'case', 'True', '2gram-hash-at-both', '0.46'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'True', '2gram-hash-at-both', '0.46']
# lang_present: False
# term_present: True
# modified 121 to:
# ['RF', 'case', 'True', 'German', '2gram-hash-at-both', '0.46'] [type: <class 'list'>]
# record 122: ['NN', 'case', 'True', 'German', '2gram-hash-at-both', '0.38'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'German', '2gram-hash-at-both', '0.38']
# record 123: ['DT', 'case', 'False', 'German', '2gram-hash-at-both', '0.36'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'False', 'German', '2gram-hash-at-both', '0.36']
# record 124: ['RF', 'case', 'False', '2gram-hash-at-both', '0.38'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'False', '2gram-hash-at-both', '0.38']
# lang_present: False
# term_present: True
# modified 124 to:
# ['RF', 'case', 'False', 'German', '2gram-hash-at-both', '0.38'] [type: <class 'list'>]
# record 125: ['NN', 'case', 'False', 'German', '2gram-hash-at-both', '0.29'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'German', '2gram-hash-at-both', '0.29']
# record 126: ['DT', 'gender', 'True', 'German', '3gram-hash-at-both', '0.54'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'True', 'German', '3gram-hash-at-both', '0.54']
# record 127: ['RF', 'gender', 'True', '3gram-hash-at-both', '0.62'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'True', '3gram-hash-at-both', '0.62']
# lang_present: False
# term_present: True
# modified 127 to:
# ['RF', 'gender', 'True', 'German', '3gram-hash-at-both', '0.62'] [type: <class 'list'>]
# record 128: ['NN', 'gender', 'True', 'German', '3gram-hash-at-both', '0.53'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'German', '3gram-hash-at-both', '0.53']
# record 129: ['DT', 'gender', 'False', 'German', '3gram-hash-at-both', '0.51'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'False', 'German', '3gram-hash-at-both', '0.51']
# record 130: ['RF', 'gender', 'False', '3gram-hash-at-both', '0.62'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'False', '3gram-hash-at-both', '0.62']
# lang_present: False
# term_present: True
# modified 130 to:
# ['RF', 'gender', 'False', 'German', '3gram-hash-at-both', '0.62'] [type: <class 'list'>]
# record 131: ['NN', 'gender', 'False', 'German', '3gram-hash-at-both', '0.55'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'German', '3gram-hash-at-both', '0.55']
# record 132: ['DT', 'plurality', 'True', 'German', '3gram-hash-at-both', '0.80'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'True', 'German', '3gram-hash-at-both', '0.80']
# record 133: ['RF', 'plurality', 'True', '3gram-hash-at-both', '0.81'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'True', '3gram-hash-at-both', '0.81']
# lang_present: False
# term_present: True
# modified 133 to:
# ['RF', 'plurality', 'True', 'German', '3gram-hash-at-both', '0.81'] [type: <class 'list'>]
# record 134: ['NN', 'plurality', 'True', 'German', '3gram-hash-at-both', '0.82'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'German', '3gram-hash-at-both', '0.82']
# record 135: ['DT', 'plurality', 'False', 'German', '3gram-hash-at-both', '0.76'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'False', 'German', '3gram-hash-at-both', '0.76']
# record 136: ['RF', 'plurality', 'False', '3gram-hash-at-both', '0.80'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'False', '3gram-hash-at-both', '0.80']
# lang_present: False
# term_present: True
# modified 136 to:
# ['RF', 'plurality', 'False', 'German', '3gram-hash-at-both', '0.80'] [type: <class 'list'>]
# record 137: ['NN', 'plurality', 'False', 'German', '3gram-hash-at-both', '0.78'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'German', '3gram-hash-at-both', '0.78']
# record 138: ['DT', 'case', 'True', 'German', '3gram-hash-at-both', '0.41'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'True', 'German', '3gram-hash-at-both', '0.41']
# record 139: ['RF', 'case', 'True', '3gram-hash-at-both', '0.42'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'True', '3gram-hash-at-both', '0.42']
# lang_present: False
# term_present: True
# modified 139 to:
# ['RF', 'case', 'True', 'German', '3gram-hash-at-both', '0.42'] [type: <class 'list'>]
# record 140: ['NN', 'case', 'True', 'German', '3gram-hash-at-both', '0.36'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'German', '3gram-hash-at-both', '0.36']
# record 141: ['DT', 'case', 'False', 'German', '3gram-hash-at-both', '0.40'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'False', 'German', '3gram-hash-at-both', '0.40']
# record 142: ['RF', 'case', 'False', '3gram-hash-at-both', '0.41'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'False', '3gram-hash-at-both', '0.41']
# lang_present: False
# term_present: True
# modified 142 to:
# ['RF', 'case', 'False', 'German', '3gram-hash-at-both', '0.41'] [type: <class 'list'>]
# record 143: ['NN', 'case', 'False', 'German', '3gram-hash-at-both', '0.34'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'German', '3gram-hash-at-both', '0.34']
# record 144: ['DT', 'gender', 'True', 'German', '4gram-hash-at-both', '0.58'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'True', 'German', '4gram-hash-at-both', '0.58']
# record 145: ['RF', 'gender', 'True', '4gram-hash-at-both', '0.56'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'True', '4gram-hash-at-both', '0.56']
# lang_present: False
# term_present: True
# modified 145 to:
# ['RF', 'gender', 'True', 'German', '4gram-hash-at-both', '0.56'] [type: <class 'list'>]
# record 146: ['NN', 'gender', 'True', 'German', '4gram-hash-at-both', '0.64'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'German', '4gram-hash-at-both', '0.64']
# record 147: ['DT', 'gender', 'False', 'German', '4gram-hash-at-both', '0.51'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'False', 'German', '4gram-hash-at-both', '0.51']
# record 148: ['RF', 'gender', 'False', '4gram-hash-at-both', '0.55'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'False', '4gram-hash-at-both', '0.55']
# lang_present: False
# term_present: True
# modified 148 to:
# ['RF', 'gender', 'False', 'German', '4gram-hash-at-both', '0.55'] [type: <class 'list'>]
# record 149: ['NN', 'gender', 'False', 'German', '4gram-hash-at-both', '0.58'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'German', '4gram-hash-at-both', '0.58']
# record 150: ['DT', 'plurality', 'True', 'German', '4gram-hash-at-both', '0.76'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'True', 'German', '4gram-hash-at-both', '0.76']
# record 151: ['RF', 'plurality', 'True', '4gram-hash-at-both', '0.85'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'True', '4gram-hash-at-both', '0.85']
# lang_present: False
# term_present: True
# modified 151 to:
# ['RF', 'plurality', 'True', 'German', '4gram-hash-at-both', '0.85'] [type: <class 'list'>]
# record 152: ['NN', 'plurality', 'True', 'German', '4gram-hash-at-both', '0.80'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'German', '4gram-hash-at-both', '0.80']
# record 153: ['DT', 'plurality', 'False', 'German', '4gram-hash-at-both', '0.76'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'False', 'German', '4gram-hash-at-both', '0.76']
# record 154: ['RF', 'plurality', 'False', '4gram-hash-at-both', '0.80'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'False', '4gram-hash-at-both', '0.80']
# lang_present: False
# term_present: True
# modified 154 to:
# ['RF', 'plurality', 'False', 'German', '4gram-hash-at-both', '0.80'] [type: <class 'list'>]
# record 155: ['NN', 'plurality', 'False', 'German', '4gram-hash-at-both', '0.77'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'German', '4gram-hash-at-both', '0.77']
# record 156: ['DT', 'case', 'True', 'German', '4gram-hash-at-both', '0.39'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'True', 'German', '4gram-hash-at-both', '0.39']
# record 157: ['RF', 'case', 'True', '4gram-hash-at-both', '0.41'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'True', '4gram-hash-at-both', '0.41']
# lang_present: False
# term_present: True
# modified 157 to:
# ['RF', 'case', 'True', 'German', '4gram-hash-at-both', '0.41'] [type: <class 'list'>]
# record 158: ['NN', 'case', 'True', 'German', '4gram-hash-at-both', '0.36'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'German', '4gram-hash-at-both', '0.36']
# record 159: ['DT', 'case', 'False', 'German', '4gram-hash-at-both', '0.34'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'False', 'German', '4gram-hash-at-both', '0.34']
# record 160: ['RF', 'case', 'False', '4gram-hash-at-both', '0.42'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'False', '4gram-hash-at-both', '0.42']
# lang_present: False
# term_present: True
# modified 160 to:
# ['RF', 'case', 'False', 'German', '4gram-hash-at-both', '0.42'] [type: <class 'list'>]
# record 161: ['NN', 'case', 'False', 'German', '4gram-hash-at-both', '0.34'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'German', '4gram-hash-at-both', '0.34']
# record 162: ['DT', 'gender', 'True', 'German', 'skippy2gram-hash-at-both', '0.51'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'True', 'German', 'skippy2gram-hash-at-both', '0.51']
# record 163: ['RF', 'gender', 'True', 'skippy2gram-hash-at-both', '0.64'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy2gram-hash-at-both', '0.64']
# lang_present: False
# term_present: True
# modified 163 to:
# ['RF', 'gender', 'True', 'German', 'skippy2gram-hash-at-both', '0.64'] [type: <class 'list'>]
# record 164: ['NN', 'gender', 'True', 'German', 'skippy2gram-hash-at-both', '0.59'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'German', 'skippy2gram-hash-at-both', '0.59']
# record 165: ['DT', 'gender', 'False', 'German', 'skippy2gram-hash-at-both', '0.55'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'False', 'German', 'skippy2gram-hash-at-both', '0.55']
# record 166: ['RF', 'gender', 'False', 'skippy2gram-hash-at-both', '0.63'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy2gram-hash-at-both', '0.63']
# lang_present: False
# term_present: True
# modified 166 to:
# ['RF', 'gender', 'False', 'German', 'skippy2gram-hash-at-both', '0.63'] [type: <class 'list'>]
# record 167: ['NN', 'gender', 'False', 'German', 'skippy2gram-hash-at-both', '0.56'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'German', 'skippy2gram-hash-at-both', '0.56']
# record 168: ['DT', 'plurality', 'True', 'German', 'skippy2gram-hash-at-both', '0.78'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'True', 'German', 'skippy2gram-hash-at-both', '0.78']
# record 169: ['RF', 'plurality', 'True', 'skippy2gram-hash-at-both', '0.85'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy2gram-hash-at-both', '0.85']
# lang_present: False
# term_present: True
# modified 169 to:
# ['RF', 'plurality', 'True', 'German', 'skippy2gram-hash-at-both', '0.85'] [type: <class 'list'>]
# record 170: ['NN', 'plurality', 'True', 'German', 'skippy2gram-hash-at-both', '0.80'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'German', 'skippy2gram-hash-at-both', '0.80']
# record 171: ['DT', 'plurality', 'False', 'German', 'skippy2gram-hash-at-both', '0.78'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'False', 'German', 'skippy2gram-hash-at-both', '0.78']
# record 172: ['RF', 'plurality', 'False', 'skippy2gram-hash-at-both', '0.81'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy2gram-hash-at-both', '0.81']
# lang_present: False
# term_present: True
# modified 172 to:
# ['RF', 'plurality', 'False', 'German', 'skippy2gram-hash-at-both', '0.81'] [type: <class 'list'>]
# record 173: ['NN', 'plurality', 'False', 'German', 'skippy2gram-hash-at-both', '0.76'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'German', 'skippy2gram-hash-at-both', '0.76']
# record 174: ['DT', 'case', 'True', 'German', 'skippy2gram-hash-at-both', '0.43'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'True', 'German', 'skippy2gram-hash-at-both', '0.43']
# record 175: ['RF', 'case', 'True', 'skippy2gram-hash-at-both', '0.45'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy2gram-hash-at-both', '0.45']
# lang_present: False
# term_present: True
# modified 175 to:
# ['RF', 'case', 'True', 'German', 'skippy2gram-hash-at-both', '0.45'] [type: <class 'list'>]
# record 176: ['NN', 'case', 'True', 'German', 'skippy2gram-hash-at-both', '0.40'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'German', 'skippy2gram-hash-at-both', '0.40']
# record 177: ['DT', 'case', 'False', 'German', 'skippy2gram-hash-at-both', '0.37'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'False', 'German', 'skippy2gram-hash-at-both', '0.37']
# record 178: ['RF', 'case', 'False', 'skippy2gram-hash-at-both', '0.47'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy2gram-hash-at-both', '0.47']
# lang_present: False
# term_present: True
# modified 178 to:
# ['RF', 'case', 'False', 'German', 'skippy2gram-hash-at-both', '0.47'] [type: <class 'list'>]
# record 179: ['NN', 'case', 'False', 'German', 'skippy2gram-hash-at-both', '0.37'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'German', 'skippy2gram-hash-at-both', '0.37']
# record 180: ['DT', 'gender', 'True', 'German', 'skippy3gram-hash-at-both', '0.54'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'True', 'German', 'skippy3gram-hash-at-both', '0.54']
# record 181: ['RF', 'gender', 'True', 'skippy3gram-hash-at-both', '0.59'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy3gram-hash-at-both', '0.59']
# lang_present: False
# term_present: True
# modified 181 to:
# ['RF', 'gender', 'True', 'German', 'skippy3gram-hash-at-both', '0.59'] [type: <class 'list'>]
# record 182: ['NN', 'gender', 'True', 'German', 'skippy3gram-hash-at-both', '0.55'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'German', 'skippy3gram-hash-at-both', '0.55']
# record 183: ['DT', 'gender', 'False', 'German', 'skippy3gram-hash-at-both', '0.51'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'False', 'German', 'skippy3gram-hash-at-both', '0.51']
# record 184: ['RF', 'gender', 'False', 'skippy3gram-hash-at-both', '0.59'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy3gram-hash-at-both', '0.59']
# lang_present: False
# term_present: True
# modified 184 to:
# ['RF', 'gender', 'False', 'German', 'skippy3gram-hash-at-both', '0.59'] [type: <class 'list'>]
# record 185: ['NN', 'gender', 'False', 'German', 'skippy3gram-hash-at-both', '0.60'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'German', 'skippy3gram-hash-at-both', '0.60']
# record 186: ['DT', 'plurality', 'True', 'German', 'skippy3gram-hash-at-both', '0.79'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'True', 'German', 'skippy3gram-hash-at-both', '0.79']
# record 187: ['RF', 'plurality', 'True', 'skippy3gram-hash-at-both', '0.85'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy3gram-hash-at-both', '0.85']
# lang_present: False
# term_present: True
# modified 187 to:
# ['RF', 'plurality', 'True', 'German', 'skippy3gram-hash-at-both', '0.85'] [type: <class 'list'>]
# record 188: ['NN', 'plurality', 'True', 'German', 'skippy3gram-hash-at-both', '0.79'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'True', 'German', 'skippy3gram-hash-at-both', '0.79']
# record 189: ['DT', 'plurality', 'False', 'German', 'skippy3gram-hash-at-both', '0.81'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'False', 'German', 'skippy3gram-hash-at-both', '0.81']
# record 190: ['RF', 'plurality', 'False', 'skippy3gram-hash-at-both', '0.85'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'False', 'skippy3gram-hash-at-both', '0.85']
# lang_present: False
# term_present: True
# modified 190 to:
# ['RF', 'plurality', 'False', 'German', 'skippy3gram-hash-at-both', '0.85'] [type: <class 'list'>]
# record 191: ['NN', 'plurality', 'False', 'German', 'skippy3gram-hash-at-both', '0.78'] [type: <class 'list'>]
# found valid record
# ['NN', 'plurality', 'False', 'German', 'skippy3gram-hash-at-both', '0.78']
# record 192: ['DT', 'case', 'True', 'German', 'skippy3gram-hash-at-both', '0.36'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'True', 'German', 'skippy3gram-hash-at-both', '0.36']
# record 193: ['RF', 'case', 'True', 'skippy3gram-hash-at-both', '0.43'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'True', 'skippy3gram-hash-at-both', '0.43']
# lang_present: False
# term_present: True
# modified 193 to:
# ['RF', 'case', 'True', 'German', 'skippy3gram-hash-at-both', '0.43'] [type: <class 'list'>]
# record 194: ['NN', 'case', 'True', 'German', 'skippy3gram-hash-at-both', '0.38'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'True', 'German', 'skippy3gram-hash-at-both', '0.38']
# record 195: ['DT', 'case', 'False', 'German', 'skippy3gram-hash-at-both', '0.35'] [type: <class 'list'>]
# found valid record
# ['DT', 'case', 'False', 'German', 'skippy3gram-hash-at-both', '0.35']
# record 196: ['RF', 'case', 'False', 'skippy3gram-hash-at-both', '0.44'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'case', 'False', 'skippy3gram-hash-at-both', '0.44']
# lang_present: False
# term_present: True
# modified 196 to:
# ['RF', 'case', 'False', 'German', 'skippy3gram-hash-at-both', '0.44'] [type: <class 'list'>]
# record 197: ['NN', 'case', 'False', 'German', 'skippy3gram-hash-at-both', '0.36'] [type: <class 'list'>]
# found valid record
# ['NN', 'case', 'False', 'German', 'skippy3gram-hash-at-both', '0.36']
# record 198: ['DT', 'gender', 'True', 'German', 'skippy4gram-hash-at-both', '0.51'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'True', 'German', 'skippy4gram-hash-at-both', '0.51']
# record 199: ['RF', 'gender', 'True', 'skippy4gram-hash-at-both', '0.57'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'True', 'skippy4gram-hash-at-both', '0.57']
# lang_present: False
# term_present: True
# modified 199 to:
# ['RF', 'gender', 'True', 'German', 'skippy4gram-hash-at-both', '0.57'] [type: <class 'list'>]
# record 200: ['NN', 'gender', 'True', 'German', 'skippy4gram-hash-at-both', '0.61'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'True', 'German', 'skippy4gram-hash-at-both', '0.61']
# record 201: ['DT', 'gender', 'False', 'German', 'skippy4gram-hash-at-both', '0.55'] [type: <class 'list'>]
# found valid record
# ['DT', 'gender', 'False', 'German', 'skippy4gram-hash-at-both', '0.55']
# record 202: ['RF', 'gender', 'False', 'skippy4gram-hash-at-both', '0.57'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'gender', 'False', 'skippy4gram-hash-at-both', '0.57']
# lang_present: False
# term_present: True
# modified 202 to:
# ['RF', 'gender', 'False', 'German', 'skippy4gram-hash-at-both', '0.57'] [type: <class 'list'>]
# record 203: ['NN', 'gender', 'False', 'German', 'skippy4gram-hash-at-both', '0.58'] [type: <class 'list'>]
# found valid record
# ['NN', 'gender', 'False', 'German', 'skippy4gram-hash-at-both', '0.58']
# record 204: ['DT', 'plurality', 'True', 'German', 'skippy4gram-hash-at-both', '0.77'] [type: <class 'list'>]
# found valid record
# ['DT', 'plurality', 'True', 'German', 'skippy4gram-hash-at-both', '0.77']
# record 205: ['RF', 'plurality', 'True', 'skippy4gram-hash-at-both', '0.81'] [type: <class 'list'>]
# found invalid record to modify
# ['RF', 'plurality', 'True', 'skippy4gram-hash-at-both', '0.81']
# lang_present: False
# term_present: True
# modified 205 to:
# ['RF', 'plurality', 'True', 'German', 'skippy4gram-hash-at-both', '0.81'] [type: <class 'list'>]
# ...
# record 081: ['DT', 'gender2', 'False', 'Czech', 'skippy3gram-no-hash', '0.62']
# record 082: ['RF', 'gender2', 'False', 'Czech', 'skippy3gram-no-hash', '0.74']
# record 083: ['NN', 'gender2', 'False', 'Czech', 'skippy3gram-no-hash', '0.76']
# record 084: ['DT', 'plurality', 'True', 'Czech', 'skippy3gram-no-hash', '0.80']
# record 085: ['RF', 'plurality', 'True', 'Czech', 'skippy3gram-no-hash', '0.84']
# record 086: ['NN', 'plurality', 'True', 'Czech', 'skippy3gram-no-hash', '0.83']
# record 087: ['DT', 'plurality', 'False', 'Czech', 'skippy3gram-no-hash', '0.81']
# record 088: ['RF', 'plurality', 'False', 'Czech', 'skippy3gram-no-hash', '0.82']
# record 089: ['NN', 'plurality', 'False', 'Czech', 'skippy3gram-no-hash', '0.81']
# record 090: ['DT', 'case', 'True', 'Czech', 'skippy4gram-no-hash', '0.45']
# record 091: ['RF', 'case', 'True', 'Czech', 'skippy4gram-no-hash', '0.51']
# record 092: ['NN', 'case', 'True', 'Czech', 'skippy4gram-no-hash', '0.41']
# record 093: ['DT', 'case', 'False', 'Czech', 'skippy4gram-no-hash', '0.32']
# record 094: ['RF', 'case', 'False', 'Czech', 'skippy4gram-no-hash', '0.45']
# record 095: ['NN', 'case', 'False', 'Czech', 'skippy4gram-no-hash', '0.40']
# record 096: ['DT', 'gender2', 'True', 'Czech', 'skippy4gram-no-hash', '0.65']
# record 097: ['RF', 'gender2', 'True', 'Czech', 'skippy4gram-no-hash', '0.91']
# record 098: ['NN', 'gender2', 'True', 'Czech', 'skippy4gram-no-hash', '0.91']
# record 099: ['DT', 'gender2', 'False', 'Czech', 'skippy4gram-no-hash', '0.62']
# record 100: ['RF', 'gender2', 'False', 'Czech', 'skippy4gram-no-hash', '0.74']
# record 101: ['NN', 'gender2', 'False', 'Czech', 'skippy4gram-no-hash', '0.74']
# record 102: ['DT', 'plurality', 'True', 'Czech', 'skippy4gram-no-hash', '0.83']
# record 103: ['RF', 'plurality', 'True', 'Czech', 'skippy4gram-no-hash', '0.90']
# record 104: ['NN', 'plurality', 'True', 'Czech', 'skippy4gram-no-hash', '0.86']
# record 105: ['DT', 'plurality', 'False', 'Czech', 'skippy4gram-no-hash', '0.83']
# record 106: ['RF', 'plurality', 'False', 'Czech', 'skippy4gram-no-hash', '0.87']
# record 107: ['NN', 'plurality', 'False', 'Czech', 'skippy4gram-no-hash', '0.88']
# record 108: ['DT', 'case', 'True', 'Czech', '2gram-hash-at-both', '0.49']
# record 109: ['RF', 'case', 'True', 'Czech', '2gram-hash-at-both', '0.52']
# record 110: ['NN', 'case', 'True', 'Czech', '2gram-hash-at-both', '0.46']
# record 111: ['DT', 'case', 'False', 'Czech', '2gram-hash-at-both', '0.43']
# record 112: ['RF', 'case', 'False', 'Czech', '2gram-hash-at-both', '0.45']
# record 113: ['NN', 'case', 'False', 'Czech', '2gram-hash-at-both', '0.40']
# record 114: ['DT', 'gender2', 'True', 'Czech', '2gram-hash-at-both', '0.93']
# record 115: ['RF', 'gender2', 'True', 'Czech', '2gram-hash-at-both', '0.93']
# record 116: ['NN', 'gender2', 'True', 'Czech', '2gram-hash-at-both', '0.93']
# record 117: ['DT', 'gender2', 'False', 'Czech', '2gram-hash-at-both', '0.63']
# record 118: ['RF', 'gender2', 'False', 'Czech', '2gram-hash-at-both', '0.71']
# record 119: ['NN', 'gender2', 'False', 'Czech', '2gram-hash-at-both', '0.66']
# record 120: ['DT', 'plurality', 'True', 'Czech', '2gram-hash-at-both', '0.88']
# record 121: ['RF', 'plurality', 'True', 'Czech', '2gram-hash-at-both', '0.90']
# record 122: ['NN', 'plurality', 'True', 'Czech', '2gram-hash-at-both', '0.88']
# record 123: ['DT', 'plurality', 'False', 'Czech', '2gram-hash-at-both', '0.80']
# record 124: ['RF', 'plurality', 'False', 'Czech', '2gram-hash-at-both', '0.83']
# record 125: ['NN', 'plurality', 'False', 'Czech', '2gram-hash-at-both', '0.82']
# record 126: ['DT', 'case', 'True', 'Czech', '3gram-hash-at-both', '0.56']
# record 127: ['RF', 'case', 'True', 'Czech', '3gram-hash-at-both', '0.59']
# record 128: ['NN', 'case', 'True', 'Czech', '3gram-hash-at-both', '0.55']
# record 129: ['DT', 'case', 'False', 'Czech', '3gram-hash-at-both', '0.42']
# record 130: ['RF', 'case', 'False', 'Czech', '3gram-hash-at-both', '0.48']
# record 131: ['NN', 'case', 'False', 'Czech', '3gram-hash-at-both', '0.45']
# record 132: ['DT', 'gender2', 'True', 'Czech', '3gram-hash-at-both', '0.89']
# record 133: ['RF', 'gender2', 'True', 'Czech', '3gram-hash-at-both', '0.92']
# record 134: ['NN', 'gender2', 'True', 'Czech', '3gram-hash-at-both', '0.92']
# record 135: ['DT', 'gender2', 'False', 'Czech', '3gram-hash-at-both', '0.66']
# record 136: ['RF', 'gender2', 'False', 'Czech', '3gram-hash-at-both', '0.74']
# record 137: ['NN', 'gender2', 'False', 'Czech', '3gram-hash-at-both', '0.77']
# record 138: ['DT', 'plurality', 'True', 'Czech', '3gram-hash-at-both', '0.93']
# record 139: ['RF', 'plurality', 'True', 'Czech', '3gram-hash-at-both', '0.85']
# record 140: ['NN', 'plurality', 'True', 'Czech', '3gram-hash-at-both', '0.91']
# record 141: ['DT', 'plurality', 'False', 'Czech', '3gram-hash-at-both', '0.82']
# record 142: ['RF', 'plurality', 'False', 'Czech', '3gram-hash-at-both', '0.83']
# record 143: ['NN', 'plurality', 'False', 'Czech', '3gram-hash-at-both', '0.82']
# record 144: ['DT', 'case', 'True', 'Czech', '4gram-hash-at-both', '0.52']
# record 145: ['RF', 'case', 'True', 'Czech', '4gram-hash-at-both', '0.54']
# record 146: ['NN', 'case', 'True', 'Czech', '4gram-hash-at-both', '0.51']
# record 147: ['DT', 'case', 'False', 'Czech', '4gram-hash-at-both', '0.43']
# record 148: ['RF', 'case', 'False', 'Czech', '4gram-hash-at-both', '0.44']
# record 149: ['NN', 'case', 'False', 'Czech', '4gram-hash-at-both', '0.39']
# record 150: ['DT', 'gender2', 'True', 'Czech', '4gram-hash-at-both', '0.85']
# record 151: ['RF', 'gender2', 'True', 'Czech', '4gram-hash-at-both', '0.90']
# record 152: ['NN', 'gender2', 'True', 'Czech', '4gram-hash-at-both', '0.94']
# record 153: ['DT', 'gender2', 'False', 'Czech', '4gram-hash-at-both', '0.67']
# record 154: ['RF', 'gender2', 'False', 'Czech', '4gram-hash-at-both', '0.77']
# record 155: ['NN', 'gender2', 'False', 'Czech', '4gram-hash-at-both', '0.77']
# record 156: ['DT', 'plurality', 'True', 'Czech', '4gram-hash-at-both', '0.85']
# record 157: ['RF', 'plurality', 'True', 'Czech', '4gram-hash-at-both', '0.86']
# record 158: ['NN', 'plurality', 'True', 'Czech', '4gram-hash-at-both', '0.87']
# record 159: ['DT', 'plurality', 'False', 'Czech', '4gram-hash-at-both', '0.77']
# record 160: ['RF', 'plurality', 'False', 'Czech', '4gram-hash-at-both', '0.80']
# record 161: ['NN', 'plurality', 'False', 'Czech', '4gram-hash-at-both', '0.82']
# record 162: ['DT', 'case', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.51']
# record 163: ['RF', 'case', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.49']
# record 164: ['NN', 'case', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.40']
# record 165: ['DT', 'case', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.43']
# record 166: ['RF', 'case', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.44']
# record 167: ['NN', 'case', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.38']
# record 168: ['DT', 'gender2', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.77']
# record 169: ['RF', 'gender2', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.93']
# record 170: ['NN', 'gender2', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.93']
# record 171: ['DT', 'gender2', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.62']
# record 172: ['RF', 'gender2', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.73']
# record 173: ['NN', 'gender2', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.71']
# record 174: ['DT', 'plurality', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.87']
# record 175: ['RF', 'plurality', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.88']
# record 176: ['NN', 'plurality', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.85']
# record 177: ['DT', 'plurality', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.84']
# record 178: ['RF', 'plurality', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.86']
# record 179: ['NN', 'plurality', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.84']
# record 180: ['DT', 'case', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.47']
# record 181: ['RF', 'case', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.49']
# record 182: ['NN', 'case', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.41']
# record 183: ['DT', 'case', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.42']
# record 184: ['RF', 'case', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.48']
# record 185: ['NN', 'case', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.41']
# record 186: ['DT', 'gender2', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.64']
# record 187: ['RF', 'gender2', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.92']
# record 188: ['NN', 'gender2', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.92']
# record 189: ['DT', 'gender2', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.62']
# record 190: ['RF', 'gender2', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.68']
# record 191: ['NN', 'gender2', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.74']
# record 192: ['DT', 'plurality', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.81']
# record 193: ['RF', 'plurality', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.88']
# record 194: ['NN', 'plurality', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.85']
# record 195: ['DT', 'plurality', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.83']
# record 196: ['RF', 'plurality', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.85']
# record 197: ['NN', 'plurality', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.82']
# record 198: ['DT', 'case', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.42']
# record 199: ['RF', 'case', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.50']
# record 200: ['NN', 'case', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.39']
# record 201: ['DT', 'case', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.32']
# record 202: ['RF', 'case', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.43']
# record 203: ['NN', 'case', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.39']
# record 204: ['DT', 'gender2', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.79']
# record 205: ['RF', 'gender2', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.89']
# record 206: ['NN', 'gender2', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.90']
# record 207: ['DT', 'gender2', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.57']
# record 208: ['RF', 'gender2', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.71']
# record 209: ['NN', 'gender2', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.70']
# record 210: ['DT', 'plurality', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.79']
# record 211: ['RF', 'plurality', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.83']
# record 212: ['NN', 'plurality', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.82']
# record 213: ['DT', 'plurality', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.80']
# record 214: ['RF', 'plurality', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.84']
# record 215: ['NN', 'plurality', 'False', 'Czech', 'skippy4gram-hash-at-both', '0.82']
# fn_fields: ['result', 'Czech2', '3000', 'xsk', 'mgv3', '2025', '3', '3', '12', '48.txt']
# fn_key0: ('Czech2', '3000', 'xsk', 'mgv3', '3', '3', '12', '48')
# fn_key1: ('Czech2', '3000', 'xsk', 'mgv3', '3', '3', '12', '48')
# data 01
# df key: ('German', 'sample3000', 'xsk', 'mgv3', '2', '20', '22', '11')
#        lang attribute supplement method                 term_type accuracy
# 0    German    gender       True     DT             2gram-no-hash     0.55
# 1    German    gender       True     RF             2gram-no-hash     0.63
# 2    German    gender       True     NN             2gram-no-hash     0.55
# 3    German    gender      False     DT             2gram-no-hash     0.51
# 4    German    gender      False     RF             2gram-no-hash     0.59
# ..      ...       ...        ...    ...                       ...      ...
# 211  German      case       True     RF  skippy4gram-hash-at-both     0.41
# 212  German      case       True     NN  skippy4gram-hash-at-both     0.37
# 213  German      case      False     DT  skippy4gram-hash-at-both     0.33
# 214  German      case      False     RF  skippy4gram-hash-at-both     0.41
# 215  German      case      False     NN  skippy4gram-hash-at-both     0.39
#
# [216 rows x 6 columns]
# data 02
# df key: ('Irish', 'sample3000', 'xsk', 'mgv3', '2', '21', '4', '35')
#       lang attribute supplement method                 term_type accuracy
# 0    Irish    gender       True     DT             2gram-no-hash     0.81
# 1    Irish    gender       True     RF             2gram-no-hash     0.84
# 2    Irish    gender       True     NN             2gram-no-hash     0.78
# 3    Irish    gender      False     DT             2gram-no-hash     0.67
# 4    Irish    gender      False     RF             2gram-no-hash     0.74
# ..     ...       ...        ...    ...                       ...      ...
# 211  Irish      case       True     RF  skippy4gram-hash-at-both     0.98
# 212  Irish      case       True     NN  skippy4gram-hash-at-both     0.98
# 213  Irish      case      False     DT  skippy4gram-hash-at-both     0.97
# 214  Irish      case      False     RF  skippy4gram-hash-at-both     0.98
# 215  Irish      case      False     NN  skippy4gram-hash-at-both     0.98
#
# [216 rows x 6 columns]
# data 03
# df key: ('Czech', 'sample3000', 'xsk', 'mgv3', '2', '20', '20', '35')
#       lang attribute supplement method                 term_type accuracy
# 0    Czech    gender       True     DT             2gram-no-hash     0.56
# 1    Czech    gender       True     RF             2gram-no-hash     0.58
# 2    Czech    gender       True     NN             2gram-no-hash     0.66
# 3    Czech    gender      False     DT             2gram-no-hash     0.51
# 4    Czech    gender      False     RF             2gram-no-hash     0.61
# ..     ...       ...        ...    ...                       ...      ...
# 211  Czech      case       True     RF  skippy4gram-hash-at-both     0.54
# 212  Czech      case       True     NN  skippy4gram-hash-at-both     0.40
# 213  Czech      case      False     DT  skippy4gram-hash-at-both     0.36
# 214  Czech      case      False     RF  skippy4gram-hash-at-both     0.46
# 215  Czech      case      False     NN  skippy4gram-hash-at-both     0.35
#
# [216 rows x 6 columns]
# data 04
# df key: ('French', 'sample3000', 'xsk', 'mgv3', '2', '20', '21', '31')
#        lang  attribute supplement method                 term_type accuracy
# 0    French     gender       True     DT             2gram-no-hash     0.72
# 1    French     gender       True     RF             2gram-no-hash     0.85
# 2    French     gender       True     NN             2gram-no-hash     0.78
# 3    French     gender      False     DT             2gram-no-hash     0.75
# 4    French     gender      False     RF             2gram-no-hash     0.82
# ..      ...        ...        ...    ...                       ...      ...
# 139  French  plurality       True     RF  skippy4gram-hash-at-both     0.95
# 140  French  plurality       True     NN  skippy4gram-hash-at-both     0.93
# 141  French  plurality      False     DT  skippy4gram-hash-at-both     0.80
# 142  French  plurality      False     RF  skippy4gram-hash-at-both     0.95
# 143  French  plurality      False     NN  skippy4gram-hash-at-both     0.93
#
# [144 rows x 6 columns]
# data 05
# df key: ('Czech2', '3000', 'xsk', 'mgv3', '3', '3', '12', '48')
#       lang  attribute supplement method                 term_type accuracy
# 0    Czech       case       True     DT             2gram-no-hash     0.55
# 1    Czech       case       True     RF             2gram-no-hash     0.59
# 2    Czech       case       True     NN             2gram-no-hash     0.54
# 3    Czech       case      False     DT             2gram-no-hash     0.41
# 4    Czech       case      False     RF             2gram-no-hash     0.45
# ..     ...        ...        ...    ...                       ...      ...
# 211  Czech  plurality       True     RF  skippy4gram-hash-at-both     0.83
# 212  Czech  plurality       True     NN  skippy4gram-hash-at-both     0.82
# 213  Czech  plurality      False     DT  skippy4gram-hash-at-both     0.80
# 214  Czech  plurality      False     RF  skippy4gram-hash-at-both     0.84
# 215  Czech  plurality      False     NN  skippy4gram-hash-at-both     0.82
#
# [216 rows x 6 columns]

# %%
## reconfigure dfs and output
reconfigure_df = True
save_files     = True
override_files = True
from pandas.errors import InvalidIndexError
for i, d in enumerate(dfx):
    df_key, df = d
    print(f"d {i:02d}")
    print(f"df_key: {df_key}")
    ## reconfigure df
    if reconfigure_df:
        try:
            df2 = df_reconfigure (df, df_key, check = False)
            print(df2)
        except InvalidIndexError:
            df2 = None
    else:
        df2 = df

    ## save data
    if save_files:
        if not df2 is None:
            if reconfigure_df:
                output_fname = f"{target_dir_path}/x-{'-'.join(df_key)}.csv"
            else:
                output_fname = f"{target_dir_path}/raw-x-{'-'.join(df_key)}.csv"    
            print(f"output_name: {output_fname}")
            try:
                import os
                if os.path.exists(output_fname):
                    if override_files:
                        df2.to_csv(output_fname, index = False)
                        print(f"file generated")
                    else:
                        pass
                else:
                    df2.to_csv(output_fname, index = False)
                    print(f"file generated")
            except AttributeError:
                #pass
                print(f"AttributionError occurred")
                print(f"failed to generate {output_fname}")
# Out:
# d 00
# df_key: ('German', 'sample3000', 'xsk', 'mgv3', '2', '20', '22', '11')
# skippy_means_extended: True
# lang_name: {'German'}
# attribute: plurality
# supplement: True
# supplement: False
# attribute: gender
# supplement: True
# supplement: False
# attribute: case
# supplement: True
# supplement: False
#      lang  attribute.index  attribute supplement  method.index method  \
# 0  German                1  plurality       True             3     NN
# 0  German                1  plurality      False             1     DT
# 0  German                1  plurality      False             3     NN
# 0  German                1  plurality       True             2     RF
# 0  German                1  plurality      False             2     RF
# 0  German                1  plurality       True             1     DT
# 0  German                2     gender      False             3     NN
# 0  German                2     gender      False             2     RF
# 0  German                2     gender       True             1     DT
# 0  German                2     gender       True             3     NN
# 0  German                2     gender       True             2     RF
# 0  German                2     gender      False             1     DT
# 0  German                3       case      False             2     RF
# 0  German                3       case       True             2     RF
# 0  German                3       case      False             1     DT
# 0  German                3       case       True             1     DT
# 0  German                3       case       True             3     NN
# 0  German                3       case      False             3     NN
#
#   2g-no-hash 3g-no-hash 4g-no-hash xsk2g-no-hash xsk3g-no-hash xsk4g-no-hash  \
# 0       0.84       0.84       0.83          0.82          0.78          0.78
# 0       0.79       0.84       0.79          0.78          0.74          0.74
# 0       0.81       0.80       0.79          0.79          0.78          0.80
# 0       0.85       0.89       0.85          0.82          0.84          0.85
# 0       0.80       0.86       0.83          0.82          0.82          0.82
# 0       0.75       0.84       0.85          0.78          0.79          0.79
# 0       0.54       0.56       0.65          0.53          0.62          0.63
# 0       0.59       0.60       0.66          0.54          0.61          0.59
# 0       0.55       0.53       0.56          0.53          0.53          0.53
# 0       0.55       0.59       0.64          0.58          0.58          0.60
# 0       0.63       0.61       0.66          0.62          0.61          0.60
# 0       0.51       0.55       0.57          0.49          0.51          0.51
# 0       0.40       0.38       0.39          0.46          0.39          0.40
# 0       0.44       0.39       0.41          0.46          0.38          0.39
# 0       0.35       0.35       0.42          0.37          0.34          0.32
# 0       0.34       0.36       0.35          0.38          0.40          0.33
# 0       0.34       0.33       0.35          0.35          0.32          0.34
# 0       0.35       0.33       0.37          0.37          0.36          0.34
#
#   2g-hash-at-both 3g-hash-at-both 4g-hash-at-both xsk2g-hash-at-both  \
# 0            0.82            0.82            0.80               0.80
# 0            0.77            0.76            0.76               0.78
# 0            0.78            0.78            0.77               0.76
# 0            0.83            0.81            0.85               0.85
# 0            0.81            0.80            0.80               0.81
# 0            0.80            0.80            0.76               0.78
# 0            0.57            0.55            0.58               0.56
# 0            0.56            0.62            0.55               0.63
# 0            0.51            0.54            0.58               0.51
# 0            0.57            0.53            0.64               0.59
# 0            0.61            0.62            0.56               0.64
# 0            0.50            0.51            0.51               0.55
# 0            0.38            0.41            0.42               0.47
# 0            0.46            0.42            0.41               0.45
# 0            0.36            0.40            0.34               0.37
# 0            0.33            0.41            0.39               0.43
# 0            0.38            0.36            0.36               0.40
# 0            0.29            0.34            0.34               0.37
#
#   xsk3g-hash-at-both xsk4g-hash-at-both   max
# 0               0.79               0.80  None
# 0               0.81               0.78  None
# 0               0.78               0.78  None
# 0               0.85               0.81  None
# 0               0.85               0.81  None
# 0               0.79               0.77  None
# 0               0.60               0.58  None
# 0               0.59               0.57  None
# 0               0.54               0.51  None
# 0               0.55               0.61  None
# 0               0.59               0.57  None
# 0               0.51               0.55  None
# 0               0.44               0.41  None
# 0               0.43               0.41  None
# 0               0.35               0.33  None
# 0               0.36               0.34  None
# 0               0.38               0.37  None
# 0               0.36               0.39  None
# output_name: results/3k/mgv3-xsk/x-German-sample3000-xsk-mgv3-2-20-22-11.csv
# file generated
# d 01
# df_key: ('Irish', 'sample3000', 'xsk', 'mgv3', '2', '21', '4', '35')
# skippy_means_extended: True
# lang_name: {'Irish'}
# attribute: plurality
# supplement: True
# supplement: False
# attribute: gender
# supplement: True
# supplement: False
# attribute: case
# supplement: True
# supplement: False
#     lang  attribute.index  attribute supplement  method.index method  \
# 0  Irish                1  plurality       True             3     NN
# 0  Irish                1  plurality      False             1     DT
# 0  Irish                1  plurality      False             3     NN
# 0  Irish                1  plurality       True             2     RF
# 0  Irish                1  plurality      False             2     RF
# 0  Irish                1  plurality       True             1     DT
# 0  Irish                2     gender      False             3     NN
# 0  Irish                2     gender      False             2     RF
# 0  Irish                2     gender       True             1     DT
# 0  Irish                2     gender       True             3     NN
# 0  Irish                2     gender       True             2     RF
# 0  Irish                2     gender      False             1     DT
# 0  Irish                3       case      False             2     RF
# 0  Irish                3       case       True             2     RF
# 0  Irish                3       case      False             1     DT
# 0  Irish                3       case       True             1     DT
# 0  Irish                3       case       True             3     NN
# 0  Irish                3       case      False             3     NN
#
#   2g-no-hash 3g-no-hash 4g-no-hash xsk2g-no-hash xsk3g-no-hash xsk4g-no-hash  \
# 0       0.68       0.69       0.72          0.73          0.68          0.64
# 0       0.63       0.63       0.66          0.69          0.62          0.66
# 0       0.64       0.62       0.64          0.70          0.66          0.63
# 0       0.73       0.70       0.69          0.72          0.71          0.68
# 0       0.67       0.67       0.70          0.70          0.70          0.68
# 0       0.74       0.70       0.69          0.69          0.68          0.68
# 0       0.72       0.71       0.77          0.76          0.71          0.76
# 0       0.74       0.73       0.74          0.76          0.76          0.78
# 0       0.81       0.75       0.76          0.73          0.70          0.74
# 0       0.78       0.74       0.78          0.77          0.77          0.77
# 0       0.84       0.75       0.81          0.73          0.76          0.80
# 0       0.67       0.69       0.75          0.71          0.69          0.73
# 0       0.95       0.96       0.96          0.97          0.95          0.98
# 0       0.96       0.96       0.96          0.97          0.95          0.98
# 0       0.95       0.95       0.95          0.96          0.94          0.98
# 0       0.96       0.96       0.96          0.97          0.95          0.97
# 0       0.95       0.96       0.96          0.97          0.95          0.98
# 0       0.95       0.96       0.96          0.97          0.95          0.98
#
#   2g-hash-at-both 3g-hash-at-both 4g-hash-at-both xsk2g-hash-at-both  \
# 0            0.65            0.67            0.68               0.66
# 0            0.63            0.63            0.64               0.62
# 0            0.59            0.58            0.62               0.65
# 0            0.73            0.69            0.72               0.75
# 0            0.65            0.65            0.68               0.67
# 0            0.71            0.67            0.66               0.66
# 0            0.73            0.68            0.77               0.73
# 0            0.74            0.75            0.76               0.76
# 0            0.77            0.75            0.78               0.70
# 0            0.78            0.77            0.78               0.76
# 0            0.80            0.78            0.75               0.77
# 0            0.70            0.70            0.65               0.68
# 0            0.97            0.96            0.95               0.98
# 0            0.97            0.96            0.96               0.98
# 0            0.96            0.96            0.96               0.98
# 0            0.97            0.97            0.95               0.96
# 0            0.97            0.96            0.96               0.98
# 0            0.97            0.96            0.96               0.98
#
#   xsk3g-hash-at-both xsk4g-hash-at-both   max
# 0               0.64               0.66  None
# 0               0.66               0.70  None
# 0               0.62               0.65  None
# 0               0.68               0.73  None
# 0               0.69               0.71  None
# 0               0.64               0.67  None
# 0               0.74               0.77  None
# 0               0.73               0.75  None
# 0               0.70               0.69  None
# 0               0.80               0.77  None
# 0               0.73               0.75  None
# 0               0.71               0.72  None
# 0               0.98               0.98  None
# 0               0.98               0.98  None
# 0               0.98               0.97  None
# 0               0.97               0.97  None
# 0               0.98               0.98  None
# 0               0.98               0.98  None
# output_name: results/3k/mgv3-xsk/x-Irish-sample3000-xsk-mgv3-2-21-4-35.csv
# file generated
# d 02
# df_key: ('Czech', 'sample3000', 'xsk', 'mgv3', '2', '20', '20', '35')
# skippy_means_extended: True
# lang_name: {'Czech'}
# attribute: plurality
# supplement: True
# supplement: False
# attribute: gender
# supplement: True
# supplement: False
# attribute: case
# supplement: True
# supplement: False
#     lang  attribute.index  attribute supplement  method.index method  \
# 0  Czech                1  plurality       True             3     NN
# 0  Czech                1  plurality      False             1     DT
# 0  Czech                1  plurality      False             3     NN
# 0  Czech                1  plurality       True             2     RF
# 0  Czech                1  plurality      False             2     RF
# 0  Czech                1  plurality       True             1     DT
# 0  Czech                2     gender      False             3     NN
# 0  Czech                2     gender      False             2     RF
# 0  Czech                2     gender       True             1     DT
# 0  Czech                2     gender       True             3     NN
# 0  Czech                2     gender       True             2     RF
# 0  Czech                2     gender      False             1     DT
# 0  Czech                3       case      False             2     RF
# 0  Czech                3       case       True             2     RF
# 0  Czech                3       case      False             1     DT
# 0  Czech                3       case       True             1     DT
# 0  Czech                3       case       True             3     NN
# 0  Czech                3       case      False             3     NN
#
#   2g-no-hash 3g-no-hash 4g-no-hash xsk2g-no-hash xsk3g-no-hash xsk4g-no-hash  \
# 0       0.87       0.86       0.86          0.87          0.87          0.77
# 0       0.84       0.82       0.80          0.86          0.84          0.76
# 0       0.80       0.80       0.76          0.87          0.85          0.77
# 0       0.89       0.86       0.87          0.89          0.87          0.83
# 0       0.84       0.82       0.82          0.84          0.85          0.79
# 0       0.86       0.87       0.79          0.87          0.81          0.75
# 0       0.60       0.69       0.69          0.70          0.70          0.70
# 0       0.61       0.63       0.68          0.63          0.68          0.61
# 0       0.56       0.59       0.43          0.58          0.58          0.45
# 0       0.66       0.66       0.69          0.72          0.71          0.65
# 0       0.58       0.67       0.73          0.68          0.72          0.65
# 0       0.51       0.58       0.55          0.55          0.55          0.50
# 0       0.48       0.47       0.44          0.39          0.48          0.44
# 0       0.57       0.55       0.51          0.46          0.54          0.50
# 0       0.40       0.43       0.38          0.34          0.38          0.35
# 0       0.48       0.35       0.50          0.43          0.46          0.33
# 0       0.52       0.47       0.51          0.40          0.44          0.39
# 0       0.39       0.41       0.41          0.39          0.41          0.37
#
#   2g-hash-at-both 3g-hash-at-both 4g-hash-at-both xsk2g-hash-at-both  \
# 0            0.89            0.85            0.86               0.82
# 0            0.74            0.81            0.80               0.81
# 0            0.76            0.77            0.78               0.80
# 0            0.84            0.89            0.87               0.88
# 0            0.81            0.85            0.81               0.83
# 0            0.84            0.83            0.84               0.82
# 0            0.64            0.65            0.68               0.70
# 0            0.68            0.68            0.70               0.66
# 0            0.59            0.56            0.61               0.50
# 0            0.67            0.69            0.68               0.65
# 0            0.71            0.69            0.71               0.66
# 0            0.62            0.54            0.54               0.54
# 0            0.39            0.48            0.43               0.41
# 0            0.56            0.61            0.56               0.51
# 0            0.37            0.42            0.39               0.37
# 0            0.53            0.57            0.46               0.38
# 0            0.49            0.50            0.54               0.43
# 0            0.37            0.38            0.40               0.41
#
#   xsk3g-hash-at-both xsk4g-hash-at-both   max
# 0               0.81               0.82  None
# 0               0.82               0.77  None
# 0               0.81               0.79  None
# 0               0.86               0.86  None
# 0               0.83               0.82  None
# 0               0.83               0.82  None
# 0               0.68               0.69  None
# 0               0.62               0.62  None
# 0               0.51               0.58  None
# 0               0.71               0.68  None
# 0               0.69               0.67  None
# 0               0.52               0.50  None
# 0               0.47               0.46  None
# 0               0.52               0.54  None
# 0               0.40               0.36  None
# 0               0.48               0.35  None
# 0               0.45               0.40  None
# 0               0.43               0.35  None
# output_name: results/3k/mgv3-xsk/x-Czech-sample3000-xsk-mgv3-2-20-20-35.csv
# file generated
# d 03
# df_key: ('French', 'sample3000', 'xsk', 'mgv3', '2', '20', '21', '31')
# skippy_means_extended: True
# lang_name: {'French'}
# attribute: plurality
# supplement: True
# supplement: False
# attribute: gender
# supplement: True
# supplement: False
#      lang  attribute.index  attribute supplement  method.index method  \
# 0  French                1  plurality       True             1     DT
# 0  French                1  plurality       True             2     RF
# 0  French                1  plurality       True             3     NN
# 0  French                1  plurality      False             1     DT
# 0  French                1  plurality      False             2     RF
# 0  French                1  plurality      False             3     NN
# 0  French                2     gender       True             1     DT
# 0  French                2     gender       True             2     RF
# 0  French                2     gender       True             3     NN
# 0  French                2     gender      False             1     DT
# 0  French                2     gender      False             2     RF
# 0  French                2     gender      False             3     NN
#
#   2g-no-hash 3g-no-hash 4g-no-hash xsk2g-no-hash xsk3g-no-hash xsk4g-no-hash  \
# 0       0.91       0.90       0.92          0.94          0.81          0.85
# 0       0.93       0.94       0.93          0.97          0.94          0.95
# 0       0.93       0.96       0.95          0.96          0.94          0.94
# 0       0.88       0.90       0.91          0.90          0.83          0.91
# 0       0.94       0.92       0.93          0.96          0.94          0.94
# 0       0.93       0.94       0.95          0.96          0.95          0.96
# 0       0.72       0.70       0.75          0.76          0.72          0.74
# 0       0.85       0.76       0.81          0.82          0.82          0.83
# 0       0.78       0.76       0.79          0.81          0.76          0.80
# 0       0.75       0.69       0.71          0.71          0.77          0.75
# 0       0.82       0.77       0.79          0.82          0.80          0.83
# 0       0.79       0.80       0.80          0.78          0.83          0.82
#
#   2g-hash-at-both 3g-hash-at-both 4g-hash-at-both xsk2g-hash-at-both  \
# 0            0.88            0.88            0.90               0.91
# 0            0.91            0.93            0.89               0.94
# 0            0.92            0.93            0.91               0.95
# 0            0.86            0.89            0.82               0.91
# 0            0.90            0.92            0.90               0.92
# 0            0.90            0.95            0.91               0.95
# 0            0.70            0.72            0.73               0.74
# 0            0.81            0.79            0.81               0.81
# 0            0.79            0.78            0.78               0.80
# 0            0.69            0.68            0.70               0.71
# 0            0.77            0.81            0.81               0.81
# 0            0.79            0.82            0.81               0.82
#
#   xsk3g-hash-at-both xsk4g-hash-at-both   max
# 0               0.85               0.89  None
# 0               0.94               0.95  None
# 0               0.96               0.93  None
# 0               0.91               0.80  None
# 0               0.95               0.95  None
# 0               0.95               0.93  None
# 0               0.70               0.68  None
# 0               0.83               0.81  None
# 0               0.81               0.79  None
# 0               0.69               0.77  None
# 0               0.82               0.78  None
# 0               0.80               0.78  None
# output_name: results/3k/mgv3-xsk/x-French-sample3000-xsk-mgv3-2-20-21-31.csv
# file generated
# d 04
# df_key: ('Czech2', '3000', 'xsk', 'mgv3', '3', '3', '12', '48')
# skippy_means_extended: True
# lang_name: {'Czech'}
# attribute: plurality
# supplement: True
# supplement: False
# attribute: gender2
# supplement: True
# supplement: False
# attribute: case
# supplement: True
# supplement: False
#     lang  attribute.index  attribute supplement  method.index method  \
# 0  Czech                1  plurality       True             3     NN
# 0  Czech                1  plurality      False             1     DT
# 0  Czech                1  plurality      False             3     NN
# 0  Czech                1  plurality       True             2     RF
# 0  Czech                1  plurality      False             2     RF
# 0  Czech                1  plurality       True             1     DT
# 0  Czech                2    gender2      False             3     NN
# 0  Czech                2    gender2      False             2     RF
# 0  Czech                2    gender2       True             1     DT
# 0  Czech                2    gender2       True             3     NN
# 0  Czech                2    gender2       True             2     RF
# 0  Czech                2    gender2      False             1     DT
# 0  Czech                3       case      False             2     RF
# 0  Czech                3       case       True             2     RF
# 0  Czech                3       case      False             1     DT
# 0  Czech                3       case       True             1     DT
# 0  Czech                3       case       True             3     NN
# 0  Czech                3       case      False             3     NN
#
#   2g-no-hash 3g-no-hash 4g-no-hash xsk2g-no-hash xsk3g-no-hash xsk4g-no-hash  \
# 0       0.94       0.90       0.87          0.88          0.83          0.86
# 0       0.81       0.85       0.80          0.85          0.81          0.83
# 0       0.81       0.86       0.77          0.85          0.81          0.88
# 0       0.90       0.91       0.89          0.92          0.84          0.90
# 0       0.84       0.86       0.85          0.90          0.82          0.87
# 0       0.91       0.86       0.89          0.89          0.80          0.83
# 0       0.76       0.71       0.75          0.74          0.76          0.74
# 0       0.76       0.73       0.71          0.70          0.74          0.74
# 0       0.92       0.92       0.80          0.80          0.70          0.65
# 0       0.94       0.91       0.91          0.91          0.92          0.91
# 0       0.95       0.93       0.91          0.89          0.89          0.91
# 0       0.61       0.59       0.65          0.63          0.62          0.62
# 0       0.45       0.48       0.47          0.40          0.45          0.45
# 0       0.59       0.56       0.55          0.56          0.52          0.51
# 0       0.41       0.39       0.46          0.43          0.32          0.32
# 0       0.55       0.54       0.48          0.45          0.41          0.45
# 0       0.54       0.49       0.52          0.43          0.38          0.41
# 0       0.46       0.40       0.47          0.40          0.36          0.40
#
#   2g-hash-at-both 3g-hash-at-both 4g-hash-at-both xsk2g-hash-at-both  \
# 0            0.88            0.91            0.87               0.85
# 0            0.80            0.82            0.77               0.84
# 0            0.82            0.82            0.82               0.84
# 0            0.90            0.85            0.86               0.88
# 0            0.83            0.83            0.80               0.86
# 0            0.88            0.93            0.85               0.87
# 0            0.66            0.77            0.77               0.71
# 0            0.71            0.74            0.77               0.73
# 0            0.93            0.89            0.85               0.77
# 0            0.93            0.92            0.94               0.93
# 0            0.93            0.92            0.90               0.93
# 0            0.63            0.66            0.67               0.62
# 0            0.45            0.48            0.44               0.44
# 0            0.52            0.59            0.54               0.49
# 0            0.43            0.42            0.43               0.43
# 0            0.49            0.56            0.52               0.51
# 0            0.46            0.55            0.51               0.40
# 0            0.40            0.45            0.39               0.38
#
#   xsk3g-hash-at-both xsk4g-hash-at-both   max
# 0               0.85               0.82  None
# 0               0.83               0.80  None
# 0               0.82               0.82  None
# 0               0.88               0.83  None
# 0               0.85               0.84  None
# 0               0.81               0.79  None
# 0               0.74               0.70  None
# 0               0.68               0.71  None
# 0               0.64               0.79  None
# 0               0.92               0.90  None
# 0               0.92               0.89  None
# 0               0.62               0.57  None
# 0               0.48               0.43  None
# 0               0.49               0.50  None
# 0               0.42               0.32  None
# 0               0.47               0.42  None
# 0               0.41               0.39  None
# 0               0.41               0.39  None
# output_name: results/3k/mgv3-xsk/x-Czech2-3000-xsk-mgv3-3-3-12-48.csv
# file generated
