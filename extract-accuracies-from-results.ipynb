# %%
## process files
import glob
import pprint
target_dir = '3k/mgv9-sk'
files = glob.glob(f"results/{target_dir}/*")
verbose = False
if verbose:
    pprint.pprint(files)

## filter files
sample_n = 3000
import re
data_files = [ file for file in files if re.match(f".*result-.*{sample_n}.*.txt", file) ]
pprint.pprint(data_files)

# %%
## extract values
import io, re
method_names = [ 'DT', 'RF', 'NN', 'MM' ]
attr_names   = [ 'gender', 'plurality', 'case']
trueness     = [ 'True]', 'False]' ]
lang_names   = [ 'Czech', 'French', 'German', 'Irish' ]
term_names   = [ f"{x}{y}gram{z}" for x in [ '', 'skippy', 'xskippy' ]
                                    for y in range(2,5)
                                    for z in ['-no-hash', '-hash-at-both'] ]
print(f"term_names: {term_names}")
registered_vals = method_names + lang_names + attr_names + trueness + term_names
print(f"registered_vales: {registered_vals}")
# Out:
# ['results/3k/mgv9-sk/result-French-sample3000-mgv9-2024-12-27-22-40.txt',
#  'results/3k/mgv9-sk/result-Czech-sample3000-mgv9-2024-12-27-21-29.txt',
#  'results/3k/mgv9-sk/result-Irish-sample3000-mgv9-2024-12-28-8-50.txt',
#  'results/3k/mgv9-sk/result-German-sample3000-mgv9-2024-12-28-2-17.txt']
# term_names: ['2gram-no-hash', '2gram-hash-at-both', '3gram-no-hash', '3gram-hash-at-both', '4gram-no-hash', '4gram-hash-at-both', 'skippy2gram-no-hash', 'skippy2gram-hash-at-both', 'skippy3gram-no-hash', 'skippy3gram-hash-at-both', 'skippy4gram-no-hash', 'skippy4gram-hash-at-both', 'xskippy2gram-no-hash', 'xskippy2gram-hash-at-both', 'xskippy3gram-no-hash', 'xskippy3gram-hash-at-both', 'xskippy4gram-no-hash', 'xskippy4gram-hash-at-both']
# registered_vales: ['DT', 'RF', 'NN', 'MM', 'Czech', 'French', 'German', 'Irish', 'gender', 'plurality', 'case', 'True]', 'False]', '2gram-no-hash', '2gram-hash-at-both', '3gram-no-hash', '3gram-hash-at-both', '4gram-no-hash', '4gram-hash-at-both', 'skippy2gram-no-hash', 'skippy2gram-hash-at-both', 'skippy3gram-no-hash', 'skippy3gram-hash-at-both', 'skippy4gram-no-hash', 'skippy4gram-hash-at-both', 'xskippy2gram-no-hash', 'xskippy2gram-hash-at-both', 'xskippy3gram-no-hash', 'xskippy3gram-hash-at-both', 'xskippy4gram-no-hash', 'xskippy4gram-hash-at-both']

# %%
def extract_data (lines, check: bool = False):
    import re
    lines = [ re.split(r"\s\s+", line.strip()) for line in lines if len(line) > 1 ]
    d = []
    for i, line in enumerate(lines):
        if line[0] in [ 'accuracy' ]:
            if check:
                print(f"target_value on: {line}")
            target_accuracy = line[1]
            try:
                candidate_line = lines[i-5]
                if check:
                    print(f"candidate_line1: {candidate_line}")
                if "classification" in candidate_line[0]:
                    method_line = candidate_line
                    if check:
                        print(f"method_line: {method_line}")
                    d.append((method_line, target_accuracy))
                else:
                    candidate_line = lines[i-4]
                    if check:
                        print(f"candidate_line2: {candidate_line}")
                    if "classification" in candidate_line[0]:
                        method_line = candidate_line
                        if check:
                            print(f"method_line: {method_line}")
                        d.append((method_line, target_accuracy))
                    else:
                        candidate_line = lines[i-3]
                        if check:
                            print(f"candidate_line3: {candidate_line}")
                        if "classification" in candidate_line[0]:
                            method_line = candidate_line
                            if check:
                                print(f"method_line: {method_line}")
                            d.append((method_line, target_accuracy))
                if check:
                    print(f"method_line: {method_line}")
            except ValueError:
                pass
    if check:
        print(f"d: {d}")
    return d

# %%
def extract_values (records, registered: list, check: bool = False):
    import re
    R = []
    for record in records:
        if check:
            print(f"record: {record}")
        method, accuracy = record
        F = [ field for field in re.split(r"\s+", method[0]) if field in registered ]
        F = [ 'NN' if x == 'MM' else x for x in F ]
        F = [ 'True' if x == 'True]' else x for x in F ]
        F = [ 'False' if x == 'False]' else x for x in F ]
        F.append(accuracy)
        R.append(F)
    return R

# %%
## extract values and generate output files
import pandas as pd
check = True
dfs = []
for file in data_files:
    fn_fields = re.split(r"-", file)
    lang_setting, sample, term_setting, mgv, year, month, day, hour, minute = \
        fn_fields[1], fn_fields[2], fn_fields[3], fn_fields[4], fn_fields[5], fn_fields[6], fn_fields[7], fn_fields[8], fn_fields[9]
    if check:
        print(f"opening {file}")
    with io.open(file, encoding = 'utf-8_sig') as f:
        lines = [ line.strip() for line in f.readlines() if len(line) > 0 ]
        if not len(lines) > 1:
            continue
        records = extract_values (extract_data (lines), registered_vals)
    if check:
        print(records)
    ##
    records_rev = []
    for i, record in enumerate(records):
        print(f"record {i:03d}: {record} [type: {type(record)}]")
        if len(record) < 6:
            print(f"found invalid record")
            print(record)
            lang_present = any(map(lambda x: x in record, lang_names))
            print(f"lang_present: {lang_present}")
            if not lang_present:
                record.insert(3, last_lang_name)
            term_present = any(map(lambda x: x in record, term_names))
            print(f"term_present: {term_present}")
            if not term_present:
                record.insert(4, "missing")
            print(f"modified {i}: {record} [type: {type(record)}]")
            records_rev.append(record)
        else:
            records_rev.append(record)
            last_lang_name = [ x for x in record if x in lang_names ][0]
    ##
    df = pd.DataFrame(columns = [ 'lang', 'method', 'attribute', 'supplement', 'term_type', 'accuracy'])
    for i, record in enumerate(records_rev):
        print(f"record {i}: {record}")
        method, attr, supplement, lang, term, accuracy = record
        df.loc[i] = [lang, attr, supplement, method, term, accuracy]
    dfs.append(((term_setting, sample, lang, mgv, month, day, hour, minute), df))
# Out:
# opening results/3k/mgv9-sk/result-French-sample3000-mgv9-2024-12-27-22-40.txt
# [['DT', 'gender', 'True', 'French', '2gram-no-hash', '0.74'], ['RF', 'gender', 'True', '0.83'], ['NN', 'gender', 'True', 'French', '2gram-no-hash', '0.77'], ['DT', 'gender', 'False', 'French', '2gram-no-hash', '0.75'], ['RF', 'gender', 'False', '0.83'], ['NN', 'gender', 'False', 'French', '2gram-no-hash', '0.78'], ['DT', 'plurality', 'True', 'French', '2gram-no-hash', '0.90'], ['RF', 'plurality', 'True', '0.91'], ['NN', 'plurality', 'True', 'French', '2gram-no-hash', '0.92'], ['DT', 'plurality', 'False', 'French', '2gram-no-hash', '0.93'], ['RF', 'plurality', 'False', '0.93'], ['NN', 'plurality', 'False', 'French', '2gram-no-hash', '0.94'], ['DT', 'gender', 'True', 'French', '3gram-no-hash', '0.73'], ['RF', 'gender', 'True', '0.74'], ['NN', 'gender', 'True', 'French', '3gram-no-hash', '0.77'], ['DT', 'gender', 'False', 'French', '3gram-no-hash', '0.74'], ['RF', 'gender', 'False', '0.79'], ['NN', 'gender', 'False', 'French', '3gram-no-hash', '0.77'], ['DT', 'plurality', 'True', 'French', '3gram-no-hash', '0.92'], ['RF', 'plurality', 'True', '0.95'], ['NN', 'plurality', 'True', 'French', '3gram-no-hash', '0.94'], ['DT', 'plurality', 'False', 'French', '3gram-no-hash', '0.89'], ['RF', 'plurality', 'False', '0.94'], ['NN', 'plurality', 'False', 'French', '3gram-no-hash', '0.95'], ['DT', 'gender', 'True', 'French', '4gram-no-hash', '0.74'], ['RF', 'gender', 'True', '0.81'], ['NN', 'gender', 'True', 'French', '4gram-no-hash', '0.81'], ['DT', 'gender', 'False', 'French', '4gram-no-hash', '0.72'], ['RF', 'gender', 'False', '0.82'], ['NN', 'gender', 'False', 'French', '4gram-no-hash', '0.81'], ['DT', 'plurality', 'True', 'French', '4gram-no-hash', '0.93'], ['RF', 'plurality', 'True', '0.94'], ['NN', 'plurality', 'True', 'French', '4gram-no-hash', '0.97'], ['DT', 'plurality', 'False', 'French', '4gram-no-hash', '0.89'], ['RF', 'plurality', 'False', '0.92'], ['NN', 'plurality', 'False', 'French', '4gram-no-hash', '0.96'], ['DT', 'gender', 'True', 'French', 'skippy2gram-no-hash', '0.73'], ['RF', 'gender', 'True', '0.80'], ['NN', 'gender', 'True', 'French', 'skippy2gram-no-hash', '0.77'], ['DT', 'gender', 'False', 'French', 'skippy2gram-no-hash', '0.72'], ['RF', 'gender', 'False', '0.78'], ['NN', 'gender', 'False', 'French', 'skippy2gram-no-hash', '0.75'], ['DT', 'plurality', 'True', 'French', 'skippy2gram-no-hash', '0.93'], ['RF', 'plurality', 'True', '0.93'], ['NN', 'plurality', 'True', 'French', 'skippy2gram-no-hash', '0.95'], ['DT', 'plurality', 'False', 'French', 'skippy2gram-no-hash', '0.88'], ['RF', 'plurality', 'False', '0.93'], ['NN', 'plurality', 'False', 'French', 'skippy2gram-no-hash', '0.95'], ['DT', 'gender', 'True', 'French', 'skippy3gram-no-hash', '0.62'], ['RF', 'gender', 'True', '0.75'], ['NN', 'gender', 'True', 'French', 'skippy3gram-no-hash', '0.78'], ['DT', 'gender', 'False', 'French', 'skippy3gram-no-hash', '0.65'], ['RF', 'gender', 'False', '0.73'], ['NN', 'gender', 'False', 'French', 'skippy3gram-no-hash', '0.76'], ['DT', 'plurality', 'True', 'French', 'skippy3gram-no-hash', '0.87'], ['RF', 'plurality', 'True', '0.92'], ['NN', 'plurality', 'True', 'French', 'skippy3gram-no-hash', '0.96'], ['DT', 'plurality', 'False', 'French', 'skippy3gram-no-hash', '0.86'], ['RF', 'plurality', 'False', '0.92'], ['NN', 'plurality', 'False', 'French', 'skippy3gram-no-hash', '0.96'], ['DT', 'gender', 'True', 'French', 'skippy4gram-no-hash', '0.70'], ['RF', 'gender', 'True', '0.80'], ['NN', 'gender', 'True', 'French', 'skippy4gram-no-hash', '0.78'], ['DT', 'gender', 'False', 'French', 'skippy4gram-no-hash', '0.72'], ['RF', 'gender', 'False', '0.80'], ['NN', 'gender', 'False', 'French', 'skippy4gram-no-hash', '0.76'], ['DT', 'plurality', 'True', 'French', 'skippy4gram-no-hash', '0.86'], ['RF', 'plurality', 'True', '0.90'], ['NN', 'plurality', 'True', 'French', 'skippy4gram-no-hash', '0.95'], ['DT', 'plurality', 'False', 'French', 'skippy4gram-no-hash', '0.75'], ['RF', 'plurality', 'False', '0.91'], ['NN', 'plurality', 'False', 'French', ...
# record 000: ['DT', 'gender', 'True', 'French', '2gram-no-hash', '0.74'] [type: <class 'list'>]
# record 001: ['RF', 'gender', 'True', '0.83'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'True', '0.83']
# lang_present: False
# term_present: False
# modified 1: ['RF', 'gender', 'True', 'French', 'missing', '0.83'] [type: <class 'list'>]
# record 002: ['NN', 'gender', 'True', 'French', '2gram-no-hash', '0.77'] [type: <class 'list'>]
# record 003: ['DT', 'gender', 'False', 'French', '2gram-no-hash', '0.75'] [type: <class 'list'>]
# record 004: ['RF', 'gender', 'False', '0.83'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'False', '0.83']
# lang_present: False
# term_present: False
# modified 4: ['RF', 'gender', 'False', 'French', 'missing', '0.83'] [type: <class 'list'>]
# record 005: ['NN', 'gender', 'False', 'French', '2gram-no-hash', '0.78'] [type: <class 'list'>]
# record 006: ['DT', 'plurality', 'True', 'French', '2gram-no-hash', '0.90'] [type: <class 'list'>]
# record 007: ['RF', 'plurality', 'True', '0.91'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.91']
# lang_present: False
# term_present: False
# modified 7: ['RF', 'plurality', 'True', 'French', 'missing', '0.91'] [type: <class 'list'>]
# record 008: ['NN', 'plurality', 'True', 'French', '2gram-no-hash', '0.92'] [type: <class 'list'>]
# record 009: ['DT', 'plurality', 'False', 'French', '2gram-no-hash', '0.93'] [type: <class 'list'>]
# record 010: ['RF', 'plurality', 'False', '0.93'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.93']
# lang_present: False
# term_present: False
# modified 10: ['RF', 'plurality', 'False', 'French', 'missing', '0.93'] [type: <class 'list'>]
# record 011: ['NN', 'plurality', 'False', 'French', '2gram-no-hash', '0.94'] [type: <class 'list'>]
# record 012: ['DT', 'gender', 'True', 'French', '3gram-no-hash', '0.73'] [type: <class 'list'>]
# record 013: ['RF', 'gender', 'True', '0.74'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'True', '0.74']
# lang_present: False
# term_present: False
# modified 13: ['RF', 'gender', 'True', 'French', 'missing', '0.74'] [type: <class 'list'>]
# record 014: ['NN', 'gender', 'True', 'French', '3gram-no-hash', '0.77'] [type: <class 'list'>]
# record 015: ['DT', 'gender', 'False', 'French', '3gram-no-hash', '0.74'] [type: <class 'list'>]
# record 016: ['RF', 'gender', 'False', '0.79'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'False', '0.79']
# lang_present: False
# term_present: False
# modified 16: ['RF', 'gender', 'False', 'French', 'missing', '0.79'] [type: <class 'list'>]
# record 017: ['NN', 'gender', 'False', 'French', '3gram-no-hash', '0.77'] [type: <class 'list'>]
# record 018: ['DT', 'plurality', 'True', 'French', '3gram-no-hash', '0.92'] [type: <class 'list'>]
# record 019: ['RF', 'plurality', 'True', '0.95'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.95']
# lang_present: False
# term_present: False
# modified 19: ['RF', 'plurality', 'True', 'French', 'missing', '0.95'] [type: <class 'list'>]
# record 020: ['NN', 'plurality', 'True', 'French', '3gram-no-hash', '0.94'] [type: <class 'list'>]
# record 021: ['DT', 'plurality', 'False', 'French', '3gram-no-hash', '0.89'] [type: <class 'list'>]
# record 022: ['RF', 'plurality', 'False', '0.94'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.94']
# lang_present: False
# term_present: False
# modified 22: ['RF', 'plurality', 'False', 'French', 'missing', '0.94'] [type: <class 'list'>]
# record 023: ['NN', 'plurality', 'False', 'French', '3gram-no-hash', '0.95'] [type: <class 'list'>]
# record 024: ['DT', 'gender', 'True', 'French', '4gram-no-hash', '0.74'] [type: <class 'list'>]
# record 025: ['RF', 'gender', 'True', '0.81'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'True', '0.81']
# lang_present: False
# term_present: False
# modified 25: ['RF', 'gender', 'True', 'French', 'missing', '0.81'] [type: <class 'list'>]
# record 026: ['NN', 'gender', 'True', 'French', '4gram-no-hash', '0.81'] [type: <class 'list'>]
# record 027: ['DT', 'gender', 'False', 'French', '4gram-no-hash', '0.72'] [type: <class 'list'>]
# record 028: ['RF', 'gender', 'False', '0.82'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'False', '0.82']
# lang_present: False
# term_present: False
# modified 28: ['RF', 'gender', 'False', 'French', 'missing', '0.82'] [type: <class 'list'>]
# record 029: ['NN', 'gender', 'False', 'French', '4gram-no-hash', '0.81'] [type: <class 'list'>]
# record 030: ['DT', 'plurality', 'True', 'French', '4gram-no-hash', '0.93'] [type: <class 'list'>]
# record 031: ['RF', 'plurality', 'True', '0.94'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.94']
# lang_present: False
# term_present: False
# modified 31: ['RF', 'plurality', 'True', 'French', 'missing', '0.94'] [type: <class 'list'>]
# record 032: ['NN', 'plurality', 'True', 'French', '4gram-no-hash', '0.97'] [type: <class 'list'>]
# record 033: ['DT', 'plurality', 'False', 'French', '4gram-no-hash', '0.89'] [type: <class 'list'>]
# record 034: ['RF', 'plurality', 'False', '0.92'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.92']
# lang_present: False
# term_present: False
# modified 34: ['RF', 'plurality', 'False', 'French', 'missing', '0.92'] [type: <class 'list'>]
# record 035: ['NN', 'plurality', 'False', 'French', '4gram-no-hash', '0.96'] [type: <class 'list'>]
# record 036: ['DT', 'gender', 'True', 'French', 'skippy2gram-no-hash', '0.73'] [type: <class 'list'>]
# record 037: ['RF', 'gender', 'True', '0.80'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'True', '0.80']
# lang_present: False
# term_present: False
# modified 37: ['RF', 'gender', 'True', 'French', 'missing', '0.80'] [type: <class 'list'>]
# record 038: ['NN', 'gender', 'True', 'French', 'skippy2gram-no-hash', '0.77'] [type: <class 'list'>]
# record 039: ['DT', 'gender', 'False', 'French', 'skippy2gram-no-hash', '0.72'] [type: <class 'list'>]
# record 040: ['RF', 'gender', 'False', '0.78'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'False', '0.78']
# lang_present: False
# term_present: False
# modified 40: ['RF', 'gender', 'False', 'French', 'missing', '0.78'] [type: <class 'list'>]
# record 041: ['NN', 'gender', 'False', 'French', 'skippy2gram-no-hash', '0.75'] [type: <class 'list'>]
# record 042: ['DT', 'plurality', 'True', 'French', 'skippy2gram-no-hash', '0.93'] [type: <class 'list'>]
# record 043: ['RF', 'plurality', 'True', '0.93'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.93']
# lang_present: False
# term_present: False
# modified 43: ['RF', 'plurality', 'True', 'French', 'missing', '0.93'] [type: <class 'list'>]
# record 044: ['NN', 'plurality', 'True', 'French', 'skippy2gram-no-hash', '0.95'] [type: <class 'list'>]
# record 045: ['DT', 'plurality', 'False', 'French', 'skippy2gram-no-hash', '0.88'] [type: <class 'list'>]
# record 046: ['RF', 'plurality', 'False', '0.93'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.93']
# lang_present: False
# term_present: False
# modified 46: ['RF', 'plurality', 'False', 'French', 'missing', '0.93'] [type: <class 'list'>]
# record 047: ['NN', 'plurality', 'False', 'French', 'skippy2gram-no-hash', '0.95'] [type: <class 'list'>]
# record 048: ['DT', 'gender', 'True', 'French', 'skippy3gram-no-hash', '0.62'] [type: <class 'list'>]
# record 049: ['RF', 'gender', 'True', '0.75'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'True', '0.75']
# lang_present: False
# term_present: False
# modified 49: ['RF', 'gender', 'True', 'French', 'missing', '0.75'] [type: <class 'list'>]
# record 050: ['NN', 'gender', 'True', 'French', 'skippy3gram-no-hash', '0.78'] [type: <class 'list'>]
# record 051: ['DT', 'gender', 'False', 'French', 'skippy3gram-no-hash', '0.65'] [type: <class 'list'>]
# record 052: ['RF', 'gender', 'False', '0.73'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'False', '0.73']
# lang_present: False
# term_present: False
# modified 52: ['RF', 'gender', 'False', 'French', 'missing', '0.73'] [type: <class 'list'>]
# record 053: ['NN', 'gender', 'False', 'French', 'skippy3gram-no-hash', '0.76'] [type: <class 'list'>]
# record 054: ['DT', 'plurality', 'True', 'French', 'skippy3gram-no-hash', '0.87'] [type: <class 'list'>]
# record 055: ['RF', 'plurality', 'True', '0.92'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.92']
# lang_present: False
# term_present: False
# modified 55: ['RF', 'plurality', 'True', 'French', 'missing', '0.92'] [type: <class 'list'>]
# record 056: ['NN', 'plurality', 'True', 'French', 'skippy3gram-no-hash', '0.96'] [type: <class 'list'>]
# record 057: ['DT', 'plurality', 'False', 'French', 'skippy3gram-no-hash', '0.86'] [type: <class 'list'>]
# record 058: ['RF', 'plurality', 'False', '0.92'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.92']
# lang_present: False
# term_present: False
# modified 58: ['RF', 'plurality', 'False', 'French', 'missing', '0.92'] [type: <class 'list'>]
# record 059: ['NN', 'plurality', 'False', 'French', 'skippy3gram-no-hash', '0.96'] [type: <class 'list'>]
# record 060: ['DT', 'gender', 'True', 'French', 'skippy4gram-no-hash', '0.70'] [type: <class 'list'>]
# record 061: ['RF', 'gender', 'True', '0.80'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'True', '0.80']
# lang_present: False
# term_present: False
# modified 61: ['RF', 'gender', 'True', 'French', 'missing', '0.80'] [type: <class 'list'>]
# record 062: ['NN', 'gender', 'True', 'French', 'skippy4gram-no-hash', '0.78'] [type: <class 'list'>]
# record 063: ['DT', 'gender', 'False', 'French', 'skippy4gram-no-hash', '0.72'] [type: <class 'list'>]
# record 064: ['RF', 'gender', 'False', '0.80'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'False', '0.80']
# lang_present: False
# term_present: False
# modified 64: ['RF', 'gender', 'False', 'French', 'missing', '0.80'] [type: <class 'list'>]
# record 065: ['NN', 'gender', 'False', 'French', 'skippy4gram-no-hash', '0.76'] [type: <class 'list'>]
# record 066: ['DT', 'plurality', 'True', 'French', 'skippy4gram-no-hash', '0.86'] [type: <class 'list'>]
# record 067: ['RF', 'plurality', 'True', '0.90'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.90']
# lang_present: False
# term_present: False
# modified 67: ['RF', 'plurality', 'True', 'French', 'missing', '0.90'] [type: <class 'list'>]
# record 068: ['NN', 'plurality', 'True', 'French', 'skippy4gram-no-hash', '0.95'] [type: <class 'list'>]
# record 069: ['DT', 'plurality', 'False', 'French', 'skippy4gram-no-hash', '0.75'] [type: <class 'list'>]
# record 070: ['RF', 'plurality', 'False', '0.91'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.91']
# lang_present: False
# term_present: False
# modified 70: ['RF', 'plurality', 'False', 'French', 'missing', '0.91'] [type: <class 'list'>]
# record 071: ['NN', 'plurality', 'False', 'French', 'skippy4gram-no-hash', '0.94'] [type: <class 'list'>]
# record 072: ['DT', 'gender', 'True', 'French', '2gram-hash-at-both', '0.77'] [type: <class 'list'>]
# record 073: ['RF', 'gender', 'True', '0.81'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'True', '0.81']
# lang_present: False
# term_present: False
# modified 73: ['RF', 'gender', 'True', 'French', 'missing', '0.81'] [type: <class 'list'>]
# record 074: ['NN', 'gender', 'True', 'French', '2gram-hash-at-both', '0.83'] [type: <class 'list'>]
# record 075: ['DT', 'gender', 'False', 'French', '2gram-hash-at-both', '0.73'] [type: <class 'list'>]
# record 076: ['RF', 'gender', 'False', '0.81'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'False', '0.81']
# lang_present: False
# term_present: False
# modified 76: ['RF', 'gender', 'False', 'French', 'missing', '0.81'] [type: <class 'list'>]
# record 077: ['NN', 'gender', 'False', 'French', '2gram-hash-at-both', '0.79'] [type: <class 'list'>]
# record 078: ['DT', 'plurality', 'True', 'French', '2gram-hash-at-both', '0.87'] [type: <class 'list'>]
# record 079: ['RF', 'plurality', 'True', '0.92'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.92']
# lang_present: False
# term_present: False
# modified 79: ['RF', 'plurality', 'True', 'French', 'missing', '0.92'] [type: <class 'list'>]
# record 080: ['NN', 'plurality', 'True', 'French', '2gram-hash-at-both', '0.92'] [type: <class 'list'>]
# record 081: ['DT', 'plurality', 'False', 'French', '2gram-hash-at-both', '0.90'] [type: <class 'list'>]
# record 082: ['RF', 'plurality', 'False', '0.92'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.92']
# lang_present: False
# term_present: False
# modified 82: ['RF', 'plurality', 'False', 'French', 'missing', '0.92'] [type: <class 'list'>]
# record 083: ['NN', 'plurality', 'False', 'French', '2gram-hash-at-both', '0.94'] [type: <class 'list'>]
# record 084: ['DT', 'gender', 'True', 'French', '3gram-hash-at-both', '0.75'] [type: <class 'list'>]
# record 085: ['RF', 'gender', 'True', '0.80'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'True', '0.80']
# lang_present: False
# term_present: False
# modified 85: ['RF', 'gender', 'True', 'French', 'missing', '0.80'] [type: <class 'list'>]
# record 086: ['NN', 'gender', 'True', 'French', '3gram-hash-at-both', '0.75'] [type: <class 'list'>]
# record 087: ['DT', 'gender', 'False', 'French', '3gram-hash-at-both', '0.69'] [type: <class 'list'>]
# record 088: ['RF', 'gender', 'False', '0.79'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'False', '0.79']
# lang_present: False
# term_present: False
# modified 88: ['RF', 'gender', 'False', 'French', 'missing', '0.79'] [type: <class 'list'>]
# record 089: ['NN', 'gender', 'False', 'French', '3gram-hash-at-both', '0.72'] [type: <class 'list'>]
# record 090: ['DT', 'plurality', 'True', 'French', '3gram-hash-at-both', '0.92'] [type: <class 'list'>]
# record 091: ['RF', 'plurality', 'True', '0.95'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.95']
# lang_present: False
# term_present: False
# modified 91: ['RF', 'plurality', 'True', 'French', 'missing', '0.95'] [type: <class 'list'>]
# record 092: ['NN', 'plurality', 'True', 'French', '3gram-hash-at-both', '0.94'] [type: <class 'list'>]
# record 093: ['DT', 'plurality', 'False', 'French', '3gram-hash-at-both', '0.93'] [type: <class 'list'>]
# record 094: ['RF', 'plurality', 'False', '0.95'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.95']
# lang_present: False
# term_present: False
# modified 94: ['RF', 'plurality', 'False', 'French', 'missing', '0.95'] [type: <class 'list'>]
# record 095: ['NN', 'plurality', 'False', 'French', '3gram-hash-at-both', '0.94'] [type: <class 'list'>]
# record 096: ['DT', 'gender', 'True', 'French', '4gram-hash-at-both', '0.74'] [type: <class 'list'>]
# record 097: ['RF', 'gender', 'True', '0.80'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'True', '0.80']
# lang_present: False
# term_present: False
# modified 97: ['RF', 'gender', 'True', 'French', 'missing', '0.80'] [type: <class 'list'>]
# record 098: ['NN', 'gender', 'True', 'French', '4gram-hash-at-both', '0.77'] [type: <class 'list'>]
# record 099: ['DT', 'gender', 'False', 'French', '4gram-hash-at-both', '0.68'] [type: <class 'list'>]
# record 100: ['RF', 'gender', 'False', '0.78'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'False', '0.78']
# lang_present: False
# term_present: False
# modified 100: ['RF', 'gender', 'False', 'French', 'missing', '0.78'] [type: <class 'list'>]
# record 101: ['NN', 'gender', 'False', 'French', '4gram-hash-at-both', '0.80'] [type: <class 'list'>]
# record 102: ['DT', 'plurality', 'True', 'French', '4gram-hash-at-both', '0.89'] [type: <class 'list'>]
# record 103: ['RF', 'plurality', 'True', '0.94'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.94']
# lang_present: False
# term_present: False
# modified 103: ['RF', 'plurality', 'True', 'French', 'missing', '0.94'] [type: <class 'list'>]
# record 104: ['NN', 'plurality', 'True', 'French', '4gram-hash-at-both', '0.93'] [type: <class 'list'>]
# record 105: ['DT', 'plurality', 'False', 'French', '4gram-hash-at-both', '0.90'] [type: <class 'list'>]
# record 106: ['RF', 'plurality', 'False', '0.94'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.94']
# lang_present: False
# term_present: False
# modified 106: ['RF', 'plurality', 'False', 'French', 'missing', '0.94'] [type: <class 'list'>]
# record 107: ['NN', 'plurality', 'False', 'French', '4gram-hash-at-both', '0.94'] [type: <class 'list'>]
# record 108: ['DT', 'gender', 'True', 'French', 'skippy2gram-hash-at-both', '0.75'] [type: <class 'list'>]
# record 109: ['RF', 'gender', 'True', '0.82'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'True', '0.82']
# lang_present: False
# term_present: False
# modified 109: ['RF', 'gender', 'True', 'French', 'missing', '0.82'] [type: <class 'list'>]
# record 110: ['NN', 'gender', 'True', 'French', 'skippy2gram-hash-at-both', '0.82'] [type: <class 'list'>]
# record 111: ['DT', 'gender', 'False', 'French', 'skippy2gram-hash-at-both', '0.74'] [type: <class 'list'>]
# record 112: ['RF', 'gender', 'False', '0.83'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'False', '0.83']
# lang_present: False
# term_present: False
# modified 112: ['RF', 'gender', 'False', 'French', 'missing', '0.83'] [type: <class 'list'>]
# record 113: ['NN', 'gender', 'False', 'French', 'skippy2gram-hash-at-both', '0.79'] [type: <class 'list'>]
# record 114: ['DT', 'plurality', 'True', 'French', 'skippy2gram-hash-at-both', '0.88'] [type: <class 'list'>]
# record 115: ['RF', 'plurality', 'True', '0.93'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.93']
# lang_present: False
# term_present: False
# modified 115: ['RF', 'plurality', 'True', 'French', 'missing', '0.93'] [type: <class 'list'>]
# record 116: ['NN', 'plurality', 'True', 'French', 'skippy2gram-hash-at-both', '0.96'] [type: <class 'list'>]
# record 117: ['DT', 'plurality', 'False', 'French', 'skippy2gram-hash-at-both', '0.87'] [type: <class 'list'>]
# record 118: ['RF', 'plurality', 'False', '0.94'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.94']
# lang_present: False
# term_present: False
# modified 118: ['RF', 'plurality', 'False', 'French', 'missing', '0.94'] [type: <class 'list'>]
# record 119: ['NN', 'plurality', 'False', 'French', 'skippy2gram-hash-at-both', '0.96'] [type: <class 'list'>]
# record 120: ['DT', 'gender', 'True', 'French', 'skippy3gram-hash-at-both', '0.71'] [type: <class 'list'>]
# record 121: ['RF', 'gender', 'True', '0.77'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'True', '0.77']
# lang_present: False
# term_present: False
# modified 121: ['RF', 'gender', 'True', 'French', 'missing', '0.77'] [type: <class 'list'>]
# record 122: ['NN', 'gender', 'True', 'French', 'skippy3gram-hash-at-both', '0.82'] [type: <class 'list'>]
# record 123: ['DT', 'gender', 'False', 'French', 'skippy3gram-hash-at-both', '0.66'] [type: <class 'list'>]
# record 124: ['RF', 'gender', 'False', '0.73'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'False', '0.73']
# lang_present: False
# term_present: False
# modified 124: ['RF', 'gender', 'False', 'French', 'missing', '0.73'] [type: <class 'list'>]
# record 125: ['NN', 'gender', 'False', 'French', 'skippy3gram-hash-at-both', '0.82'] [type: <class 'list'>]
# record 126: ['DT', 'plurality', 'True', 'French', 'skippy3gram-hash-at-both', '0.90'] [type: <class 'list'>]
# record 127: ['RF', 'plurality', 'True', '0.91'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.91']
# lang_present: False
# term_present: False
# modified 127: ['RF', 'plurality', 'True', 'French', 'missing', '0.91'] [type: <class 'list'>]
# record 128: ['NN', 'plurality', 'True', 'French', 'skippy3gram-hash-at-both', '0.96'] [type: <class 'list'>]
# record 129: ['DT', 'plurality', 'False', 'French', 'skippy3gram-hash-at-both', '0.90'] [type: <class 'list'>]
# record 130: ['RF', 'plurality', 'False', '0.92'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.92']
# lang_present: False
# term_present: False
# modified 130: ['RF', 'plurality', 'False', 'French', 'missing', '0.92'] [type: <class 'list'>]
# record 131: ['NN', 'plurality', 'False', 'French', 'skippy3gram-hash-at-both', '0.97'] [type: <class 'list'>]
# record 132: ['DT', 'gender', 'True', 'French', 'skippy4gram-hash-at-both', '0.69'] [type: <class 'list'>]
# record 133: ['RF', 'gender', 'True', '0.76'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'True', '0.76']
# lang_present: False
# term_present: False
# modified 133: ['RF', 'gender', 'True', 'French', 'missing', '0.76'] [type: <class 'list'>]
# record 134: ['NN', 'gender', 'True', 'French', 'skippy4gram-hash-at-both', '0.74'] [type: <class 'list'>]
# record 135: ['DT', 'gender', 'False', 'French', 'skippy4gram-hash-at-both', '0.70'] [type: <class 'list'>]
# record 136: ['RF', 'gender', 'False', '0.76'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'False', '0.76']
# lang_present: False
# term_present: False
# modified 136: ['RF', 'gender', 'False', 'French', 'missing', '0.76'] [type: <class 'list'>]
# record 137: ['NN', 'gender', 'False', 'French', 'skippy4gram-hash-at-both', '0.72'] [type: <class 'list'>]
# record 138: ['DT', 'plurality', 'True', 'French', 'skippy4gram-hash-at-both', '0.89'] [type: <class 'list'>]
# record 139: ['RF', 'plurality', 'True', '0.93'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.93']
# lang_present: False
# term_present: False
# modified 139: ['RF', 'plurality', 'True', 'French', 'missing', '0.93'] [type: <class 'list'>]
# record 140: ['NN', 'plurality', 'True', 'French', 'skippy4gram-hash-at-both', '0.94'] [type: <class 'list'>]
# record 141: ['DT', 'plurality', 'False', 'French', 'skippy4gram-hash-at-both', '0.90'] [type: <class 'list'>]
# record 142: ['RF', 'plurality', 'False', '0.93'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.93']
# lang_present: False
# term_present: False
# modified 142: ['RF', 'plurality', 'False', 'French', 'missing', '0.93'] [type: <class 'list'>]
# record 143: ['NN', 'plurality', 'False', 'French', 'skippy4gram-hash-at-both', '0.95'] [type: <class 'list'>]
# record 0: ['DT', 'gender', 'True', 'French', '2gram-no-hash', '0.74']
# record 1: ['RF', 'gender', 'True', 'French', 'missing', '0.83']
# record 2: ['NN', 'gender', 'True', 'French', '2gram-no-hash', '0.77']
# record 3: ['DT', 'gender', 'False', 'French', '2gram-no-hash', '0.75']
# record 4: ['RF', 'gender', 'False', 'French', 'missing', '0.83']
# record 5: ['NN', 'gender', 'False', 'French', '2gram-no-hash', '0.78']
# record 6: ['DT', 'plurality', 'True', 'French', '2gram-no-hash', '0.90']
# record 7: ['RF', 'plurality', 'True', 'French', 'missing', '0.91']
# record 8: ['NN', 'plurality', 'True', 'French', '2gram-no-hash', '0.92']
# record 9: ['DT', 'plurality', 'False', 'French', '2gram-no-hash', '0.93']
# record 10: ['RF', 'plurality', 'False', 'French', 'missing', '0.93']
# record 11: ['NN', 'plurality', 'False', 'French', '2gram-no-hash', '0.94']
# record 12: ['DT', 'gender', 'True', 'French', '3gram-no-hash', '0.73']
# record 13: ['RF', 'gender', 'True', 'French', 'missing', '0.74']
# record 14: ['NN', 'gender', 'True', 'French', '3gram-no-hash', '0.77']
# record 15: ['DT', 'gender', 'False', 'French', '3gram-no-hash', '0.74']
# record 16: ['RF', 'gender', 'False', 'French', 'missing', '0.79']
# record 17: ['NN', 'gender', 'False', 'French', '3gram-no-hash', '0.77']
# record 18: ['DT', 'plurality', 'True', 'French', '3gram-no-hash', '0.92']
# record 19: ['RF', 'plurality', 'True', 'French', 'missing', '0.95']
# record 20: ['NN', 'plurality', 'True', 'French', '3gram-no-hash', '0.94']
# record 21: ['DT', 'plurality', 'False', 'French', '3gram-no-hash', '0.89']
# record 22: ['RF', 'plurality', 'False', 'French', 'missing', '0.94']
# record 23: ['NN', 'plurality', 'False', 'French', '3gram-no-hash', '0.95']
# record 24: ['DT', 'gender', 'True', 'French', '4gram-no-hash', '0.74']
# record 25: ['RF', 'gender', 'True', 'French', 'missing', '0.81']
# record 26: ['NN', 'gender', 'True', 'French', '4gram-no-hash', '0.81']
# record 27: ['DT', 'gender', 'False', 'French', '4gram-no-hash', '0.72']
# record 28: ['RF', 'gender', 'False', 'French', 'missing', '0.82']
# record 29: ['NN', 'gender', 'False', 'French', '4gram-no-hash', '0.81']
# record 30: ['DT', 'plurality', 'True', 'French', '4gram-no-hash', '0.93']
# record 31: ['RF', 'plurality', 'True', 'French', 'missing', '0.94']
# record 32: ['NN', 'plurality', 'True', 'French', '4gram-no-hash', '0.97']
# record 33: ['DT', 'plurality', 'False', 'French', '4gram-no-hash', '0.89']
# record 34: ['RF', 'plurality', 'False', 'French', 'missing', '0.92']
# record 35: ['NN', 'plurality', 'False', 'French', '4gram-no-hash', '0.96']
# record 36: ['DT', 'gender', 'True', 'French', 'skippy2gram-no-hash', '0.73']
# record 37: ['RF', 'gender', 'True', 'French', 'missing', '0.80']
# record 38: ['NN', 'gender', 'True', 'French', 'skippy2gram-no-hash', '0.77']
# record 39: ['DT', 'gender', 'False', 'French', 'skippy2gram-no-hash', '0.72']
# record 40: ['RF', 'gender', 'False', 'French', 'missing', '0.78']
# record 41: ['NN', 'gender', 'False', 'French', 'skippy2gram-no-hash', '0.75']
# record 42: ['DT', 'plurality', 'True', 'French', 'skippy2gram-no-hash', '0.93']
# record 43: ['RF', 'plurality', 'True', 'French', 'missing', '0.93']
# record 44: ['NN', 'plurality', 'True', 'French', 'skippy2gram-no-hash', '0.95']
# record 45: ['DT', 'plurality', 'False', 'French', 'skippy2gram-no-hash', '0.88']
# record 46: ['RF', 'plurality', 'False', 'French', 'missing', '0.93']
# record 47: ['NN', 'plurality', 'False', 'French', 'skippy2gram-no-hash', '0.95']
# record 48: ['DT', 'gender', 'True', 'French', 'skippy3gram-no-hash', '0.62']
# record 49: ['RF', 'gender', 'True', 'French', 'missing', '0.75']
# record 50: ['NN', 'gender', 'True', 'French', 'skippy3gram-no-hash', '0.78']
# record 51: ['DT', 'gender', 'False', 'French', 'skippy3gram-no-hash', '0.65']
# record 52: ['RF', 'gender', 'False', 'French', 'missing', '0.73']
# record 53: ['NN', 'gender', 'False', 'French', 'skippy3gram-no-hash', '0.76']
# record 54: ['DT', 'plurality', 'True', 'French', 'skippy3gram-no-hash', '0.87']
# record 55: ['RF', 'plurality', 'True', 'French', 'missing', '0.92']
# record 56: ['NN', 'plurality', 'True', 'French', 'skippy3gram-no-hash', '0.96']
# record 57: ['DT', 'plurality', 'False', 'French', 'skippy3gram-no-hash', '0.86']
# record 58: ['RF', 'plurality', 'False', 'French', 'missing', '0.92']
# record 59: ['NN', 'plurality', 'False', 'French', 'skippy3gram-no-hash', '0.96']
# record 60: ['DT', 'gender', 'True', 'French', 'skippy4gram-no-hash', '0.70']
# record 61: ['RF', 'gender', 'True', 'French', 'missing', '0.80']
# record 62: ['NN', 'gender', 'True', 'French', 'skippy4gram-no-hash', '0.78']
# record 63: ['DT', 'gender', 'False', 'French', 'skippy4gram-no-hash', '0.72']
# record 64: ['RF', 'gender', 'False', 'French', 'missing', '0.80']
# record 65: ['NN', 'gender', 'False', 'French', 'skippy4gram-no-hash', '0.76']
# record 66: ['DT', 'plurality', 'True', 'French', 'skippy4gram-no-hash', '0.86']
# record 67: ['RF', 'plurality', 'True', 'French', 'missing', '0.90']
# record 68: ['NN', 'plurality', 'True', 'French', 'skippy4gram-no-hash', '0.95']
# record 69: ['DT', 'plurality', 'False', 'French', 'skippy4gram-no-hash', '0.75']
# record 70: ['RF', 'plurality', 'False', 'French', 'missing', '0.91']
# record 71: ['NN', 'plurality', 'False', 'French', 'skippy4gram-no-hash', '0.94']
# record 72: ['DT', 'gender', 'True', 'French', '2gram-hash-at-both', '0.77']
# record 73: ['RF', 'gender', 'True', 'French', 'missing', '0.81']
# record 74: ['NN', 'gender', 'True', 'French', '2gram-hash-at-both', '0.83']
# record 75: ['DT', 'gender', 'False', 'French', '2gram-hash-at-both', '0.73']
# record 76: ['RF', 'gender', 'False', 'French', 'missing', '0.81']
# record 77: ['NN', 'gender', 'False', 'French', '2gram-hash-at-both', '0.79']
# record 78: ['DT', 'plurality', 'True', 'French', '2gram-hash-at-both', '0.87']
# record 79: ['RF', 'plurality', 'True', 'French', 'missing', '0.92']
# record 80: ['NN', 'plurality', 'True', 'French', '2gram-hash-at-both', '0.92']
# record 81: ['DT', 'plurality', 'False', 'French', '2gram-hash-at-both', '0.90']
# record 82: ['RF', 'plurality', 'False', 'French', 'missing', '0.92']
# record 83: ['NN', 'plurality', 'False', 'French', '2gram-hash-at-both', '0.94']
# record 84: ['DT', 'gender', 'True', 'French', '3gram-hash-at-both', '0.75']
# record 85: ['RF', 'gender', 'True', 'French', 'missing', '0.80']
# record 86: ['NN', 'gender', 'True', 'French', '3gram-hash-at-both', '0.75']
# record 87: ['DT', 'gender', 'False', 'French', '3gram-hash-at-both', '0.69']
# record 88: ['RF', 'gender', 'False', 'French', 'missing', '0.79']
# record 89: ['NN', 'gender', 'False', 'French', '3gram-hash-at-both', '0.72']
# record 90: ['DT', 'plurality', 'True', 'French', '3gram-hash-at-both', '0.92']
# record 91: ['RF', 'plurality', 'True', 'French', 'missing', '0.95']
# record 92: ['NN', 'plurality', 'True', 'French', '3gram-hash-at-both', '0.94']
# record 93: ['DT', 'plurality', 'False', 'French', '3gram-hash-at-both', '0.93']
# record 94: ['RF', 'plurality', 'False', 'French', 'missing', '0.95']
# record 95: ['NN', 'plurality', 'False', 'French', '3gram-hash-at-both', '0.94']
# record 96: ['DT', 'gender', 'True', 'French', '4gram-hash-at-both', '0.74']
# record 97: ['RF', 'gender', 'True', 'French', 'missing', '0.80']
# record 98: ['NN', 'gender', 'True', 'French', '4gram-hash-at-both', '0.77']
# record 99: ['DT', 'gender', 'False', 'French', '4gram-hash-at-both', '0.68']
# record 100: ['RF', 'gender', 'False', 'French', 'missing', '0.78']
# record 101: ['NN', 'gender', 'False', 'French', '4gram-hash-at-both', '0.80']
# record 102: ['DT', 'plurality', 'True', 'French', '4gram-hash-at-both', '0.89']
# record 103: ['RF', 'plurality', 'True', 'French', 'missing', '0.94']
# record 104: ['NN', 'plurality', 'True', 'French', '4gram-hash-at-both', '0.93']
# record 105: ['DT', 'plurality', 'False', 'French', '4gram-hash-at-both', '0.90']
# record 106: ['RF', 'plurality', 'False', 'French', 'missing', '0.94']
# record 107: ['NN', 'plurality', 'False', 'French', '4gram-hash-at-both', '0.94']
# record 108: ['DT', 'gender', 'True', 'French', 'skippy2gram-hash-at-both', '0.75']
# record 109: ['RF', 'gender', 'True', 'French', 'missing', '0.82']
# record 110: ['NN', 'gender', 'True', 'French', 'skippy2gram-hash-at-both', '0.82']
# record 111: ['DT', 'gender', 'False', 'French', 'skippy2gram-hash-at-both', '0.74']
# record 112: ['RF', 'gender', 'False', 'French', 'missing', '0.83']
# record 113: ['NN', 'gender', 'False', 'French', 'skippy2gram-hash-at-both', '0.79']
# record 114: ['DT', 'plurality', 'True', 'French', 'skippy2gram-hash-at-both', '0.88']
# record 115: ['RF', 'plurality', 'True', 'French', 'missing', '0.93']
# record 116: ['NN', 'plurality', 'True', 'French', 'skippy2gram-hash-at-both', '0.96']
# record 117: ['DT', 'plurality', 'False', 'French', 'skippy2gram-hash-at-both', '0.87']
# record 118: ['RF', 'plurality', 'False', 'French', 'missing', '0.94']
# record 119: ['NN', 'plurality', 'False', 'French', 'skippy2gram-hash-at-both', '0.96']
# record 120: ['DT', 'gender', 'True', 'French', 'skippy3gram-hash-at-both', '0.71']
# record 121: ['RF', 'gender', 'True', 'French', 'missing', '0.77']
# record 122: ['NN', 'gender', 'True', 'French', 'skippy3gram-hash-at-both', '0.82']
# record 123: ['DT', 'gender', 'False', 'French', 'skippy3gram-hash-at-both', '0.66']
# record 124: ['RF', 'gender', 'False', 'French', 'missing', '0.73']
# record 125: ['NN', 'gender', 'False', 'French', 'skippy3gram-hash-at-both', '0.82']
# record 126: ['DT', 'plurality', 'True', 'French', 'skippy3gram-hash-at-both', '0.90']
# record 127: ['RF', 'plurality', 'True', 'French', 'missing', '0.91']
# record 128: ['NN', 'plurality', 'True', 'French', 'skippy3gram-hash-at-both', '0.96']
# record 129: ['DT', 'plurality', 'False', 'French', 'skippy3gram-hash-at-both', '0.90']
# record 130: ['RF', 'plurality', 'False', 'French', 'missing', '0.92']
# record 131: ['NN', 'plurality', 'False', 'French', 'skippy3gram-hash-at-both', '0.97']
# record 132: ['DT', 'gender', 'True', 'French', 'skippy4gram-hash-at-both', '0.69']
# record 133: ['RF', 'gender', 'True', 'French', 'missing', '0.76']
# record 134: ['NN', 'gender', 'True', 'French', 'skippy4gram-hash-at-both', '0.74']
# record 135: ['DT', 'gender', 'False', 'French', 'skippy4gram-hash-at-both', '0.70']
# record 136: ['RF', 'gender', 'False', 'French', 'missing', '0.76']
# record 137: ['NN', 'gender', 'False', 'French', 'skippy4gram-hash-at-both', '0.72']
# record 138: ['DT', 'plurality', 'True', 'French', 'skippy4gram-hash-at-both', '0.89']
# record 139: ['RF', 'plurality', 'True', 'French', 'missing', '0.93']
# record 140: ['NN', 'plurality', 'True', 'French', 'skippy4gram-hash-at-both', '0.94']
# record 141: ['DT', 'plurality', 'False', 'French', 'skippy4gram-hash-at-both', '0.90']
# record 142: ['RF', 'plurality', 'False', 'French', 'missing', '0.93']
# record 143: ['NN', 'plurality', 'False', 'French', 'skippy4gram-hash-at-both', '0.95']
# opening results/3k/mgv9-sk/result-Czech-sample3000-mgv9-2024-12-27-21-29.txt
# [['DT', 'plurality', 'True', 'Czech', '2gram-no-hash', '0.87'], ['RF', 'plurality', 'True', '0.87'], ['NN', 'plurality', 'True', 'Czech', '2gram-no-hash', '0.86'], ['DT', 'plurality', 'False', 'Czech', '2gram-no-hash', '0.77'], ['RF', 'plurality', 'False', '0.80'], ['NN', 'plurality', 'False', 'Czech', '2gram-no-hash', '0.78'], ['DT', 'plurality', 'True', 'Czech', '3gram-no-hash', '0.85'], ['RF', 'plurality', 'True', '0.87'], ['NN', 'plurality', 'True', 'Czech', '3gram-no-hash', '0.87'], ['DT', 'plurality', 'False', 'Czech', '3gram-no-hash', '0.84'], ['RF', 'plurality', 'False', '0.84'], ['NN', 'plurality', 'False', 'Czech', '3gram-no-hash', '0.81'], ['DT', 'plurality', 'True', 'Czech', '4gram-no-hash', '0.89'], ['RF', 'plurality', 'True', '0.88'], ['NN', 'plurality', 'True', 'Czech', '4gram-no-hash', '0.89'], ['DT', 'plurality', 'False', 'Czech', '4gram-no-hash', '0.83'], ['RF', 'plurality', 'False', '0.85'], ['NN', 'plurality', 'False', 'Czech', '4gram-no-hash', '0.78'], ['DT', 'plurality', 'True', 'Czech', 'skippy2gram-no-hash', '0.87'], ['RF', 'plurality', 'True', '0.91'], ['NN', 'plurality', 'True', 'Czech', 'skippy2gram-no-hash', '0.89'], ['DT', 'plurality', 'False', 'Czech', 'skippy2gram-no-hash', '0.83'], ['RF', 'plurality', 'False', '0.85'], ['NN', 'plurality', 'False', 'Czech', 'skippy2gram-no-hash', '0.83'], ['DT', 'plurality', 'True', 'Czech', 'skippy3gram-no-hash', '0.82'], ['RF', 'plurality', 'True', '0.83'], ['NN', 'plurality', 'True', 'Czech', 'skippy3gram-no-hash', '0.85'], ['DT', 'plurality', 'False', 'Czech', 'skippy3gram-no-hash', '0.82'], ['RF', 'plurality', 'False', '0.83'], ['NN', 'plurality', 'False', 'Czech', 'skippy3gram-no-hash', '0.86'], ['DT', 'plurality', 'True', 'Czech', 'skippy4gram-no-hash', '0.80'], ['RF', 'plurality', 'True', '0.87'], ['NN', 'plurality', 'True', 'Czech', 'skippy4gram-no-hash', '0.87'], ['DT', 'plurality', 'False', 'Czech', 'skippy4gram-no-hash', '0.82'], ['RF', 'plurality', 'False', '0.80'], ['NN', 'plurality', 'False', 'Czech', 'skippy4gram-no-hash', '0.81'], ['DT', 'plurality', 'True', 'Czech', '2gram-hash-at-both', '0.87'], ['RF', 'plurality', 'True', '0.91'], ['NN', 'plurality', 'True', 'Czech', '2gram-hash-at-both', '0.94'], ['DT', 'plurality', 'False', 'Czech', '2gram-hash-at-both', '0.84'], ['RF', 'plurality', 'False', '0.85'], ['NN', 'plurality', 'False', 'Czech', '2gram-hash-at-both', '0.86'], ['DT', 'plurality', 'True', 'Czech', '3gram-hash-at-both', '0.85'], ['RF', 'plurality', 'True', '0.89'], ['NN', 'plurality', 'True', 'Czech', '3gram-hash-at-both', '0.91'], ['DT', 'plurality', 'False', 'Czech', '3gram-hash-at-both', '0.80'], ['RF', 'plurality', 'False', '0.81'], ['NN', 'plurality', 'False', 'Czech', '3gram-hash-at-both', '0.82'], ['DT', 'plurality', 'True', 'Czech', '4gram-hash-at-both', '0.84'], ['RF', 'plurality', 'True', '0.87'], ['NN', 'plurality', 'True', 'Czech', '4gram-hash-at-both', '0.86'], ['DT', 'plurality', 'False', 'Czech', '4gram-hash-at-both', '0.77'], ['RF', 'plurality', 'False', '0.83'], ['NN', 'plurality', 'False', 'Czech', '4gram-hash-at-both', '0.80'], ['DT', 'plurality', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.89'], ['RF', 'plurality', 'True', '0.89'], ['NN', 'plurality', 'True', 'Czech', 'skippy2gram-hash-at-both', '0.88'], ['DT', 'plurality', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.83'], ['RF', 'plurality', 'False', '0.85'], ['NN', 'plurality', 'False', 'Czech', 'skippy2gram-hash-at-both', '0.79'], ['DT', 'plurality', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.79'], ['RF', 'plurality', 'True', '0.86'], ['NN', 'plurality', 'True', 'Czech', 'skippy3gram-hash-at-both', '0.87'], ['DT', 'plurality', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.81'], ['RF', 'plurality', 'False', '0.83'], ['NN', 'plurality', 'False', 'Czech', 'skippy3gram-hash-at-both', '0.85'], ['DT', 'plurality', 'True', 'Czech', 'skippy4gram-hash-at-both', '0.86'], ['RF', 'plurality', 'True', '0.90'], ['NN', 'plurality', 'True', 'Czech', 'skippy4gram ...
# record 000: ['DT', 'plurality', 'True', 'Czech', '2gram-no-hash', '0.87'] [type: <class 'list'>]
# record 001: ['RF', 'plurality', 'True', '0.87'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.87']
# lang_present: False
# term_present: False
# modified 1: ['RF', 'plurality', 'True', 'Czech', 'missing', '0.87'] [type: <class 'list'>]
# record 002: ['NN', 'plurality', 'True', 'Czech', '2gram-no-hash', '0.86'] [type: <class 'list'>]
# record 003: ['DT', 'plurality', 'False', 'Czech', '2gram-no-hash', '0.77'] [type: <class 'list'>]
# record 004: ['RF', 'plurality', 'False', '0.80'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.80']
# lang_present: False
# term_present: False
# modified 4: ['RF', 'plurality', 'False', 'Czech', 'missing', '0.80'] [type: <class 'list'>]
# record 005: ['NN', 'plurality', 'False', 'Czech', '2gram-no-hash', '0.78'] [type: <class 'list'>]
# record 006: ['DT', 'plurality', 'True', 'Czech', '3gram-no-hash', '0.85'] [type: <class 'list'>]
# record 007: ['RF', 'plurality', 'True', '0.87'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.87']
# lang_present: False
# term_present: False
# modified 7: ['RF', 'plurality', 'True', 'Czech', 'missing', '0.87'] [type: <class 'list'>]
# record 008: ['NN', 'plurality', 'True', 'Czech', '3gram-no-hash', '0.87'] [type: <class 'list'>]
# record 009: ['DT', 'plurality', 'False', 'Czech', '3gram-no-hash', '0.84'] [type: <class 'list'>]
# record 010: ['RF', 'plurality', 'False', '0.84'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.84']
# lang_present: False
# term_present: False
# modified 10: ['RF', 'plurality', 'False', 'Czech', 'missing', '0.84'] [type: <class 'list'>]
# record 011: ['NN', 'plurality', 'False', 'Czech', '3gram-no-hash', '0.81'] [type: <class 'list'>]
# record 012: ['DT', 'plurality', 'True', 'Czech', '4gram-no-hash', '0.89'] [type: <class 'list'>]
# record 013: ['RF', 'plurality', 'True', '0.88'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.88']
# lang_present: False
# term_present: False
# modified 13: ['RF', 'plurality', 'True', 'Czech', 'missing', '0.88'] [type: <class 'list'>]
# record 014: ['NN', 'plurality', 'True', 'Czech', '4gram-no-hash', '0.89'] [type: <class 'list'>]
# record 015: ['DT', 'plurality', 'False', 'Czech', '4gram-no-hash', '0.83'] [type: <class 'list'>]
# record 016: ['RF', 'plurality', 'False', '0.85'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.85']
# lang_present: False
# term_present: False
# modified 16: ['RF', 'plurality', 'False', 'Czech', 'missing', '0.85'] [type: <class 'list'>]
# record 017: ['NN', 'plurality', 'False', 'Czech', '4gram-no-hash', '0.78'] [type: <class 'list'>]
# record 018: ['DT', 'plurality', 'True', 'Czech', 'skippy2gram-no-hash', '0.87'] [type: <class 'list'>]
# record 019: ['RF', 'plurality', 'True', '0.91'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.91']
# lang_present: False
# term_present: False
# modified 19: ['RF', 'plurality', 'True', 'Czech', 'missing', '0.91'] [type: <class 'list'>]
# record 020: ['NN', 'plurality', 'True', 'Czech', 'skippy2gram-no-hash', '0.89'] [type: <class 'list'>]
# record 021: ['DT', 'plurality', 'False', 'Czech', 'skippy2gram-no-hash', '0.83'] [type: <class 'list'>]
# record 022: ['RF', 'plurality', 'False', '0.85'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.85']
# lang_present: False
# term_present: False
# modified 22: ['RF', 'plurality', 'False', 'Czech', 'missing', '0.85'] [type: <class 'list'>]
# record 023: ['NN', 'plurality', 'False', 'Czech', 'skippy2gram-no-hash', '0.83'] [type: <class 'list'>]
# record 024: ['DT', 'plurality', 'True', 'Czech', 'skippy3gram-no-hash', '0.82'] [type: <class 'list'>]
# record 025: ['RF', 'plurality', 'True', '0.83'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.83']
# lang_present: False
# term_present: False
# modified 25: ['RF', 'plurality', 'True', 'Czech', 'missing', '0.83'] [type: <class 'list'>]
# record 026: ['NN', 'plurality', 'True', 'Czech', 'skippy3gram-no-hash', '0.85'] [type: <class 'list'>]
# record 027: ['DT', 'plurality', 'False', 'Czech', 'skippy3gram-no-hash', '0.82'] [type: <class 'list'>]
# record 028: ['RF', 'plurality', 'False', '0.83'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.83']
# lang_present: False
# term_present: False
# modified 28: ['RF', 'plurality', 'False', 'Czech', 'missing', '0.83'] [type: <class 'list'>]
# record 029: ['NN', 'plurality', 'False', 'Czech', 'skippy3gram-no-hash', '0.86'] [type: <class 'list'>]
# record 030: ['DT', 'plurality', 'True', 'Czech', 'skippy4gram-no-hash', '0.80'] [type: <class 'list'>]
# record 031: ['RF', 'plurality', 'True', '0.87'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.87']
# lang_present: False
# term_present: False
# modified 31: ['RF', 'plurality', 'True', 'Czech', 'missing', '0.87'] [type: <class 'list'>]
# record 032: ['NN', 'plurality', 'True', 'Czech', 'skippy4gram-no-hash', '0.87'] [type: <class 'list'>]
# record 033: ['DT', 'plurality', 'False', 'Czech', 'skippy4gram-no-hash', '0.82'] [type: <class 'list'>]
# record 034: ['RF', 'plurality', 'False', '0.80'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.80']
# lang_present: False
# term_present: False
# modified 34: ['RF', 'plurality', 'False', 'Czech', 'missing', '0.80'] [type: <class 'list'>]
# record 035: ['NN', 'plurality', 'False', 'Czech', 'skippy4gram-no-hash', '0.81'] [type: <class 'list'>]
# record 036: ['DT', 'plurality', 'True', 'Czech', '2gram-hash-at-both', '0.87'] [type: <class 'list'>]
# record 037: ['RF', 'plurality', 'True', '0.91'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.91']
# lang_present: False
# term_present: False
# modified 37: ['RF', 'plurality', 'True', 'Czech', 'missing', '0.91'] [type: <class 'list'>]
# record 038: ['NN', 'plurality', 'True', 'Czech', '2gram-hash-at-both', '0.94'] [type: <class 'list'>]
# record 039: ['DT', 'plurality', 'False', 'Czech', '2gram-hash-at-both', '0.84'] [type: <class 'list'>]
# record 040: ['RF', 'plurality', 'False', '0.85'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.85']
# lang_present: False
# term_present: False
# modified 40: ['RF', 'plurality', 'False', 'Czech', 'missing', '0.85'] [type: <class 'list'>]
# record 041: ['NN', 'plurality', 'False', 'Czech', '2gram-hash-at-both', '0.86'] [type: <class 'list'>]
# record 042: ['DT', 'plurality', 'True', 'Czech', '3gram-hash-at-both', '0.85'] [type: <class 'list'>]
# record 043: ['RF', 'plurality', 'True', '0.89'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.89']
# lang_present: False
# term_present: False
# ...
# record 112: ['RF', 'gender', 'False', '0.64'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'False', '0.64']
# lang_present: False
# term_present: False
# modified 112: ['RF', 'gender', 'False', 'German', 'missing', '0.64'] [type: <class 'list'>]
# record 113: ['NN', 'gender', 'False', 'German', 'skippy2gram-hash-at-both', '0.57'] [type: <class 'list'>]
# record 114: ['DT', 'plurality', 'True', 'German', 'skippy2gram-hash-at-both', '0.81'] [type: <class 'list'>]
# record 115: ['RF', 'plurality', 'True', '0.85'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.85']
# lang_present: False
# term_present: False
# modified 115: ['RF', 'plurality', 'True', 'German', 'missing', '0.85'] [type: <class 'list'>]
# record 116: ['NN', 'plurality', 'True', 'German', 'skippy2gram-hash-at-both', '0.82'] [type: <class 'list'>]
# record 117: ['DT', 'plurality', 'False', 'German', 'skippy2gram-hash-at-both', '0.78'] [type: <class 'list'>]
# record 118: ['RF', 'plurality', 'False', '0.81'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.81']
# lang_present: False
# term_present: False
# modified 118: ['RF', 'plurality', 'False', 'German', 'missing', '0.81'] [type: <class 'list'>]
# record 119: ['NN', 'plurality', 'False', 'German', 'skippy2gram-hash-at-both', '0.79'] [type: <class 'list'>]
# record 120: ['DT', 'gender', 'True', 'German', 'skippy3gram-hash-at-both', '0.47'] [type: <class 'list'>]
# record 121: ['RF', 'gender', 'True', '0.57'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'True', '0.57']
# lang_present: False
# term_present: False
# modified 121: ['RF', 'gender', 'True', 'German', 'missing', '0.57'] [type: <class 'list'>]
# record 122: ['NN', 'gender', 'True', 'German', 'skippy3gram-hash-at-both', '0.63'] [type: <class 'list'>]
# record 123: ['DT', 'gender', 'False', 'German', 'skippy3gram-hash-at-both', '0.47'] [type: <class 'list'>]
# record 124: ['RF', 'gender', 'False', '0.55'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'False', '0.55']
# lang_present: False
# term_present: False
# modified 124: ['RF', 'gender', 'False', 'German', 'missing', '0.55'] [type: <class 'list'>]
# record 125: ['NN', 'gender', 'False', 'German', 'skippy3gram-hash-at-both', '0.60'] [type: <class 'list'>]
# record 126: ['DT', 'plurality', 'True', 'German', 'skippy3gram-hash-at-both', '0.77'] [type: <class 'list'>]
# record 127: ['RF', 'plurality', 'True', '0.80'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.80']
# lang_present: False
# term_present: False
# modified 127: ['RF', 'plurality', 'True', 'German', 'missing', '0.80'] [type: <class 'list'>]
# record 128: ['NN', 'plurality', 'True', 'German', 'skippy3gram-hash-at-both', '0.75'] [type: <class 'list'>]
# record 129: ['DT', 'plurality', 'False', 'German', 'skippy3gram-hash-at-both', '0.71'] [type: <class 'list'>]
# record 130: ['RF', 'plurality', 'False', '0.79'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.79']
# lang_present: False
# term_present: False
# modified 130: ['RF', 'plurality', 'False', 'German', 'missing', '0.79'] [type: <class 'list'>]
# record 131: ['NN', 'plurality', 'False', 'German', 'skippy3gram-hash-at-both', '0.75'] [type: <class 'list'>]
# record 132: ['DT', 'gender', 'True', 'German', 'skippy4gram-hash-at-both', '0.51'] [type: <class 'list'>]
# record 133: ['RF', 'gender', 'True', '0.59'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'True', '0.59']
# lang_present: False
# term_present: False
# modified 133: ['RF', 'gender', 'True', 'German', 'missing', '0.59'] [type: <class 'list'>]
# record 134: ['NN', 'gender', 'True', 'German', 'skippy4gram-hash-at-both', '0.54'] [type: <class 'list'>]
# record 135: ['DT', 'gender', 'False', 'German', 'skippy4gram-hash-at-both', '0.52'] [type: <class 'list'>]
# record 136: ['RF', 'gender', 'False', '0.57'] [type: <class 'list'>]
# found invalid record
# ['RF', 'gender', 'False', '0.57']
# lang_present: False
# term_present: False
# modified 136: ['RF', 'gender', 'False', 'German', 'missing', '0.57'] [type: <class 'list'>]
# record 137: ['NN', 'gender', 'False', 'German', 'skippy4gram-hash-at-both', '0.54'] [type: <class 'list'>]
# record 138: ['DT', 'plurality', 'True', 'German', 'skippy4gram-hash-at-both', '0.81'] [type: <class 'list'>]
# record 139: ['RF', 'plurality', 'True', '0.85'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'True', '0.85']
# lang_present: False
# term_present: False
# modified 139: ['RF', 'plurality', 'True', 'German', 'missing', '0.85'] [type: <class 'list'>]
# record 140: ['NN', 'plurality', 'True', 'German', 'skippy4gram-hash-at-both', '0.79'] [type: <class 'list'>]
# record 141: ['DT', 'plurality', 'False', 'German', 'skippy4gram-hash-at-both', '0.79'] [type: <class 'list'>]
# record 142: ['RF', 'plurality', 'False', '0.82'] [type: <class 'list'>]
# found invalid record
# ['RF', 'plurality', 'False', '0.82']
# lang_present: False
# term_present: False
# modified 142: ['RF', 'plurality', 'False', 'German', 'missing', '0.82'] [type: <class 'list'>]
# record 143: ['NN', 'plurality', 'False', 'German', 'skippy4gram-hash-at-both', '0.74'] [type: <class 'list'>]
# record 0: ['DT', 'gender', 'True', 'German', '2gram-no-hash', '0.56']
# record 1: ['RF', 'gender', 'True', 'German', 'missing', '0.61']
# record 2: ['NN', 'gender', 'True', 'German', '2gram-no-hash', '0.57']
# record 3: ['DT', 'gender', 'False', 'German', '2gram-no-hash', '0.53']
# record 4: ['RF', 'gender', 'False', 'German', 'missing', '0.59']
# record 5: ['NN', 'gender', 'False', 'German', '2gram-no-hash', '0.56']
# record 6: ['DT', 'plurality', 'True', 'German', '2gram-no-hash', '0.78']
# record 7: ['RF', 'plurality', 'True', 'German', 'missing', '0.82']
# record 8: ['NN', 'plurality', 'True', 'German', '2gram-no-hash', '0.81']
# record 9: ['DT', 'plurality', 'False', 'German', '2gram-no-hash', '0.75']
# record 10: ['RF', 'plurality', 'False', 'German', 'missing', '0.76']
# record 11: ['NN', 'plurality', 'False', 'German', '2gram-no-hash', '0.74']
# record 12: ['DT', 'gender', 'True', 'German', '3gram-no-hash', '0.54']
# record 13: ['RF', 'gender', 'True', 'German', 'missing', '0.61']
# record 14: ['NN', 'gender', 'True', 'German', '3gram-no-hash', '0.58']
# record 15: ['DT', 'gender', 'False', 'German', '3gram-no-hash', '0.53']
# record 16: ['RF', 'gender', 'False', 'German', 'missing', '0.55']
# record 17: ['NN', 'gender', 'False', 'German', '3gram-no-hash', '0.56']
# record 18: ['DT', 'plurality', 'True', 'German', '3gram-no-hash', '0.81']
# record 19: ['RF', 'plurality', 'True', 'German', 'missing', '0.84']
# record 20: ['NN', 'plurality', 'True', 'German', '3gram-no-hash', '0.82']
# record 21: ['DT', 'plurality', 'False', 'German', '3gram-no-hash', '0.75']
# record 22: ['RF', 'plurality', 'False', 'German', 'missing', '0.81']
# record 23: ['NN', 'plurality', 'False', 'German', '3gram-no-hash', '0.79']
# record 24: ['DT', 'gender', 'True', 'German', '4gram-no-hash', '0.56']
# record 25: ['RF', 'gender', 'True', 'German', 'missing', '0.66']
# record 26: ['NN', 'gender', 'True', 'German', '4gram-no-hash', '0.61']
# record 27: ['DT', 'gender', 'False', 'German', '4gram-no-hash', '0.50']
# record 28: ['RF', 'gender', 'False', 'German', 'missing', '0.60']
# record 29: ['NN', 'gender', 'False', 'German', '4gram-no-hash', '0.59']
# record 30: ['DT', 'plurality', 'True', 'German', '4gram-no-hash', '0.83']
# record 31: ['RF', 'plurality', 'True', 'German', 'missing', '0.83']
# record 32: ['NN', 'plurality', 'True', 'German', '4gram-no-hash', '0.81']
# record 33: ['DT', 'plurality', 'False', 'German', '4gram-no-hash', '0.78']
# record 34: ['RF', 'plurality', 'False', 'German', 'missing', '0.82']
# record 35: ['NN', 'plurality', 'False', 'German', '4gram-no-hash', '0.80']
# record 36: ['DT', 'gender', 'True', 'German', 'skippy2gram-no-hash', '0.47']
# record 37: ['RF', 'gender', 'True', 'German', 'missing', '0.60']
# record 38: ['NN', 'gender', 'True', 'German', 'skippy2gram-no-hash', '0.57']
# record 39: ['DT', 'gender', 'False', 'German', 'skippy2gram-no-hash', '0.42']
# record 40: ['RF', 'gender', 'False', 'German', 'missing', '0.58']
# record 41: ['NN', 'gender', 'False', 'German', 'skippy2gram-no-hash', '0.53']
# record 42: ['DT', 'plurality', 'True', 'German', 'skippy2gram-no-hash', '0.80']
# record 43: ['RF', 'plurality', 'True', 'German', 'missing', '0.88']
# record 44: ['NN', 'plurality', 'True', 'German', 'skippy2gram-no-hash', '0.85']
# record 45: ['DT', 'plurality', 'False', 'German', 'skippy2gram-no-hash', '0.79']
# record 46: ['RF', 'plurality', 'False', 'German', 'missing', '0.84']
# record 47: ['NN', 'plurality', 'False', 'German', 'skippy2gram-no-hash', '0.82']
# record 48: ['DT', 'gender', 'True', 'German', 'skippy3gram-no-hash', '0.52']
# record 49: ['RF', 'gender', 'True', 'German', 'missing', '0.57']
# record 50: ['NN', 'gender', 'True', 'German', 'skippy3gram-no-hash', '0.63']
# record 51: ['DT', 'gender', 'False', 'German', 'skippy3gram-no-hash', '0.51']
# record 52: ['RF', 'gender', 'False', 'German', 'missing', '0.57']
# record 53: ['NN', 'gender', 'False', 'German', 'skippy3gram-no-hash', '0.58']
# record 54: ['DT', 'plurality', 'True', 'German', 'skippy3gram-no-hash', '0.74']
# record 55: ['RF', 'plurality', 'True', 'German', 'missing', '0.84']
# record 56: ['NN', 'plurality', 'True', 'German', 'skippy3gram-no-hash', '0.77']
# record 57: ['DT', 'plurality', 'False', 'German', 'skippy3gram-no-hash', '0.76']
# record 58: ['RF', 'plurality', 'False', 'German', 'missing', '0.78']
# record 59: ['NN', 'plurality', 'False', 'German', 'skippy3gram-no-hash', '0.79']
# record 60: ['DT', 'gender', 'True', 'German', 'skippy4gram-no-hash', '0.48']
# record 61: ['RF', 'gender', 'True', 'German', 'missing', '0.59']
# record 62: ['NN', 'gender', 'True', 'German', 'skippy4gram-no-hash', '0.62']
# record 63: ['DT', 'gender', 'False', 'German', 'skippy4gram-no-hash', '0.53']
# record 64: ['RF', 'gender', 'False', 'German', 'missing', '0.57']
# record 65: ['NN', 'gender', 'False', 'German', 'skippy4gram-no-hash', '0.59']
# record 66: ['DT', 'plurality', 'True', 'German', 'skippy4gram-no-hash', '0.80']
# record 67: ['RF', 'plurality', 'True', 'German', 'missing', '0.82']
# record 68: ['NN', 'plurality', 'True', 'German', 'skippy4gram-no-hash', '0.78']
# record 69: ['DT', 'plurality', 'False', 'German', 'skippy4gram-no-hash', '0.77']
# record 70: ['RF', 'plurality', 'False', 'German', 'missing', '0.82']
# record 71: ['NN', 'plurality', 'False', 'German', 'skippy4gram-no-hash', '0.79']
# record 72: ['DT', 'gender', 'True', 'German', '2gram-hash-at-both', '0.56']
# record 73: ['RF', 'gender', 'True', 'German', 'missing', '0.57']
# record 74: ['NN', 'gender', 'True', 'German', '2gram-hash-at-both', '0.58']
# record 75: ['DT', 'gender', 'False', 'German', '2gram-hash-at-both', '0.52']
# record 76: ['RF', 'gender', 'False', 'German', 'missing', '0.59']
# record 77: ['NN', 'gender', 'False', 'German', '2gram-hash-at-both', '0.52']
# record 78: ['DT', 'plurality', 'True', 'German', '2gram-hash-at-both', '0.83']
# record 79: ['RF', 'plurality', 'True', 'German', 'missing', '0.84']
# record 80: ['NN', 'plurality', 'True', 'German', '2gram-hash-at-both', '0.83']
# record 81: ['DT', 'plurality', 'False', 'German', '2gram-hash-at-both', '0.75']
# record 82: ['RF', 'plurality', 'False', 'German', 'missing', '0.79']
# record 83: ['NN', 'plurality', 'False', 'German', '2gram-hash-at-both', '0.76']
# record 84: ['DT', 'gender', 'True', 'German', '3gram-hash-at-both', '0.54']
# record 85: ['RF', 'gender', 'True', 'German', 'missing', '0.59']
# record 86: ['NN', 'gender', 'True', 'German', '3gram-hash-at-both', '0.59']
# record 87: ['DT', 'gender', 'False', 'German', '3gram-hash-at-both', '0.48']
# record 88: ['RF', 'gender', 'False', 'German', 'missing', '0.54']
# record 89: ['NN', 'gender', 'False', 'German', '3gram-hash-at-both', '0.62']
# record 90: ['DT', 'plurality', 'True', 'German', '3gram-hash-at-both', '0.78']
# record 91: ['RF', 'plurality', 'True', 'German', 'missing', '0.82']
# record 92: ['NN', 'plurality', 'True', 'German', '3gram-hash-at-both', '0.83']
# record 93: ['DT', 'plurality', 'False', 'German', '3gram-hash-at-both', '0.79']
# record 94: ['RF', 'plurality', 'False', 'German', 'missing', '0.80']
# record 95: ['NN', 'plurality', 'False', 'German', '3gram-hash-at-both', '0.79']
# record 96: ['DT', 'gender', 'True', 'German', '4gram-hash-at-both', '0.51']
# record 97: ['RF', 'gender', 'True', 'German', 'missing', '0.58']
# record 98: ['NN', 'gender', 'True', 'German', '4gram-hash-at-both', '0.60']
# record 99: ['DT', 'gender', 'False', 'German', '4gram-hash-at-both', '0.51']
# record 100: ['RF', 'gender', 'False', 'German', 'missing', '0.59']
# record 101: ['NN', 'gender', 'False', 'German', '4gram-hash-at-both', '0.60']
# record 102: ['DT', 'plurality', 'True', 'German', '4gram-hash-at-both', '0.81']
# record 103: ['RF', 'plurality', 'True', 'German', 'missing', '0.82']
# record 104: ['NN', 'plurality', 'True', 'German', '4gram-hash-at-both', '0.84']
# record 105: ['DT', 'plurality', 'False', 'German', '4gram-hash-at-both', '0.78']
# record 106: ['RF', 'plurality', 'False', 'German', 'missing', '0.81']
# record 107: ['NN', 'plurality', 'False', 'German', '4gram-hash-at-both', '0.82']
# record 108: ['DT', 'gender', 'True', 'German', 'skippy2gram-hash-at-both', '0.48']
# record 109: ['RF', 'gender', 'True', 'German', 'missing', '0.65']
# record 110: ['NN', 'gender', 'True', 'German', 'skippy2gram-hash-at-both', '0.62']
# record 111: ['DT', 'gender', 'False', 'German', 'skippy2gram-hash-at-both', '0.49']
# record 112: ['RF', 'gender', 'False', 'German', 'missing', '0.64']
# record 113: ['NN', 'gender', 'False', 'German', 'skippy2gram-hash-at-both', '0.57']
# record 114: ['DT', 'plurality', 'True', 'German', 'skippy2gram-hash-at-both', '0.81']
# record 115: ['RF', 'plurality', 'True', 'German', 'missing', '0.85']
# record 116: ['NN', 'plurality', 'True', 'German', 'skippy2gram-hash-at-both', '0.82']
# record 117: ['DT', 'plurality', 'False', 'German', 'skippy2gram-hash-at-both', '0.78']
# record 118: ['RF', 'plurality', 'False', 'German', 'missing', '0.81']
# record 119: ['NN', 'plurality', 'False', 'German', 'skippy2gram-hash-at-both', '0.79']
# record 120: ['DT', 'gender', 'True', 'German', 'skippy3gram-hash-at-both', '0.47']
# record 121: ['RF', 'gender', 'True', 'German', 'missing', '0.57']
# record 122: ['NN', 'gender', 'True', 'German', 'skippy3gram-hash-at-both', '0.63']
# record 123: ['DT', 'gender', 'False', 'German', 'skippy3gram-hash-at-both', '0.47']
# record 124: ['RF', 'gender', 'False', 'German', 'missing', '0.55']
# record 125: ['NN', 'gender', 'False', 'German', 'skippy3gram-hash-at-both', '0.60']
# record 126: ['DT', 'plurality', 'True', 'German', 'skippy3gram-hash-at-both', '0.77']
# record 127: ['RF', 'plurality', 'True', 'German', 'missing', '0.80']
# record 128: ['NN', 'plurality', 'True', 'German', 'skippy3gram-hash-at-both', '0.75']
# record 129: ['DT', 'plurality', 'False', 'German', 'skippy3gram-hash-at-both', '0.71']
# record 130: ['RF', 'plurality', 'False', 'German', 'missing', '0.79']
# record 131: ['NN', 'plurality', 'False', 'German', 'skippy3gram-hash-at-both', '0.75']
# record 132: ['DT', 'gender', 'True', 'German', 'skippy4gram-hash-at-both', '0.51']
# record 133: ['RF', 'gender', 'True', 'German', 'missing', '0.59']
# record 134: ['NN', 'gender', 'True', 'German', 'skippy4gram-hash-at-both', '0.54']
# record 135: ['DT', 'gender', 'False', 'German', 'skippy4gram-hash-at-both', '0.52']
# record 136: ['RF', 'gender', 'False', 'German', 'missing', '0.57']
# record 137: ['NN', 'gender', 'False', 'German', 'skippy4gram-hash-at-both', '0.54']
# record 138: ['DT', 'plurality', 'True', 'German', 'skippy4gram-hash-at-both', '0.81']
# record 139: ['RF', 'plurality', 'True', 'German', 'missing', '0.85']
# record 140: ['NN', 'plurality', 'True', 'German', 'skippy4gram-hash-at-both', '0.79']
# record 141: ['DT', 'plurality', 'False', 'German', 'skippy4gram-hash-at-both', '0.79']
# record 142: ['RF', 'plurality', 'False', 'German', 'missing', '0.82']
# record 143: ['NN', 'plurality', 'False', 'German', 'skippy4gram-hash-at-both', '0.74']

# %%
dfs
# Out:
# [(('sample3000', 'French', 'French', 'mgv9', '12', '27', '22', '40.txt'),
#          lang     method attribute supplement                 term_type accuracy
#   0    French     gender      True         DT             2gram-no-hash     0.74
#   1    French     gender      True         RF                   missing     0.83
#   2    French     gender      True         NN             2gram-no-hash     0.77
#   3    French     gender     False         DT             2gram-no-hash     0.75
#   4    French     gender     False         RF                   missing     0.83
#   ..      ...        ...       ...        ...                       ...      ...
#   139  French  plurality      True         RF                   missing     0.93
#   140  French  plurality      True         NN  skippy4gram-hash-at-both     0.94
#   141  French  plurality     False         DT  skippy4gram-hash-at-both     0.90
#   142  French  plurality     False         RF                   missing     0.93
#   143  French  plurality     False         NN  skippy4gram-hash-at-both     0.95
#
#   [144 rows x 6 columns]),
#  (('sample3000', 'Czech', 'Czech', 'mgv9', '12', '27', '21', '29.txt'),
#        lang     method attribute supplement                 term_type accuracy
#   0   Czech  plurality      True         DT             2gram-no-hash     0.87
#   1   Czech  plurality      True         RF                   missing     0.87
#   2   Czech  plurality      True         NN             2gram-no-hash     0.86
#   3   Czech  plurality     False         DT             2gram-no-hash     0.77
#   4   Czech  plurality     False         RF                   missing     0.80
#   ..    ...        ...       ...        ...                       ...      ...
#   67  Czech  plurality      True         RF                   missing     0.90
#   68  Czech  plurality      True         NN  skippy4gram-hash-at-both     0.88
#   69  Czech  plurality     False         DT  skippy4gram-hash-at-both     0.80
#   70  Czech  plurality     False         RF                   missing     0.81
#   71  Czech  plurality     False         NN  skippy4gram-hash-at-both     0.80
#
#   [72 rows x 6 columns]),
#  (('sample3000', 'Irish', 'Irish', 'mgv9', '12', '28', '8', '50.txt'),
#         lang  method attribute supplement                 term_type accuracy
#   0    Irish  gender      True         DT             2gram-no-hash     0.81
#   1    Irish  gender      True         RF                   missing     0.87
#   2    Irish  gender      True         NN             2gram-no-hash     0.80
#   3    Irish  gender     False         DT             2gram-no-hash     0.71
#   4    Irish  gender     False         RF                   missing     0.77
#   ..     ...     ...       ...        ...                       ...      ...
#   211  Irish    case      True         RF                   missing     0.98
#   212  Irish    case      True         NN  skippy4gram-hash-at-both     0.98
#   213  Irish    case     False         DT  skippy4gram-hash-at-both     0.98
#   214  Irish    case     False         RF                   missing     0.98
#   215  Irish    case     False         NN  skippy4gram-hash-at-both     0.98
#
#   [216 rows x 6 columns]),
#  (('sample3000', 'German', 'German', 'mgv9', '12', '28', '2', '17.txt'),
#          lang     method attribute supplement                 term_type accuracy
#   0    German     gender      True         DT             2gram-no-hash     0.56
#   1    German     gender      True         RF                   missing     0.61
#   2    German     gender      True         NN             2gram-no-hash     0.57
#   3    German     gender     False         DT             2gram-no-hash     0.53
#   4    German     gender     False         RF                   missing     0.59
#   ..      ...        ...       ...        ...                       ...      ...
#   139  German  plurality      True         RF                   missing     0.85
#   140  German  plurality      True         NN  skippy4gram-hash-at-both     0.79
#   141  German  plurality     False         DT  skippy4gram-hash-at-both     0.79
#   142  German  plurality     False         RF                   missing     0.82
#   143  German  plurality     False         NN  skippy4gram-hash-at-both     0.74
#
#   [144 rows x 6 columns])]

# %%
## output
for d in dfs:
    key, df = d[0], d[1]
    #print(f"key: {key}")
    output_fname = f"results/{target_dir}/{'-'.join(key)}.csv"
    print(f"output_name: {output_fname}")
    df.to_csv(output_fname, index = False)
# Out:
# key: ('sample3000', 'French', 'French', 'mgv9', '12', '27', '22', '40.txt')
# output_name: results/3k/mgv9-sk/sample3000-French-French-mgv9-12-27-22-40.txt.csv
# key: ('sample3000', 'Czech', 'Czech', 'mgv9', '12', '27', '21', '29.txt')
# output_name: results/3k/mgv9-sk/sample3000-Czech-Czech-mgv9-12-27-21-29.txt.csv
# key: ('sample3000', 'Irish', 'Irish', 'mgv9', '12', '28', '8', '50.txt')
# output_name: results/3k/mgv9-sk/sample3000-Irish-Irish-mgv9-12-28-8-50.txt.csv
# key: ('sample3000', 'German', 'German', 'mgv9', '12', '28', '2', '17.txt')
# output_name: results/3k/mgv9-sk/sample3000-German-German-mgv9-12-28-2-17.txt.csv
